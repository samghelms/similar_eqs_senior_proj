# %% [markdown]
# In this notebook, I identify similar equations using a few heuristics I created. The heuristics check for "complete" mathematical expressions, w. You can see the heuristics in common/heuristics.py
#
# You can see the results in the last cell.
#
# things to add to split on at a high level: [,;.]

# %%
import pandas as pd
from common.clean import replace
from common.heuristics import has_op, test_for_suitable
from common.tokenize import tokenize

# %%
df = pd.DataFrame(pd.read_csv("../data/eqs_100k.tsv", sep = "\t", header=None))
df.columns = ["eq_id", "eq"]

# %%
df.head()
# Out:
#            eq_id                                                 eq
# 0       EQDS578Q                   \\begin{equation}\\end{equation}
# 1  EQDS33191905Q  \\begin{equation}\n \\det\\psi_-^{-1}=m_+^{(2)...
# 2   EQDS9271890Q  \\begin{equation}T^+_{\\varepsilon}(r):=\\inf\...
# 3  EQDS14066999Q  \\begin{equation}\\max_{U \\hbox{ is unitary }...
# 4  EQDS45956134Q  \\begin{equation}\\alpha=\\frac{1}{\\sum_{i=1}...

# %%
df['clean'] = replace(df['eq'])

# %%
from common.heuristics import split_high_level_eqs
df['clean_split'] = df['clean'].apply(split_high_level_eqs)

# %%
se = df['clean_split'].apply(lambda x: len(x) > 1 if x is not None else False)
df = df[se].reset_index()

# %%
se = df['clean_split'].apply(test_for_suitable)
df['clean_split_filtered'] = se
filt = df['clean_split_filtered'].apply(lambda x: x is not None)
df = df[filt]

# %%
for i in range(0, df['clean_split_filtered'].size):
    print("equation number "+str(i))
    for j in range(0, len(df['clean_split_filtered'].iloc[i])):
        print("sub-equation number "+str(j))
        print (df['clean_split_filtered'].iloc[i][j])
        print(tokenize(df['clean_split_filtered'].iloc[i][j]))
    if i == 400:
        break
    print("=============")
# Out:
# equation number 0
# sub-equation number 0
# \\left \\langle \\frac{dC}{dt} \\right \\rangle
# ['START', '\\', '\\left', '\\', '\\langle', '\\', '\\frac', '{', 'd', 'C', '}', '{', 'd', 't', '}', '\\', '\\right', '\\', '\\rangle']
# sub-equation number 1
# \\frac{e ~C}{1 - e^{2}} \\left \\langle \\frac{de}{dt} \\right \\rangle ~.
# ['START', '\\', '\\frac', '{', 'e', 'C', '}', '{', '1', '-', 'e', '{', '2', '}', '}', '\\', '\\left', '\\', '\\langle', '\\', '\\frac', '{', 'd', 'e', '}', '{', 'd', 't', '}', '\\', '\\right', '\\', '\\rangle']
# =============
# equation number 1
# sub-equation number 0
#  3\\widetilde{\\Gamma}_{2j}-3\\Gamma_{2j}
# ['START', '3', '\\', '\\widetilde', '{', '\\', '\\Gamma', '}', '{', '2', 'j', '}', '-', '3', '\\', '\\Gamma', '{', '2', 'j', '}']
# sub-equation number 1
# -3R_4(0)a_{2j}^2 -6\\int_{\\gamma_j}\\frac{S_2R_4}{r^5}\\,\\psi_2\\varphi_1^4\\,dw +3\\int_{\\gamma_j}\\frac{S_2R_3}{r^4}\\,\\psi_2^2\\varphi_1^3\\,dw.
# ['START', '-', '3', 'R', '4', '(', '0', ')', 'a', '{', '2', 'j', '}', '2', '-', '6', '\\', '\\int', '{', '\\', '\\gamma', 'j', '}', '\\', '\\frac', '{', 'S', '2', 'R', '4', '}', '{', 'r', '5', '}', '\\', '\\', '\\', '\\psi', '2', '\\', '\\varphi', '1', '4', '\\', '\\', 'd', 'w', '+', '3', '\\', '\\int', '{', '\\', '\\gamma', 'j', '}', '\\', '\\frac', '{', 'S', '2', 'R', '3', '}', '{', 'r', '4', '}', '\\', '\\', '\\', '\\psi', '2', '2', '\\', '\\varphi', '1', '3', '\\', '\\', 'd', 'w']
# =============
# equation number 2
# sub-equation number 0
# \\mathrm{or,}\\sqrt{\\alpha^2-\\beta^2}-c
# ['START', '\\', '\\mathrm', '{', 'o', 'r', '}', '\\', '\\sqrt', '{', '\\', '\\alpha', '2', '-', '\\', '\\beta', '2', '}', '-', 'c']
# sub-equation number 1
# -\\betaz+\\alpha\\sqrt{1+z^2}
# ['START', '-', '\\', '\\betaz', '+', '\\', '\\alpha', '\\', '\\sqrt', '{', '1', '+', 'z', '2', '}']
# =============
# equation number 3
# sub-equation number 0
# \\frac{1}{2}\\int_{0}^{1} \\frac{d}{ds} g\\big(\\dot{r}(s,t),\\dot{r}(s,t)\\big)\\;dt
# ['START', '\\', '\\frac', '{', '1', '}', '{', '2', '}', '\\', '\\int', '{', '0', '}', '{', '1', '}', '\\', '\\frac', '{', 'd', '}', '{', 'd', 's', '}', 'g', '\\', '\\big', '(', '\\', '\\dot', '{', 'r', '}', '(', 's', 't', ')', '\\', '\\dot', '{', 'r', '}', '(', 's', 't', ')', '\\', '\\big', ')', '\\', '\\', 'd', 't']
# sub-equation number 1
# \\int_{0}^{1} g\\big(\\frac{D}{ds}\\dot{r}(s,t),\\dot{r}(s,t)\\big)\\;dt
# ['START', '\\', '\\int', '{', '0', '}', '{', '1', '}', 'g', '\\', '\\big', '(', '\\', '\\frac', '{', 'D', '}', '{', 'd', 's', '}', '\\', '\\dot', '{', 'r', '}', '(', 's', 't', ')', '\\', '\\dot', '{', 'r', '}', '(', 's', 't', ')', '\\', '\\big', ')', '\\', '\\', 'd', 't']
# =============
# equation number 4
# sub-equation number 0
# \\sum_{\\mu=1}^\\infty\\frac{\\mu^{\\mu-1}}{\\mu!}\\;e^{-\\mu}\\;x^\\mu,t-1
# ['START', '\\', '\\sum', '{', '\\', '\\mu', '=', '1', '}', '\\', '\\infty', '\\', '\\frac', '{', '\\', '\\mu', '{', '\\', '\\mu', '-', '1', '}', '}', '{', '\\', '\\mu', '}', '\\', '\\', 'e', '{', '-', '\\', '\\mu', '}', '\\', '\\', 'x', '\\', '\\mu', 't', '-', '1']
# sub-equation number 1
# \\sum_{\\mu=1}^\\infty\\frac{\\mu^{\\mu}}{\\mu!}\\;e^{-\\mu}\\;x^\\mu.
# ['START', '\\', '\\sum', '{', '\\', '\\mu', '=', '1', '}', '\\', '\\infty', '\\', '\\frac', '{', '\\', '\\mu', '{', '\\', '\\mu', '}', '}', '{', '\\', '\\mu', '}', '\\', '\\', 'e', '{', '-', '\\', '\\mu', '}', '\\', '\\', 'x', '\\', '\\mu']
# =============
# equation number 5
# sub-equation number 0
# \\frac{\\omega_n}{\\omega_{n-j}}\\left(\\int_{{\\rmG}_{n,n-j}}V_{n-j}(K|\\xi)^{-1}d\\mu_{n-j}(\\xi)\\right)^{-1}, j
# ['START', '\\', '\\frac', '{', '\\', '\\omega', 'n', '}', '{', '\\', '\\omega', '{', 'n', '-', 'j', '}', '}', '\\', '\\left', '(', '\\', '\\int', '{', '{', '\\', '\\rmG', '}', '{', 'n', 'n', '-', 'j', '}', '}', 'V', '{', 'n', '-', 'j', '}', '(', 'K', '\\', '\\xi', ')', '{', '-', '1', '}', 'd', '\\', '\\mu', '{', 'n', '-', 'j', '}', '(', '\\', '\\xi', ')', '\\', '\\right', ')', '{', '-', '1', '}', 'j']
# sub-equation number 1
# 1, \\ldots, n-1.
# ['START', '1', '\\', '\\ldots', 'n', '-', '1']
# =============
# equation number 6
# sub-equation number 0
# {\\cal{H}}^{sp} + {\\cal{H}}^c + {\\cal{H}}^d
# ['START', '{', '\\', '\\cal', '{', 'H', '}', '}', '{', 's', 'p', '}', '+', '{', '\\', '\\cal', '{', 'H', '}', '}', 'c', '+', '{', '\\', '\\cal', '{', 'H', '}', '}', 'd']
# sub-equation number 1
#  T + V   \\;,
# ['START', 'T', '+', 'V', '\\', '\\']
# =============
# equation number 7
# sub-equation number 0
# \\frac{e^{-\\gammat}}{L^{\\sigma}}\\mathrm{Im}\\sum_{n=-N}^{n=N}(-\\gammau_n+\\dot{u}_n)
# ['START', '\\', '\\frac', '{', 'e', '{', '-', '\\', '\\gammat', '}', '}', '{', 'L', '{', '\\', '\\sigma', '}', '}', '\\', '\\mathrm', '{', 'I', 'm', '}', '\\', '\\sum', '{', 'n', '=', '-', 'N', '}', '{', 'n', '=', 'N', '}', '(', '-', '\\', '\\gammau', 'n', '+', '\\', '\\dot', '{', 'u', '}', 'n', ')']
# sub-equation number 1
# \\frac{e^{-\\gammat}}{L^{\\sigma}}\\mathrm{Im}\\sum_{n=-N}^{n=N}\\left\\{(\\lambda+i\\alpha)(u_{n-1}-2u_n+u_{n+1})+F(u_n)\\right\\}
# ['START', '\\', '\\frac', '{', 'e', '{', '-', '\\', '\\gammat', '}', '}', '{', 'L', '{', '\\', '\\sigma', '}', '}', '\\', '\\mathrm', '{', 'I', 'm', '}', '\\', '\\sum', '{', 'n', '=', '-', 'N', '}', '{', 'n', '=', 'N', '}', '\\', '\\left', '\\', '\\', '{', '(', '\\', '\\lambda', '+', 'i', '\\', '\\alpha', ')', '(', 'u', '{', 'n', '-', '1', '}', '-', '2', 'u', 'n', '+', 'u', '{', 'n', '+', '1', '}', ')', '+', 'F', '(', 'u', 'n', ')', '\\', '\\right', '\\', '\\', '}']
# =============
# equation number 8
# sub-equation number 0
#  \\frac{2 c}{\\sqrt{ |g|}} \\, \\frac{\\delta S}{\\delta g^{ik}}\\ \\ \\ \\Leftrightarrow \\ \\ \\\nT^{ik}
# ['START', '\\', '\\frac', '{', '2', 'c', '}', '{', '\\', '\\sqrt', '{', 'g', '}', '}', '\\', '\\', '\\', '\\frac', '{', '\\', '\\delta', 'S', '}', '{', '\\', '\\delta', 'g', '{', 'i', 'k', '}', '}', '\\', '\\', '\\', '\\', '\\', '\\', '\\', '\\Leftrightarrow', '\\', '\\', '\\', '\\', '\\', '\\', '\\nT', '{', 'i', 'k', '}']
# sub-equation number 1
#  - \\frac{2 c}{\\sqrt{ |g|}} \\, \\frac{\\delta S}{\\delta g_{ik}} \\,.
# ['START', '-', '\\', '\\frac', '{', '2', 'c', '}', '{', '\\', '\\sqrt', '{', 'g', '}', '}', '\\', '\\', '\\', '\\frac', '{', '\\', '\\delta', 'S', '}', '{', '\\', '\\delta', 'g', '{', 'i', 'k', '}', '}', '\\', '\\']
# =============
# equation number 9
# sub-equation number 0
#  - \\frac{1}{3} \\, \\left\\{ \\nabla_{x} \\! \\cdot \\! \\vec{u}(\\vec{x}) \\right\\} \\, \\frac{p^{2}}{E} \\stackrel{\\rm ave}{\\xrightarrow{\\hspace*{1cm}}} b_{\\rm adia}(K)
# ['START', '-', '\\', '\\frac', '{', '1', '}', '{', '3', '}', '\\', '\\', '\\', '\\left', '\\', '\\', '{', '\\', '\\nabla', '{', 'x', '}', '\\', '\\', '\\', '\\cdot', '\\', '\\', '\\', '\\vec', '{', 'u', '}', '(', '\\', '\\vec', '{', 'x', '}', ')', '\\', '\\right', '\\', '\\', '}', '\\', '\\', '\\', '\\frac', '{', 'p', '{', '2', '}', '}', '{', 'E', '}', '\\', '\\stackrel', '{', '\\', '\\rm', 'a', 'v', 'e', '}', '{', '\\', '\\xrightarrow', '{', '\\', '\\hspace', '*', '{', '1', 'c', 'm', '}', '}', '}', 'b', '{', '\\', '\\rm', 'a', 'd', 'i', 'a', '}', '(', 'K', ')']
# sub-equation number 1
#  - \\frac{V_{\\rm conv}}{3h} \\, \\frac{p^{2}}{E}
# ['START', '-', '\\', '\\frac', '{', 'V', '{', '\\', '\\rm', 'c', 'o', 'n', 'v', '}', '}', '{', '3', 'h', '}', '\\', '\\', '\\', '\\frac', '{', 'p', '{', '2', '}', '}', '{', 'E', '}']
# =============
# equation number 10
# sub-equation number 0
# 2\\langle\\triangle^\\perp{\\vec{H}},{\\vec{H}}\\rangle+2\\|\\nabla^\\perp{\\vec{H}}\\|^2
# ['START', '2', '\\', '\\langle', '\\', '\\triangle', '\\', '\\perp', '{', '\\', '\\vec', '{', 'H', '}', '}', '{', '\\', '\\vec', '{', 'H', '}', '}', '\\', '\\rangle', '+', '2', '\\', '\\', '\\', '\\nabla', '\\', '\\perp', '{', '\\', '\\vec', '{', 'H', '}', '}', '\\', '\\', '2']
# sub-equation number 1
# 2\\langle{\\vec{H}}-P^{ik}A_{ik}+\\theta^k\\nabla_k^\\perp{\\vec{H}},{\\vec{H}}\\rangle+2\\|\\nabla^\\perp{\\vec{H}}\\|^2
# ['START', '2', '\\', '\\langle', '{', '\\', '\\vec', '{', 'H', '}', '}', '-', 'P', '{', 'i', 'k', '}', 'A', '{', 'i', 'k', '}', '+', '\\', '\\theta', 'k', '\\', '\\nabla', 'k', '\\', '\\perp', '{', '\\', '\\vec', '{', 'H', '}', '}', '{', '\\', '\\vec', '{', 'H', '}', '}', '\\', '\\rangle', '+', '2', '\\', '\\', '\\', '\\nabla', '\\', '\\perp', '{', '\\', '\\vec', '{', 'H', '}', '}', '\\', '\\', '2']
# =============
# equation number 11
# sub-equation number 0
#  a\\hat{x}(t) +  K(t) y(t)\\\\\n\\check{x}(t+1)
# ['START', 'a', '\\', '\\hat', '{', 'x', '}', '(', 't', ')', '+', 'K', '(', 't', ')', 'y', '(', 't', ')', '\\', '\\', '\\', '\\', '\\n', '\\', '\\check', '{', 'x', '}', '(', 't', '+', '1', ')']
# sub-equation number 1
#  aN(P+N)^{-1} \\check{x}(t) + x(t+1)-ax(t)  \\\\\n ~~~+ a\\bar{\\sigma}_t^2 (\\bar{\\sigma}_t^2 + N_\\textup{f})^{-1}(x(t) - \\check{x}(t) - y_\\textup{f}(t))\\\\ z(t)
# ['START', 'a', 'N', '(', 'P', '+', 'N', ')', '{', '-', '1', '}', '\\', '\\check', '{', 'x', '}', '(', 't', ')', '+', 'x', '(', 't', '+', '1', ')', '-', 'a', 'x', '(', 't', ')', '\\', '\\', '\\', '\\', '\\n', '+', 'a', '\\', '\\bar', '{', '\\', '\\sigma', '}', 't', '2', '(', '\\', '\\bar', '{', '\\', '\\sigma', '}', 't', '2', '+', 'N', '\\', '\\textup', '{', 'f', '}', ')', '{', '-', '1', '}', '(', 'x', '(', 't', ')', '-', '\\', '\\check', '{', 'x', '}', '(', 't', ')', '-', 'y', '\\', '\\textup', '{', 'f', '}', '(', 't', ')', ')', '\\', '\\', '\\', '\\', 'z', '(', 't', ')']
# sub-equation number 2
#  \\frac{\\sqrt{P}}{\\sigma_t} \\check{x}(t),\\\\\n \\end{aligned}
# ['START', '\\', '\\frac', '{', '\\', '\\sqrt', '{', 'P', '}', '}', '{', '\\', '\\sigma', 't', '}', '\\', '\\check', '{', 'x', '}', '(', 't', ')', '\\', '\\', '\\', '\\', '\\n', '\\', '\\end', '{', 'a', 'l', 'i', 'g', 'n', 'e', 'd', '}']
# =============
# equation number 12
# sub-equation number 0
#  \\Sigma_{jk}(p)-\\varphi^{l}  (\\Lambda_{lj;k}^{(3)}(p)-\\Gamma_{ljk}^{(3)})  \\\\\n
# ['START', '\\', '\\Sigma', '{', 'j', 'k', '}', '(', 'p', ')', '-', '\\', '\\varphi', '{', 'l', '}', '(', '\\', '\\Lambda', '{', 'l', 'j', 'k', '}', '{', '(', '3', ')', '}', '(', 'p', ')', '-', '\\', '\\Gamma', '{', 'l', 'j', 'k', '}', '{', '(', '3', ')', '}', ')', '\\', '\\', '\\', '\\', '\\n']
# sub-equation number 1
#  \\Sigma_{jk} - \\vec{\\varphi}^{2} \\{ [3 \\lambda +  \\Lambda_{2}^{(3)}(p)+2\\Lambda_{4}^{(3)}(p)] P_{\\parallel jk}+  [\\lambda+\\Lambda_{3}^{(3)}(p)] P_{\\perp jk} \\} .\\end{split}
# ['START', '\\', '\\Sigma', '{', 'j', 'k', '}', '-', '\\', '\\vec', '{', '\\', '\\varphi', '}', '{', '2', '}', '\\', '\\', '{', '3', '\\', '\\lambda', '+', '\\', '\\Lambda', '{', '2', '}', '{', '(', '3', ')', '}', '(', 'p', ')', '+', '2', '\\', '\\Lambda', '{', '4', '}', '{', '(', '3', ')', '}', '(', 'p', ')', 'P', '{', '\\', '\\parallel', 'j', 'k', '}', '+', '\\', '\\lambda', '+', '\\', '\\Lambda', '{', '3', '}', '{', '(', '3', ')', '}', '(', 'p', ')', 'P', '{', '\\', '\\perp', 'j', 'k', '}', '\\', '\\', '}', '\\', '\\end', '{', 's', 'p', 'l', 'i', 't', '}']
# =============
# equation number 13
# sub-equation number 0
# \\lim_{n\\to\\infty}\\frac{\\log(\\rho^{\\star}_{\\lambda^{\\textup{{\\textsf{{UC}}}}}}(n))}{\\log(n)}
# ['START', '\\', '\\lim', '{', 'n', '\\', '\\to', '\\', '\\infty', '}', '\\', '\\frac', '{', '\\', '\\log', '(', '\\', '\\rho', '{', '\\', '\\star', '}', '{', '\\', '\\lambda', '{', '\\', '\\textup', '{', '{', '\\', '\\textsf', '{', '{', 'U', 'C', '}', '}', '}', '}', '}', '}', '(', 'n', ')', ')', '}', '{', '\\', '\\log', '(', 'n', ')', '}']
# sub-equation number 1
# \\lim_{n\\to\\infty}\\frac{\\log(\\hat{\\rho}^{\\star}_{\\lambda^{\\textup{{\\textsf{{UC}}}}}}(n))}{\\log(n)}.
# ['START', '\\', '\\lim', '{', 'n', '\\', '\\to', '\\', '\\infty', '}', '\\', '\\frac', '{', '\\', '\\log', '(', '\\', '\\hat', '{', '\\', '\\rho', '}', '{', '\\', '\\star', '}', '{', '\\', '\\lambda', '{', '\\', '\\textup', '{', '{', '\\', '\\textsf', '{', '{', 'U', 'C', '}', '}', '}', '}', '}', '}', '(', 'n', ')', ')', '}', '{', '\\', '\\log', '(', 'n', ')', '}']
# =============
# equation number 14
# sub-equation number 0
#  \\int  \\limits_{0}^{\\beta_0}  {\\rm d} \\beta \\beta\\alpha \\left [ \\frac{\\beta}{\\pi \\alpha} +\\frac 1 2 + \\frac{\\pi\\alpha}{12\\beta} \\right ]\\;,\\\\\nI_2
# ['START', '\\', '\\int', '\\', '\\limits', '{', '0', '}', '{', '\\', '\\beta', '0', '}', '{', '\\', '\\rm', 'd', '}', '\\', '\\beta', '\\', '\\beta', '\\', '\\alpha', '\\', '\\left', '\\', '\\frac', '{', '\\', '\\beta', '}', '{', '\\', '\\pi', '\\', '\\alpha', '}', '+', '\\', '\\frac', '1', '2', '+', '\\', '\\frac', '{', '\\', '\\pi', '\\', '\\alpha', '}', '{', '1', '2', '\\', '\\beta', '}', '\\', '\\right', '\\', '\\', '\\', '\\', '\\', '\\', '\\nI', '2']
# sub-equation number 1
#  \\int  \\limits_{0}^{\\beta_0}  {\\rm d} \\beta \\beta \\alpha \\left [\\frac{1}{1-e^{-\\pi \\alpha/\\beta}} - \\frac{\\beta}{\\pi \\alpha} - \\frac 1 2- \\frac{\\pi\\alpha}{12\\beta} \\right ].\\end{split}
# ['START', '\\', '\\int', '\\', '\\limits', '{', '0', '}', '{', '\\', '\\beta', '0', '}', '{', '\\', '\\rm', 'd', '}', '\\', '\\beta', '\\', '\\beta', '\\', '\\alpha', '\\', '\\left', '\\', '\\frac', '{', '1', '}', '{', '1', '-', 'e', '{', '-', '\\', '\\pi', '\\', '\\alpha', '\\', '\\beta', '}', '}', '-', '\\', '\\frac', '{', '\\', '\\beta', '}', '{', '\\', '\\pi', '\\', '\\alpha', '}', '-', '\\', '\\frac', '1', '2', '-', '\\', '\\frac', '{', '\\', '\\pi', '\\', '\\alpha', '}', '{', '1', '2', '\\', '\\beta', '}', '\\', '\\right', '\\', '\\end', '{', 's', 'p', 'l', 'i', 't', '}']
# =============
# equation number 15
# sub-equation number 0
# \\pi_i\\frac{\\pi'W^*e_i}{\\pi'W^*\\pi}
# ['START', '\\', '\\pi', 'i', '\\', '\\frac', '{', '\\', '\\pi', 'W', '*', 'e', 'i', '}', '{', '\\', '\\pi', 'W', '*', '\\', '\\pi', '}']
# sub-equation number 1
# \\frac{\\pi'W^*e_ie_i'\\pi}{\\pi'W^*\\pi}
# ['START', '\\', '\\frac', '{', '\\', '\\pi', 'W', '*', 'e', 'i', 'e', 'i', '\\', '\\pi', '}', '{', '\\', '\\pi', 'W', '*', '\\', '\\pi', '}']
# =============
# equation number 16
# sub-equation number 0
# \\frac{L^{3/2} }{12 \\pi}+\\frac{ \\sqrt{L}}{\\pi}
# ['START', '\\', '\\frac', '{', 'L', '{', '3', '2', '}', '}', '{', '1', '2', '\\', '\\pi', '}', '+', '\\', '\\frac', '{', '\\', '\\sqrt', '{', 'L', '}', '}', '{', '\\', '\\pi', '}']
# sub-equation number 1
# s\\,\\sqrt{b} \\;\\;\\;\\textrm{and} \\;\\;\\;  R
# ['STARTs', '\\', '\\', '\\', '\\sqrt', '{', 'b', '}', '\\', '\\', '\\', '\\', '\\', '\\', '\\', '\\textrm', '{', 'a', 'n', 'd', '}', '\\', '\\', '\\', '\\', '\\', '\\', 'R']
# sub-equation number 2
# \\frac{2 \\pi}{\\sqrt{L}}-\\frac{ \\pi \\sqrt{L}}{2}
# ['START', '\\', '\\frac', '{', '2', '\\', '\\pi', '}', '{', '\\', '\\sqrt', '{', 'L', '}', '}', '-', '\\', '\\frac', '{', '\\', '\\pi', '\\', '\\sqrt', '{', 'L', '}', '}', '{', '2', '}']
# =============
# equation number 17
# sub-equation number 0
# \\bigcup_{i \\in I} \\Omega_i : {\\mathcal{X}} {\\dashrightarrow} {\\mathcal{Y}},  \\left( \\bigcup_{i \\in I} \\Omega_i \\right)(x):
# ['START', '\\', '\\bigcup', '{', 'i', '\\', '\\in', 'I', '}', '\\', '\\Omega', 'i', '{', '\\', '\\mathcal', '{', 'X', '}', '}', '{', '\\', '\\dashrightarrow', '}', '{', '\\', '\\mathcal', '{', 'Y', '}', '}', '\\', '\\left', '(', '\\', '\\bigcup', '{', 'i', '\\', '\\in', 'I', '}', '\\', '\\Omega', 'i', '\\', '\\right', ')', '(', 'x', ')']
# sub-equation number 1
# \\bigcup_{i \\in I} \\Omega_i(x) \\text{ for all } x \\in {\\mathcal{X}}.
# ['START', '\\', '\\bigcup', '{', 'i', '\\', '\\in', 'I', '}', '\\', '\\Omega', 'i', '(', 'x', ')', '\\', '\\text', '{', 'f', 'o', 'r', 'a', 'l', 'l', '}', 'x', '\\', '\\in', '{', '\\', '\\mathcal', '{', 'X', '}', '}']
# =============
# equation number 18
# sub-equation number 0
# \\textstyle p_0-1
# ['START', '\\', '\\textstyle', 'p', '0', '-', '1']
# sub-equation number 1
# \\frac{2\\delta}{\\delta+1} (p-1),  \\frac{1}{p}
# ['START', '\\', '\\frac', '{', '2', '\\', '\\delta', '}', '{', '\\', '\\delta', '+', '1', '}', '(', 'p', '-', '1', ')', '\\', '\\frac', '{', '1', '}', '{', 'p', '}']
# sub-equation number 2
#  \\frac{1}{2p_0}+\\frac{1}{2p_1}.
# ['START', '\\', '\\frac', '{', '1', '}', '{', '2', 'p', '0', '}', '+', '\\', '\\frac', '{', '1', '}', '{', '2', 'p', '1', '}']
# =============
# equation number 19
# sub-equation number 0
# \\frac{\\vec{\\eta} \\cdot \\vec{\\xi} + \\Omega\\vec{\\xi} \\cdot \\vec{\\xi}}{\\vec{\\eta}\\cdot \\vec{\\eta} + \\Omega\\vec{\\eta} \\cdot \\vec{\\xi}}
# ['START', '\\', '\\frac', '{', '\\', '\\vec', '{', '\\', '\\eta', '}', '\\', '\\cdot', '\\', '\\vec', '{', '\\', '\\xi', '}', '+', '\\', '\\Omega', '\\', '\\vec', '{', '\\', '\\xi', '}', '\\', '\\cdot', '\\', '\\vec', '{', '\\', '\\xi', '}', '}', '{', '\\', '\\vec', '{', '\\', '\\eta', '}', '\\', '\\cdot', '\\', '\\vec', '{', '\\', '\\eta', '}', '+', '\\', '\\Omega', '\\', '\\vec', '{', '\\', '\\eta', '}', '\\', '\\cdot', '\\', '\\vec', '{', '\\', '\\xi', '}', '}']
# sub-equation number 1
# \\frac{{\\mathfrak R}^2\\Omega - \\omega}{\\Omega\\omega -1}.
# ['START', '\\', '\\frac', '{', '{', '\\', '\\mathfrak', 'R', '}', '2', '\\', '\\Omega', '-', '\\', '\\omega', '}', '{', '\\', '\\Omega', '\\', '\\omega', '-', '1', '}']
# =============
# equation number 20
# sub-equation number 0
# 2-\\frac{\\nu}{z_1}-\\frac{\\nu}{z_2}
# ['START', '2', '-', '\\', '\\frac', '{', '\\', '\\nu', '}', '{', 'z', '1', '}', '-', '\\', '\\frac', '{', '\\', '\\nu', '}', '{', 'z', '2', '}']
# sub-equation number 1
# 1\\mbox{with}\\frac{\\nu}{z_3}\\geq1
# ['START', '1', '\\', '\\mbox', '{', 'w', 'i', 't', 'h', '}', '\\', '\\frac', '{', '\\', '\\nu', '}', '{', 'z', '3', '}', '\\', '\\geq', '1']
# =============
# equation number 21
# sub-equation number 0
# \\lim_{i \\to \\infty} \\int_{-L_{i,\\pm}}^{L_{i,\\pm}}\\int_{S^1} v_{i,\\pm}^* \\Theta^* d\\lambda
# ['START', '\\', '\\lim', '{', 'i', '\\', '\\to', '\\', '\\infty', '}', '\\', '\\int', '{', '-', 'L', '{', 'i', '\\', '\\pm', '}', '}', '{', 'L', '{', 'i', '\\', '\\pm', '}', '}', '\\', '\\int', '{', 'S', '1', '}', 'v', '{', 'i', '\\', '\\pm', '}', '*', '\\', '\\Theta', '*', 'd', '\\', '\\lambda']
# sub-equation number 1
#  0, E_\\Sigma(v_{i,\\pm}) \\leq 2\\pi + \\delta.
# ['START', '0', 'E', '\\', '\\Sigma', '(', 'v', '{', 'i', '\\', '\\pm', '}', ')', '\\', '\\leq', '2', '\\', '\\pi', '+', '\\', '\\delta']
# =============
# equation number 22
# sub-equation number 0
# \\frac{2m(2m-1)}{m(m+1)}\\,Y_{0}(m-1)
# ['START', '\\', '\\frac', '{', '2', 'm', '(', '2', 'm', '-', '1', ')', '}', '{', 'm', '(', 'm', '+', '1', ')', '}', '\\', '\\', 'Y', '{', '0', '}', '(', 'm', '-', '1', ')']
# sub-equation number 1
# \\frac{(2m)!}{m!(m+1)!}.
# ['START', '\\', '\\frac', '{', '(', '2', 'm', ')', '}', '{', 'm', '(', 'm', '+', '1', ')', '}']
# =============
# equation number 23
# sub-equation number 0
# \\left|\\frac{A_h|_{v^6}}{A_h|_{v^0}}\\right|_{v^6}^2
# ['START', '\\', '\\left', '\\', '\\frac', '{', 'A', 'h', '{', 'v', '6', '}', '}', '{', 'A', 'h', '{', 'v', '0', '}', '}', '\\', '\\right', '{', 'v', '6', '}', '2']
# sub-equation number 1
# -(G_NM\\omega)^2\\frac{214}{105}\\ln\\frac{\\omega^2}{\\mu^2}+\\ldots\\,,
# ['START', '-', '(', 'G', 'N', 'M', '\\', '\\omega', ')', '2', '\\', '\\frac', '{', '2', '1', '4', '}', '{', '1', '0', '5', '}', '\\', '\\ln', '\\', '\\frac', '{', '\\', '\\omega', '2', '}', '{', '\\', '\\mu', '2', '}', '+', '\\', '\\ldots', '\\', '\\']
# =============
# equation number 24
# sub-equation number 0
#   \\downarrow {{\\rho_{\\vec{y},\\vec{x}}}^{\\alpha}} ({{ \\overline{\\exists}_{\\vec{y}}}^{\\alpha}}({{S_H}^{\\alpha}} {\\llbracket {p(\\vec{y})} \\rrbracket}))  \\\\  where  p(\\vec{y}) {\\leftarrow}  B \\in P  \\\\\n{{S_G}^{\\alpha}} {\\llbracket {G_1, G_2} \\rrbracket}
# ['START', '\\', '\\downarrow', '{', '{', '\\', '\\rho', '{', '\\', '\\vec', '{', 'y', '}', '\\', '\\vec', '{', 'x', '}', '}', '}', '{', '\\', '\\alpha', '}', '}', '(', '{', '{', '\\', '\\overline', '{', '\\', '\\exists', '}', '{', '\\', '\\vec', '{', 'y', '}', '}', '}', '{', '\\', '\\alpha', '}', '}', '(', '{', '{', 'S', 'H', '}', '{', '\\', '\\alpha', '}', '}', '{', '\\', '\\llbracket', '{', 'p', '(', '\\', '\\vec', '{', 'y', '}', ')', '}', '\\', '\\rrbracket', '}', ')', ')', '\\', '\\', '\\', '\\', 'w', 'h', 'e', 'r', 'e', 'p', '(', '\\', '\\vec', '{', 'y', '}', ')', '{', '\\', '\\leftarrow', '}', 'B', '\\', '\\in', 'P', '\\', '\\', '\\', '\\', '\\n', '{', '{', 'S', 'G', '}', '{', '\\', '\\alpha', '}', '}', '{', '\\', '\\llbracket', '{', 'G', '1', 'G', '2', '}', '\\', '\\rrbracket', '}']
# sub-equation number 1
#   \\downarrow {{\\overline{ \\exists}_{\\vec{y}}}^{\\alpha}} ( {{S_G}^{\\alpha}} {\\llbracket {G_1} \\rrbracket} \\vee {{S_G}^{\\alpha}} {\\llbracket {G_2, G_3} \\rrbracket} \\vee {{S_G}^{\\alpha}} {\\llbracket {G_4} \\rrbracket} )\\\\  where  p(\\vec{y}) {\\leftarrow} B \\in P \\ and \\ B
# ['START', '\\', '\\downarrow', '{', '{', '\\', '\\overline', '{', '\\', '\\exists', '}', '{', '\\', '\\vec', '{', 'y', '}', '}', '}', '{', '\\', '\\alpha', '}', '}', '(', '{', '{', 'S', 'G', '}', '{', '\\', '\\alpha', '}', '}', '{', '\\', '\\llbracket', '{', 'G', '1', '}', '\\', '\\rrbracket', '}', '\\', '\\vee', '{', '{', 'S', 'G', '}', '{', '\\', '\\alpha', '}', '}', '{', '\\', '\\llbracket', '{', 'G', '2', 'G', '3', '}', '\\', '\\rrbracket', '}', '\\', '\\vee', '{', '{', 'S', 'G', '}', '{', '\\', '\\alpha', '}', '}', '{', '\\', '\\llbracket', '{', 'G', '4', '}', '\\', '\\rrbracket', '}', ')', '\\', '\\', '\\', '\\', 'w', 'h', 'e', 'r', 'e', 'p', '(', '\\', '\\vec', '{', 'y', '}', ')', '{', '\\', '\\leftarrow', '}', 'B', '\\', '\\in', 'P', '\\', '\\', 'a', 'n', 'd', '\\', '\\', 'B']
# =============
# equation number 25
# sub-equation number 0
# \\frac{1}{1-te^{x}}
# ['START', '\\', '\\frac', '{', '1', '}', '{', '1', '-', 't', 'e', '{', 'x', '}', '}']
# sub-equation number 1
# \\frac{1+te^{x}}{1-t^{2}e^{2x}}
# ['START', '\\', '\\frac', '{', '1', '+', 't', 'e', '{', 'x', '}', '}', '{', '1', '-', 't', '{', '2', '}', 'e', '{', '2', 'x', '}', '}']
# sub-equation number 2
# \\frac{1}{1-t}+\\sum_{n=1}^{\\infty}\\sum_{\\pi\\in\\mathfrak{S}_{n}}\\frac{(1+t^{2})^{n}}{2(1-t^{2})^{n-1}(1-t)^{2}}\\left(\\frac{2t}{1+t^{2}}\\right)^{{\\operatorname{udr}}(\\pi)}\\frac{x^{n}}{n!}.
# ['START', '\\', '\\frac', '{', '1', '}', '{', '1', '-', 't', '}', '+', '\\', '\\sum', '{', 'n', '=', '1', '}', '{', '\\', '\\infty', '}', '\\', '\\sum', '{', '\\', '\\pi', '\\', '\\in', '\\', '\\mathfrak', '{', 'S', '}', '{', 'n', '}', '}', '\\', '\\frac', '{', '(', '1', '+', 't', '{', '2', '}', ')', '{', 'n', '}', '}', '{', '2', '(', '1', '-', 't', '{', '2', '}', ')', '{', 'n', '-', '1', '}', '(', '1', '-', 't', ')', '{', '2', '}', '}', '\\', '\\left', '(', '\\', '\\frac', '{', '2', 't', '}', '{', '1', '+', 't', '{', '2', '}', '}', '\\', '\\right', ')', '{', '{', '\\', '\\operatorname', '{', 'u', 'd', 'r', '}', '}', '(', '\\', '\\pi', ')', '}', '\\', '\\frac', '{', 'x', '{', 'n', '}', '}', '{', 'n', '}']
# =============
# equation number 26
# sub-equation number 0
# -\\frac{f^2}{Q^2}\\,\\simeq\\,\\Pi^T_{V-A}(Q^2)
# ['START', '-', '\\', '\\frac', '{', 'f', '2', '}', '{', 'Q', '2', '}', '\\', '\\', '\\', '\\simeq', '\\', '\\', '\\', '\\Pi', 'T', '{', 'V', '-', 'A', '}', '(', 'Q', '2', ')']
# sub-equation number 1
# \\left(\\frac{F^2}{a}(M_{A}^2-M_V^2)-f^2\\right)\\frac{1}{Q^2}
# ['START', '\\', '\\left', '(', '\\', '\\frac', '{', 'F', '2', '}', '{', 'a', '}', '(', 'M', '{', 'A', '}', '2', '-', 'M', 'V', '2', ')', '-', 'f', '2', '\\', '\\right', ')', '\\', '\\frac', '{', '1', '}', '{', 'Q', '2', '}']
# =============
# equation number 27
# sub-equation number 0
# \\frac{2k\\cdotQF_\\pi(Q^2)}{(k\\cdotQ)^2-(k\\cdotl)^2},\\;\\;\\;f_2^{sQED}
# ['START', '\\', '\\frac', '{', '2', 'k', '\\', '\\cdotQF', '\\', '\\pi', '(', 'Q', '2', ')', '}', '{', '(', 'k', '\\', '\\cdotQ', ')', '2', '-', '(', 'k', '\\', '\\cdotl', ')', '2', '}', '\\', '\\', '\\', '\\', '\\', '\\', 'f', '2', '{', 's', 'Q', 'E', 'D', '}']
# sub-equation number 1
# \\frac{-2F_\\pi(Q^2)}{(k\\cdotQ)^2-(k\\cdotl)^2},\\;\\;
# ['START', '\\', '\\frac', '{', '-', '2', 'F', '\\', '\\pi', '(', 'Q', '2', ')', '}', '{', '(', 'k', '\\', '\\cdotQ', ')', '2', '-', '(', 'k', '\\', '\\cdotl', ')', '2', '}', '\\', '\\', '\\', '\\']
# =============
# equation number 28
# sub-equation number 0
# \\frac{\\kappa^{w\\kappa}\\exp(-\\kappa)}{(w\\kappa)!},\\;\\;w
# ['START', '\\', '\\frac', '{', '\\', '\\kappa', '{', 'w', '\\', '\\kappa', '}', '\\', '\\exp', '(', '-', '\\', '\\kappa', ')', '}', '{', '(', 'w', '\\', '\\kappa', ')', '}', '\\', '\\', '\\', '\\', 'w']
# sub-equation number 1
# 0,\\frac{1}{\\kappa},\\frac{2}{\\kappa},\\frac{3}{\\kappa},\\dots
# ['START', '0', '\\', '\\frac', '{', '1', '}', '{', '\\', '\\kappa', '}', '\\', '\\frac', '{', '2', '}', '{', '\\', '\\kappa', '}', '\\', '\\frac', '{', '3', '}', '{', '\\', '\\kappa', '}', '\\', '\\dots']
# =============
# equation number 29
# sub-equation number 0
# \\int_0^h\\rhodz
# ['START', '\\', '\\int', '0', 'h', '\\', '\\rhodz']
# sub-equation number 1
# \\Sigma_0+\\Sigma^{'},
# ['START', '\\', '\\Sigma', '0', '+', '\\', '\\Sigma', '{', '}']
# =============
# equation number 30
# sub-equation number 0
# \\ \\frac{L_{\\mathit ME}}{D_{\\mathit MM}}\\nabla T\\
# ['START', '\\', '\\', '\\', '\\frac', '{', 'L', '{', '\\', '\\mathit', 'M', 'E', '}', '}', '{', 'D', '{', '\\', '\\mathit', 'M', 'M', '}', '}', '\\', '\\nabla', 'T', '\\', '\\']
# sub-equation number 1
# \\ -B\\frac{\\partial \\chi}{\\partial T} \\nabla T~.
# ['START', '\\', '\\', '-', 'B', '\\', '\\frac', '{', '\\', '\\partial', '\\', '\\chi', '}', '{', '\\', '\\partial', 'T', '}', '\\', '\\nabla', 'T']
# =============
# equation number 31
# sub-equation number 0
#  \\frac{\\delta c_s}{c_s}
# ['START', '\\', '\\frac', '{', '\\', '\\delta', 'c', 's', '}', '{', 'c', 's', '}']
# sub-equation number 1
#  \\frac{c_{s,\\, {\\rm mag}} - c_{s,\\, 0}}{c_{s,\\, 0}},
# ['START', '\\', '\\frac', '{', 'c', '{', 's', '\\', '\\', '{', '\\', '\\rm', 'm', 'a', 'g', '}', '}', '-', 'c', '{', 's', '\\', '\\', '0', '}', '}', '{', 'c', '{', 's', '\\', '\\', '0', '}', '}']
# =============
# equation number 32
# sub-equation number 0
# E_{0}-2V\\!\\cos\\phi^{\\,min}_k\\!
# ['STARTE', '{', '0', '}', '-', '2', 'V', '\\', '\\', '\\', '\\cos', '\\', '\\phi', '{', '\\', '\\', 'm', 'i', 'n', '}', 'k', '\\', '\\']
# sub-equation number 1
# E_{0}-2V\\!\\cos\\frac{\\pi(k+1/2)}{N+1}\\,,
# ['STARTE', '{', '0', '}', '-', '2', 'V', '\\', '\\', '\\', '\\cos', '\\', '\\frac', '{', '\\', '\\pi', '(', 'k', '+', '1', '2', ')', '}', '{', 'N', '+', '1', '}', '\\', '\\']
# =============
# equation number 33
# sub-equation number 0
# \\Pi^{S,P}(Q^2)-\\frac32\\Pi^{V,A}(Q^2)
# ['START', '\\', '\\Pi', '{', 'S', 'P', '}', '(', 'Q', '2', ')', '-', '\\', '\\frac', '3', '2', '\\', '\\Pi', '{', 'V', 'A', '}', '(', 'Q', '2', ')']
# sub-equation number 1
# \\frac{\\alpha_s}{4\\pi}\\frac{\\langleG^2\\rangle}{Q^2}+\\mathcal{O}\\left(\\frac{1}{Q^4}\\right),
# ['START', '\\', '\\frac', '{', '\\', '\\alpha', 's', '}', '{', '4', '\\', '\\pi', '}', '\\', '\\frac', '{', '\\', '\\langleG', '2', '\\', '\\rangle', '}', '{', 'Q', '2', '}', '+', '\\', '\\mathcal', '{', 'O', '}', '\\', '\\left', '(', '\\', '\\frac', '{', '1', '}', '{', 'Q', '4', '}', '\\', '\\right', ')']
# =============
# equation number 34
# sub-equation number 0
#  8 \\pi \\int_0^\\infty (1-\\eta)~b~db/2~~,~~~\\sigma_{\\rm el}
# ['START', '8', '\\', '\\pi', '\\', '\\int', '0', '\\', '\\infty', '(', '1', '-', '\\', '\\eta', ')', 'b', 'd', 'b', '2', '\\', '\\sigma', '{', '\\', '\\rm', 'e', 'l', '}']
# sub-equation number 1
#  8 \\pi \\int_0^\\infty (1 - \\eta)^2~b~db/4~.
# ['START', '8', '\\', '\\pi', '\\', '\\int', '0', '\\', '\\infty', '(', '1', '-', '\\', '\\eta', ')', '2', 'b', 'd', 'b', '4']
# =============
# equation number 35
# sub-equation number 0
# \\min_{L,S} \\frac{1}{2}\\|L+S-Y\\|_F^2 + \\kappa\\|S\\|_1 + \\lambda\\|L\\|_*
# ['START', '\\', '\\min', '{', 'L', 'S', '}', '\\', '\\frac', '{', '1', '}', '{', '2', '}', '\\', '\\', 'L', '+', 'S', '-', 'Y', '\\', '\\', 'F', '2', '+', '\\', '\\kappa', '\\', '\\', 'S', '\\', '\\', '1', '+', '\\', '\\lambda', '\\', '\\', 'L', '\\', '\\', '*']
# sub-equation number 1
#  \\min_{L} \\rho_{\\kappa}(Y-L) + \\lambda \\|L\\|_*.
# ['START', '\\', '\\min', '{', 'L', '}', '\\', '\\rho', '{', '\\', '\\kappa', '}', '(', 'Y', '-', 'L', ')', '+', '\\', '\\lambda', '\\', '\\', 'L', '\\', '\\', '*']
# =============
# equation number 36
# sub-equation number 0
# -{1\\over(4\\pi{\\kappa}^2_{11})^{1/3}}\\int_{\\mathbb{R}^{10}I} G\\wedgeX_7
# ['START', '-', '{', '1', '\\', '\\over', '(', '4', '\\', '\\pi', '{', '\\', '\\kappa', '}', '2', '{', '1', '1', '}', ')', '{', '1', '3', '}', '}', '\\', '\\int', '{', '\\', '\\mathbb', '{', 'R', '}', '{', '1', '0', '}', 'I', '}', 'G', '\\', '\\wedgeX', '7']
# sub-equation number 1
# -{1\\over2(4\\pi{\\kappa}^2_{11})^{1/3}}\\int_{\\mathbb{R}^{10}S^1} G\\wedge X_7,
# ['START', '-', '{', '1', '\\', '\\over', '2', '(', '4', '\\', '\\pi', '{', '\\', '\\kappa', '}', '2', '{', '1', '1', '}', ')', '{', '1', '3', '}', '}', '\\', '\\int', '{', '\\', '\\mathbb', '{', 'R', '}', '{', '1', '0', '}', 'S', '1', '}', 'G', '\\', '\\wedge', 'X', '7']
# =============
# equation number 37
# sub-equation number 0
# \\frac12J_1(h)+I
# ['START', '\\', '\\frac', '1', '2', 'J', '1', '(', 'h', ')', '+', 'I']
# sub-equation number 1
# \\frac12|||h|||^2_{\\Phi_\\gamma}-\\frac12J_2(h)+I\\,.
# ['START', '\\', '\\frac', '1', '2', 'h', '2', '{', '\\', '\\Phi', '\\', '\\gamma', '}', '-', '\\', '\\frac', '1', '2', 'J', '2', '(', 'h', ')', '+', 'I', '\\', '\\']
# =============
# equation number 38
# sub-equation number 0
# \\frac{\\partial}{{\\partial} r} V_W^{+}(r \\rightarrow r'^+,{\\theta},z)- \\frac{\\partial}{{\\partial} r}V_W^{+}(r \\rightarrow r'^-,{\\theta},z)
# ['START', '\\', '\\frac', '{', '\\', '\\partial', '}', '{', '{', '\\', '\\partial', '}', 'r', '}', 'V', 'W', '{', '+', '}', '(', 'r', '\\', '\\rightarrow', 'r', '+', '{', '\\', '\\theta', '}', 'z', ')', '-', '\\', '\\frac', '{', '\\', '\\partial', '}', '{', '{', '\\', '\\partial', '}', 'r', '}', 'V', 'W', '{', '+', '}', '(', 'r', '\\', '\\rightarrow', 'r', '-', '{', '\\', '\\theta', '}', 'z', ')']
# sub-equation number 1
# -\\frac{4\\pi q}{r}{\\delta}({\\theta}-{\\theta}'){\\delta}(z-z') \\, .
# ['START', '-', '\\', '\\frac', '{', '4', '\\', '\\pi', 'q', '}', '{', 'r', '}', '{', '\\', '\\delta', '}', '(', '{', '\\', '\\theta', '}', '-', '{', '\\', '\\theta', '}', ')', '{', '\\', '\\delta', '}', '(', 'z', '-', 'z', ')', '\\', '\\']
# =============
# equation number 39
# sub-equation number 0
# \\sum_{a\\in A-k}\\int_{X^{-1}{{\\cal O}}}\\frac{d\\mu(g)}{|a+g|^2_\\infty}
# ['START', '\\', '\\sum', '{', 'a', '\\', '\\in', 'A', '-', 'k', '}', '\\', '\\int', '{', 'X', '{', '-', '1', '}', '{', '{', '\\', '\\cal', 'O', '}', '}', '}', '\\', '\\frac', '{', 'd', '\\', '\\mu', '(', 'g', ')', '}', '{', 'a', '+', 'g', '2', '\\', '\\infty', '}']
# sub-equation number 1
# \\sum_{a\\in A-k}\\frac{1}{|a|^2_\\infty}\\mu(X^{-1}{{\\cal O}})\\;.
# ['START', '\\', '\\sum', '{', 'a', '\\', '\\in', 'A', '-', 'k', '}', '\\', '\\frac', '{', '1', '}', '{', 'a', '2', '\\', '\\infty', '}', '\\', '\\mu', '(', 'X', '{', '-', '1', '}', '{', '{', '\\', '\\cal', 'O', '}', '}', ')', '\\', '\\']
# =============
# equation number 40
# sub-equation number 0
#  \\frac{u - s^{-1}}{us-1},    w_2
# ['START', '\\', '\\frac', '{', 'u', '-', 's', '{', '-', '1', '}', '}', '{', 'u', 's', '-', '1', '}', 'w', '2']
# sub-equation number 1
#   \\frac{u - s}{us-1},   w_4
# ['START', '\\', '\\frac', '{', 'u', '-', 's', '}', '{', 'u', 's', '-', '1', '}', 'w', '4']
# sub-equation number 2
# \\frac{us^{-1} - 1}{us-1} ,  w_5
# ['START', '\\', '\\frac', '{', 'u', 's', '{', '-', '1', '}', '-', '1', '}', '{', 'u', 's', '-', '1', '}', 'w', '5']
# sub-equation number 3
#  \\frac{(s^2-1)u}{us-1} , w_6
# ['START', '\\', '\\frac', '{', '(', 's', '2', '-', '1', ')', 'u', '}', '{', 'u', 's', '-', '1', '}', 'w', '6']
# sub-equation number 4
# \\frac{1 - s^{-2}}{us-1}.\\end{split}
# ['START', '\\', '\\frac', '{', '1', '-', 's', '{', '-', '2', '}', '}', '{', 'u', 's', '-', '1', '}', '\\', '\\end', '{', 's', 'p', 'l', 'i', 't', '}']
# =============
# equation number 41
# sub-equation number 0
# \\frac{dw_b}{d\\omega}
# ['START', '\\', '\\frac', '{', 'd', 'w', 'b', '}', '{', 'd', '\\', '\\omega', '}']
# sub-equation number 1
# \\frac{4\\alpha}{\\omega(2\\pi)^2}\\int_{}^{}\\left<0|r_1M+r_2{\\bfp}M{\\bfp}|0\\right>d^2p
# ['START', '\\', '\\frac', '{', '4', '\\', '\\alpha', '}', '{', '\\', '\\omega', '(', '2', '\\', '\\pi', ')', '2', '}', '\\', '\\int', '{', '}', '{', '}', '\\', '\\left', '0', 'r', '1', 'M', '+', 'r', '2', '{', '\\', '\\bfp', '}', 'M', '{', '\\', '\\bfp', '}', '0', '\\', '\\right', 'd', '2', 'p']
# =============
# equation number 42
# sub-equation number 0
# {{\\boldsymbol{{Q}}}}(t)+{{\\boldsymbol{{\\xi}}}}_Q,\\hat{{{\\boldsymbol{{E}}}}}(t)
# ['START', '{', '{', '\\', '\\boldsymbol', '{', '{', 'Q', '}', '}', '}', '}', '(', 't', ')', '+', '{', '{', '\\', '\\boldsymbol', '{', '{', '\\', '\\xi', '}', '}', '}', '}', 'Q', '\\', '\\hat', '{', '{', '{', '\\', '\\boldsymbol', '{', '{', 'E', '}', '}', '}', '}', '}', '(', 't', ')']
# sub-equation number 1
# {{\\boldsymbol{{E}}}}(t)+{{\\boldsymbol{{\\xi}}}}_E.
# ['START', '{', '{', '\\', '\\boldsymbol', '{', '{', 'E', '}', '}', '}', '}', '(', 't', ')', '+', '{', '{', '\\', '\\boldsymbol', '{', '{', '\\', '\\xi', '}', '}', '}', '}', 'E']
# =============
# equation number 43
# sub-equation number 0
# \\int {\\rm d}\\hat{\\bf x}\\,    \\big[Y_{\\ell_x}(\\hat{\\bf x}) S_{x}\\big]^\\dag _{j_x m_x} \\,    ({\\bm \\sigma}_2 + {\\bm \\sigma}_3)\\cdot \\hat{\\bf x} \\,    \\big[Y_{\\ell_x^\\prime}(\\hat{\\bf x}) S_{x}^\\prime\\big]_{j_x m_x}
# ['START', '\\', '\\int', '{', '\\', '\\rm', 'd', '}', '\\', '\\hat', '{', '\\', '\\bf', 'x', '}', '\\', '\\', '\\', '\\big', 'Y', '{', '\\', '\\ell', 'x', '}', '(', '\\', '\\hat', '{', '\\', '\\bf', 'x', '}', ')', 'S', '{', 'x', '}', '\\', '\\big', '\\', '\\dag', '{', 'j', 'x', 'm', 'x', '}', '\\', '\\', '(', '{', '\\', '\\bm', '\\', '\\sigma', '}', '2', '+', '{', '\\', '\\bm', '\\', '\\sigma', '}', '3', ')', '\\', '\\cdot', '\\', '\\hat', '{', '\\', '\\bf', 'x', '}', '\\', '\\', '\\', '\\big', 'Y', '{', '\\', '\\ell', 'x', '\\', '\\prime', '}', '(', '\\', '\\hat', '{', '\\', '\\bf', 'x', '}', ')', 'S', '{', 'x', '}', '\\', '\\prime', '\\', '\\big', '{', 'j', 'x', 'm', 'x', '}']
# sub-equation number 1
#    -2\\sqrt{\\frac{j_x+1/2 \\pm 1/2}{2j_x+1}}\\,    \\delta_{\\ell_x,\\, j_x}\\, \\delta_{S_x,1}\\, \\delta_{S^\\prime_x,1}   \\, \\delta_{\\ell_x^\\prime ,\\,j_x\\mp 1}\\ ,
# ['START', '-', '2', '\\', '\\sqrt', '{', '\\', '\\frac', '{', 'j', 'x', '+', '1', '2', '\\', '\\pm', '1', '2', '}', '{', '2', 'j', 'x', '+', '1', '}', '}', '\\', '\\', '\\', '\\delta', '{', '\\', '\\ell', 'x', '\\', '\\', 'j', 'x', '}', '\\', '\\', '\\', '\\delta', '{', 'S', 'x', '1', '}', '\\', '\\', '\\', '\\delta', '{', 'S', '\\', '\\prime', 'x', '1', '}', '\\', '\\', '\\', '\\delta', '{', '\\', '\\ell', 'x', '\\', '\\prime', '\\', '\\', 'j', 'x', '\\', '\\mp', '1', '}', '\\', '\\']
# =============
# equation number 44
# sub-equation number 0
# \\sqrt{2}\\hat{a}_A-\\frac{\\hat{a}^\\dag_{\\rmin}+\\hat{a}^\\dag_B}{\\sqrt{2}},\\hat{a}_B'
# ['START', '\\', '\\sqrt', '{', '2', '}', '\\', '\\hat', '{', 'a', '}', 'A', '-', '\\', '\\frac', '{', '\\', '\\hat', '{', 'a', '}', '\\', '\\dag', '{', '\\', '\\rmin', '}', '+', '\\', '\\hat', '{', 'a', '}', '\\', '\\dag', 'B', '}', '{', '\\', '\\sqrt', '{', '2', '}', '}', '\\', '\\hat', '{', 'a', '}', 'B']
# sub-equation number 1
# \\frac{\\hat{a}_{\\rmin}-\\hat{a}_B}{\\sqrt{2}}.\\setcounter{equation}{8}
# ['START', '\\', '\\frac', '{', '\\', '\\hat', '{', 'a', '}', '{', '\\', '\\rmin', '}', '-', '\\', '\\hat', '{', 'a', '}', 'B', '}', '{', '\\', '\\sqrt', '{', '2', '}', '}', '\\', '\\setcounter', '{', 'e', 'q', 'u', 'a', 't', 'i', 'o', 'n', '}', '{', '8', '}']
# =============
# equation number 45
# sub-equation number 0
# \\widetilde{gr}({\\bf g}_1) - \\widetilde{gr}({\\bf g}_2)
# ['START', '\\', '\\widetilde', '{', 'g', 'r', '}', '(', '{', '\\', '\\bf', 'g', '}', '1', ')', '-', '\\', '\\widetilde', '{', 'g', 'r', '}', '(', '{', '\\', '\\bf', 'g', '}', '2', ')']
# sub-equation number 1
#  \\frac{1}{n}[\\widetilde{gr}(\\widetilde{{\\bf g}}_1) - \\widetilde{gr}(\\widetilde{{\\bf g}}_2)].
# ['START', '\\', '\\frac', '{', '1', '}', '{', 'n', '}', '\\', '\\widetilde', '{', 'g', 'r', '}', '(', '\\', '\\widetilde', '{', '{', '\\', '\\bf', 'g', '}', '}', '1', ')', '-', '\\', '\\widetilde', '{', 'g', 'r', '}', '(', '\\', '\\widetilde', '{', '{', '\\', '\\bf', 'g', '}', '}', '2', ')']
# =============
# equation number 46
# sub-equation number 0
#  \\frac{(1-\\gamma) \\log(Tt^2)}{K(\\theta_a^*-t,\\theta_a^*+\\zeta t)}
# ['START', '\\', '\\frac', '{', '(', '1', '-', '\\', '\\gamma', ')', '\\', '\\log', '(', 'T', 't', '2', ')', '}', '{', 'K', '(', '\\', '\\theta', 'a', '*', '-', 't', '\\', '\\theta', 'a', '*', '+', '\\', '\\zeta', 't', ')', '}']
# sub-equation number 1
#  \\frac{(1-\\gamma) \\log(Tt^2)}{K(\\overline{\\theta}_a,\\theta_a^*+\\zeta t)},
# ['START', '\\', '\\frac', '{', '(', '1', '-', '\\', '\\gamma', ')', '\\', '\\log', '(', 'T', 't', '2', ')', '}', '{', 'K', '(', '\\', '\\overline', '{', '\\', '\\theta', '}', 'a', '\\', '\\theta', 'a', '*', '+', '\\', '\\zeta', 't', ')', '}']
# =============
# equation number 47
# sub-equation number 0
# \\!\\int_0^{+\\infty}\\!\\!\\!(1\\!-\\!\\cos(kb\\zeta))\\frac{d\\zeta}{\\zeta^{3-\\alpha}}
# ['START', '\\', '\\', '\\', '\\int', '0', '{', '+', '\\', '\\infty', '}', '\\', '\\', '\\', '\\', '\\', '\\', '(', '1', '\\', '\\', '-', '\\', '\\', '\\', '\\cos', '(', 'k', 'b', '\\', '\\zeta', ')', ')', '\\', '\\frac', '{', 'd', '\\', '\\zeta', '}', '{', '\\', '\\zeta', '{', '3', '-', '\\', '\\alpha', '}', '}']
# sub-equation number 1
# \\frac{(kb)^2 I^{(1)}}{(1-\\alpha)(2-\\alpha)},
# ['START', '\\', '\\frac', '{', '(', 'k', 'b', ')', '2', 'I', '{', '(', '1', ')', '}', '}', '{', '(', '1', '-', '\\', '\\alpha', ')', '(', '2', '-', '\\', '\\alpha', ')', '}']
# =============
# equation number 48
# sub-equation number 0
# \\frac{\\delta\\Gamma_{eff}}{\\deltaw^+(k_1)\\deltaW^-_{\\mu_2}(k_2)}
# ['START', '\\', '\\frac', '{', '\\', '\\delta', '\\', '\\Gamma', '{', 'e', 'f', 'f', '}', '}', '{', '\\', '\\deltaw', '+', '(', 'k', '1', ')', '\\', '\\deltaW', '-', '{', '\\', '\\mu', '2', '}', '(', 'k', '2', ')', '}']
# sub-equation number 1
# i\\frac{e^4}{(16\\pi^2)^2{s_W}^4}\\frac{{m_H}^2}{{M_W}^3}k_1^{\\mu_2}k_1\\cdotk_1\\Biggl\\{-\\frac{71}{192}+\\frac{11}{288}\\pi^2\\Biggr\\},
# ['STARTi', '\\', '\\frac', '{', 'e', '4', '}', '{', '(', '1', '6', '\\', '\\pi', '2', ')', '2', '{', 's', 'W', '}', '4', '}', '\\', '\\frac', '{', '{', 'm', 'H', '}', '2', '}', '{', '{', 'M', 'W', '}', '3', '}', 'k', '1', '{', '\\', '\\mu', '2', '}', 'k', '1', '\\', '\\cdotk', '1', '\\', '\\Biggl', '\\', '\\', '{', '-', '\\', '\\frac', '{', '7', '1', '}', '{', '1', '9', '2', '}', '+', '\\', '\\frac', '{', '1', '1', '}', '{', '2', '8', '8', '}', '\\', '\\pi', '2', '\\', '\\Biggr', '\\', '\\', '}']
# =============
# equation number 49
# sub-equation number 0
# \\frac{d}{dt} \\frac{\\delta \\mathbb{L}}{\\delta \\dot{\\chi}}
# ['START', '\\', '\\frac', '{', 'd', '}', '{', 'd', 't', '}', '\\', '\\frac', '{', '\\', '\\delta', '\\', '\\mathbb', '{', 'L', '}', '}', '{', '\\', '\\delta', '\\', '\\dot', '{', '\\', '\\chi', '}', '}']
# sub-equation number 1
#  \\frac{\\delta \\mathbb{L}}{\\delta \\chi} \\, ,
# ['START', '\\', '\\frac', '{', '\\', '\\delta', '\\', '\\mathbb', '{', 'L', '}', '}', '{', '\\', '\\delta', '\\', '\\chi', '}', '\\', '\\']
# =============
# equation number 50
# sub-equation number 0
# \\sum_{k}\\theta(n+k,n)\\frac{u^{n+k}}{(n+k)!}
# ['START', '\\', '\\sum', '{', 'k', '}', '\\', '\\theta', '(', 'n', '+', 'k', 'n', ')', '\\', '\\frac', '{', 'u', '{', 'n', '+', 'k', '}', '}', '{', '(', 'n', '+', 'k', ')', '}']
# sub-equation number 1
# \\sum_{k}\\frac{(n+k)!}{(n-1)!}\\delta_k(n+k)\\frac{u^{n+k}}{(n+k)!}
# ['START', '\\', '\\sum', '{', 'k', '}', '\\', '\\frac', '{', '(', 'n', '+', 'k', ')', '}', '{', '(', 'n', '-', '1', ')', '}', '\\', '\\delta', 'k', '(', 'n', '+', 'k', ')', '\\', '\\frac', '{', 'u', '{', 'n', '+', 'k', '}', '}', '{', '(', 'n', '+', 'k', ')', '}']
# sub-equation number 2
# \\frac{1}{n!}\\arg\\tanh^nu,
# ['START', '\\', '\\frac', '{', '1', '}', '{', 'n', '}', '\\', '\\arg', '\\', '\\tanh', 'n', 'u']
# =============
# equation number 51
# sub-equation number 0
# \\sum_{j=1}^{\\infty}\\frac{1}{2j-1}\\left(\\int_{\\gamma_0}\\frac{dp}{\\pi}\\frac{t\\,p}{1+e^{\\epsilon(p)}}\\right)^{2j-1}
# ['START', '\\', '\\sum', '{', 'j', '=', '1', '}', '{', '\\', '\\infty', '}', '\\', '\\frac', '{', '1', '}', '{', '2', 'j', '-', '1', '}', '\\', '\\left', '(', '\\', '\\int', '{', '\\', '\\gamma', '0', '}', '\\', '\\frac', '{', 'd', 'p', '}', '{', '\\', '\\pi', '}', '\\', '\\frac', '{', 't', '\\', '\\', 'p', '}', '{', '1', '+', 'e', '{', '\\', '\\epsilon', '(', 'p', ')', '}', '}', '\\', '\\right', ')', '{', '2', 'j', '-', '1', '}']
# sub-equation number 1
# \\ln\\sqrt{{\\frac{1+A_0}{1-A_0}}},\\end{split}
# ['START', '\\', '\\ln', '\\', '\\sqrt', '{', '{', '\\', '\\frac', '{', '1', '+', 'A', '0', '}', '{', '1', '-', 'A', '0', '}', '}', '}', '\\', '\\end', '{', 's', 'p', 'l', 'i', 't', '}']
# =============
# equation number 52
# sub-equation number 0
# {\\refstepcounter{equ}}\\forall{\\alpha} \\in R_\\mathrm{max}\\ \\exists{\\beta},{\\gamma}\\in R\\setminus R_\\mathrm{max}:{\\alpha}
# ['START', '{', '\\', '\\refstepcounter', '{', 'e', 'q', 'u', '}', '}', '\\', '\\forall', '{', '\\', '\\alpha', '}', '\\', '\\in', 'R', '\\', '\\mathrm', '{', 'm', 'a', 'x', '}', '\\', '\\', '\\', '\\exists', '{', '\\', '\\beta', '}', '{', '\\', '\\gamma', '}', '\\', '\\in', 'R', '\\', '\\setminus', 'R', '\\', '\\mathrm', '{', 'm', 'a', 'x', '}', '{', '\\', '\\alpha', '}']
# sub-equation number 1
# {\\beta}+{\\gamma},
# ['START', '{', '\\', '\\beta', '}', '+', '{', '\\', '\\gamma', '}']
# =============
# equation number 53
# sub-equation number 0
# \\int^\\infty_0\\!\\!\\!\\omega S(\\omega){\\mathrm{d}}\\omega
# ['START', '\\', '\\int', '\\', '\\infty', '0', '\\', '\\', '\\', '\\', '\\', '\\', '\\', '\\omega', 'S', '(', '\\', '\\omega', ')', '{', '\\', '\\mathrm', '{', 'd', '}', '}', '\\', '\\omega']
# sub-equation number 1
# \\frac{\\pi}{2}\\\n\\text{and}\\ \\int^\\infty_0\\!\\!\\!\\omega^3S(\\omega){\\mathrm{d}}\\omega
# ['START', '\\', '\\frac', '{', '\\', '\\pi', '}', '{', '2', '}', '\\', '\\', '\\n', '\\', '\\text', '{', 'a', 'n', 'd', '}', '\\', '\\', '\\', '\\int', '\\', '\\infty', '0', '\\', '\\', '\\', '\\', '\\', '\\', '\\', '\\omega', '3', 'S', '(', '\\', '\\omega', ')', '{', '\\', '\\mathrm', '{', 'd', '}', '}', '\\', '\\omega']
# sub-equation number 2
# \\frac{\\pi}{2}\\omega^2_R \\,,
# ['START', '\\', '\\frac', '{', '\\', '\\pi', '}', '{', '2', '}', '\\', '\\omega', '2', 'R', '\\', '\\']
# =============
# equation number 54
# sub-equation number 0
#   \\frac{|1+\\dot{\\xi }_1|\\,|1+\\dot{\\xi }_2|-(1+\\dot{\\xi }_1\\cdot \\dot{\\xi }_2)}{\\left(t_1-t_2\\right)^2+\\left(\\xi _1-\\xi _2\\right)^2}
# ['START', '\\', '\\frac', '{', '1', '+', '\\', '\\dot', '{', '\\', '\\xi', '}', '1', '\\', '\\', '1', '+', '\\', '\\dot', '{', '\\', '\\xi', '}', '2', '-', '(', '1', '+', '\\', '\\dot', '{', '\\', '\\xi', '}', '1', '\\', '\\cdot', '\\', '\\dot', '{', '\\', '\\xi', '}', '2', ')', '}', '{', '\\', '\\left', '(', 't', '1', '-', 't', '2', '\\', '\\right', ')', '2', '+', '\\', '\\left', '(', '\\', '\\xi', '1', '-', '\\', '\\xi', '2', '\\', '\\right', ')', '2', '}']
# sub-equation number 1
#   \\frac{\\frac{1}{2}\\left(\\dot{\\xi }(t_1)-\\dot{\\xi }(t_2)\\right)^2}{\\left(t_1-t_2\\right)^2}  +\\mathcal{O}\\left(\\xi ^4\\right),
# ['START', '\\', '\\frac', '{', '\\', '\\frac', '{', '1', '}', '{', '2', '}', '\\', '\\left', '(', '\\', '\\dot', '{', '\\', '\\xi', '}', '(', 't', '1', ')', '-', '\\', '\\dot', '{', '\\', '\\xi', '}', '(', 't', '2', ')', '\\', '\\right', ')', '2', '}', '{', '\\', '\\left', '(', 't', '1', '-', 't', '2', '\\', '\\right', ')', '2', '}', '+', '\\', '\\mathcal', '{', 'O', '}', '\\', '\\left', '(', '\\', '\\xi', '4', '\\', '\\right', ')']
# =============
# equation number 55
# sub-equation number 0
# \\frac{dh}{d\\mu}
# ['START', '\\', '\\frac', '{', 'd', 'h', '}', '{', 'd', '\\', '\\mu', '}']
# sub-equation number 1
#  - \\frac{n_0 \\Delta x}{\\Delta M}.
# ['START', '-', '\\', '\\frac', '{', 'n', '0', '\\', '\\Delta', 'x', '}', '{', '\\', '\\Delta', 'M', '}']
# =============
# equation number 56
# sub-equation number 0
# \\mu_0^2-\\mu_1^2
# ['START', '\\', '\\mu', '0', '2', '-', '\\', '\\mu', '1', '2']
# sub-equation number 1
# 4q(q-1)-4p(p+1),
# ['START', '4', 'q', '(', 'q', '-', '1', ')', '-', '4', 'p', '(', 'p', '+', '1', ')']
# =============
# equation number 57
# sub-equation number 0
# \\tfrac{g_0}{\\log^2q},{\\widetilde}{a}_{0,1}
# ['START', '\\', '\\tfrac', '{', 'g', '0', '}', '{', '\\', '\\log', '2', 'q', '}', '{', '\\', '\\widetilde', '}', '{', 'a', '}', '{', '0', '1', '}']
# sub-equation number 1
# \\tfrac{h_{0,0}}{\\log^2q},{\\widetilde}{a}_{0,0}
# ['START', '\\', '\\tfrac', '{', 'h', '{', '0', '0', '}', '}', '{', '\\', '\\log', '2', 'q', '}', '{', '\\', '\\widetilde', '}', '{', 'a', '}', '{', '0', '0', '}']
# sub-equation number 2
# \\tfrac{c_{0,0}}{\\log^2q},
# ['START', '\\', '\\tfrac', '{', 'c', '{', '0', '0', '}', '}', '{', '\\', '\\log', '2', 'q', '}']
# =============
# equation number 58
# sub-equation number 0
# UV^*+\\Psi_0
# ['STARTUV', '*', '+', '\\', '\\Psi', '0']
# sub-equation number 1
# K_iU_oV^*+\\Psi_0
# ['STARTK', 'i', 'U', 'o', 'V', '*', '+', '\\', '\\Psi', '0']
# =============
# equation number 59
# sub-equation number 0
#  \\sum_{i=1}^{2n-1}e_i + e_{2n,1},\\Lambda_2
# ['START', '\\', '\\sum', '{', 'i', '=', '1', '}', '{', '2', 'n', '-', '1', '}', 'e', 'i', '+', 'e', '{', '2', 'n', '1', '}', '\\', '\\Lambda', '2']
# sub-equation number 1
#  \\sum_{i=1}^{2n-2}e_{i,1} + e_{2n-1,2} + e_{2n,2}.
# ['START', '\\', '\\sum', '{', 'i', '=', '1', '}', '{', '2', 'n', '-', '2', '}', 'e', '{', 'i', '1', '}', '+', 'e', '{', '2', 'n', '-', '1', '2', '}', '+', 'e', '{', '2', 'n', '2', '}']
# =============
# equation number 60
# sub-equation number 0
# \\frac{1}{2}\\Theta_1^q(t),\\;\\;A_{22}(t)
# ['START', '\\', '\\frac', '{', '1', '}', '{', '2', '}', '\\', '\\Theta', '1', 'q', '(', 't', ')', '\\', '\\', '\\', '\\', 'A', '{', '2', '2', '}', '(', 't', ')']
# sub-equation number 1
# -\\frac{1}{2}\\Theta_2^q(t),
# ['START', '-', '\\', '\\frac', '{', '1', '}', '{', '2', '}', '\\', '\\Theta', '2', 'q', '(', 't', ')']
# =============
# equation number 61
# sub-equation number 0
# \\mathop{\\min_{y^{*}x\\neq 0}}_{y=(VV^{*})^{-1}x}\\frac{y^{*}Ax}{y^{*}x}
# ['START', '\\', '\\mathop', '{', '\\', '\\min', '{', 'y', '{', '*', '}', 'x', '\\', '\\neq', '0', '}', '}', '{', 'y', '=', '(', 'V', 'V', '{', '*', '}', ')', '{', '-', '1', '}', 'x', '}', '\\', '\\frac', '{', 'y', '{', '*', '}', 'A', 'x', '}', '{', 'y', '{', '*', '}', 'x', '}']
# sub-equation number 1
# \\lambda_{1}\\mbox{and}\\mathop{\\max_{y^{*}x\\neq 0}}_{y=(VV^{*})^{-1}x}\\frac{y^{*}Ax}{y^{*}x}
# ['START', '\\', '\\lambda', '{', '1', '}', '\\', '\\mbox', '{', 'a', 'n', 'd', '}', '\\', '\\mathop', '{', '\\', '\\max', '{', 'y', '{', '*', '}', 'x', '\\', '\\neq', '0', '}', '}', '{', 'y', '=', '(', 'V', 'V', '{', '*', '}', ')', '{', '-', '1', '}', 'x', '}', '\\', '\\frac', '{', 'y', '{', '*', '}', 'A', 'x', '}', '{', 'y', '{', '*', '}', 'x', '}']
# =============
# equation number 62
# sub-equation number 0
# \\frac{\\sqrt{D(\\nu_n)D(-\\nu_n)}}{\\sqrt{1+D(\\nu_n)+D(-\\nu_n)}}
# ['START', '\\', '\\frac', '{', '\\', '\\sqrt', '{', 'D', '(', '\\', '\\nu', 'n', ')', 'D', '(', '-', '\\', '\\nu', 'n', ')', '}', '}', '{', '\\', '\\sqrt', '{', '1', '+', 'D', '(', '\\', '\\nu', 'n', ')', '+', 'D', '(', '-', '\\', '\\nu', 'n', ')', '}', '}']
# sub-equation number 1
# {\\sqrt{D(\\nu_n)D(-\\nu_n)}}-\\frac{1}{2}\\frac{\\sqrt{D(\\nu_n)D(-\\nu_n)}}{(2i\\nu_n)^{N+1}}
# ['START', '{', '\\', '\\sqrt', '{', 'D', '(', '\\', '\\nu', 'n', ')', 'D', '(', '-', '\\', '\\nu', 'n', ')', '}', '}', '-', '\\', '\\frac', '{', '1', '}', '{', '2', '}', '\\', '\\frac', '{', '\\', '\\sqrt', '{', 'D', '(', '\\', '\\nu', 'n', ')', 'D', '(', '-', '\\', '\\nu', 'n', ')', '}', '}', '{', '(', '2', 'i', '\\', '\\nu', 'n', ')', '{', 'N', '+', '1', '}', '}']
# =============
# equation number 63
# sub-equation number 0
#  {\\label}{bb68} \\begin{aligned}  -\\frac{1}{2} \\int (e+|u|^2)\\ln (e+|u|^2)G dx\\\\&
# ...
# =============
# equation number 381
# sub-equation number 0
# \\frac{1}{B}(\\nabla A\\cdot \\nabla)\\psi, \\psi_{s}
# ['START', '\\', '\\frac', '{', '1', '}', '{', 'B', '}', '(', '\\', '\\nabla', 'A', '\\', '\\cdot', '\\', '\\nabla', ')', '\\', '\\psi', '\\', '\\psi', '{', 's', '}']
# sub-equation number 1
# \\frac{1}{B}(\\mathbf{B}\\cdot \\nabla)\\psi,\\\\\n\\\\\n\\chi_{a}
# ['START', '\\', '\\frac', '{', '1', '}', '{', 'B', '}', '(', '\\', '\\mathbf', '{', 'B', '}', '\\', '\\cdot', '\\', '\\nabla', ')', '\\', '\\psi', '\\', '\\', '\\', '\\', '\\n', '\\', '\\', '\\', '\\', '\\n', '\\', '\\chi', '{', 'a', '}']
# sub-equation number 2
# \\frac{1}{B}(\\nabla A\\cdot \\nabla)\\chi, \\chi_{s}
# ['START', '\\', '\\frac', '{', '1', '}', '{', 'B', '}', '(', '\\', '\\nabla', 'A', '\\', '\\cdot', '\\', '\\nabla', ')', '\\', '\\chi', '\\', '\\chi', '{', 's', '}']
# sub-equation number 3
# \\frac{1}{B}(\\mathbf{B}\\cdot \\nabla)\\chi,\\\\\n\\\\\nB_{a}
# ['START', '\\', '\\frac', '{', '1', '}', '{', 'B', '}', '(', '\\', '\\mathbf', '{', 'B', '}', '\\', '\\cdot', '\\', '\\nabla', ')', '\\', '\\chi', '\\', '\\', '\\', '\\', '\\n', '\\', '\\', '\\', '\\', '\\nB', '{', 'a', '}']
# =============
# equation number 382
# sub-equation number 0
#  \\frac{\\delta^2 \\mu_{i}^0 + n_i^t m_i}{\\delta^2+n_{i}^t} \\; \\text{and}\\;\\text{Var}[\\mu_{i}^t|n_i^t]
# ['START', '\\', '\\frac', '{', '\\', '\\delta', '2', '\\', '\\mu', '{', 'i', '}', '0', '+', 'n', 'i', 't', 'm', 'i', '}', '{', '\\', '\\delta', '2', '+', 'n', '{', 'i', '}', 't', '}', '\\', '\\', '\\', '\\text', '{', 'a', 'n', 'd', '}', '\\', '\\', '\\', '\\text', '{', 'V', 'a', 'r', '}', '\\', '\\mu', '{', 'i', '}', 't', 'n', 'i', 't']
# sub-equation number 1
#  \\frac{ n_i^t \\sigma_s^2}{(\\delta^2+n_{i}^t)^2}.
# ['START', '\\', '\\frac', '{', 'n', 'i', 't', '\\', '\\sigma', 's', '2', '}', '{', '(', '\\', '\\delta', '2', '+', 'n', '{', 'i', '}', 't', ')', '2', '}']
# =============
# equation number 383
# sub-equation number 0
# \\frac{d}{dt}+A(t),\\text{ i.e. } (D_A u)(t)
# ['START', '\\', '\\frac', '{', 'd', '}', '{', 'd', 't', '}', '+', 'A', '(', 't', ')', '\\', '\\text', '{', 'i', 'e', '}', '(', 'D', 'A', 'u', ')', '(', 't', ')']
# sub-equation number 1
# \\frac{du(t)}{dt}+A(t)u(t).
# ['START', '\\', '\\frac', '{', 'd', 'u', '(', 't', ')', '}', '{', 'd', 't', '}', '+', 'A', '(', 't', ')', 'u', '(', 't', ')']
# =============
# equation number 384
# sub-equation number 0
# 1_B \\bigoplus_{i=1}^n\\bigoplus_{j=1}^m \\tilde A_{ij} (1-1_B)
# ['START', '1', 'B', '\\', '\\bigoplus', '{', 'i', '=', '1', '}', 'n', '\\', '\\bigoplus', '{', 'j', '=', '1', '}', 'm', '\\', '\\tilde', 'A', '{', 'i', 'j', '}', '(', '1', '-', '1', 'B', ')']
# sub-equation number 1
#  \\bigoplus_{j=1}^m J^{10}_{*j}
# ['START', '\\', '\\bigoplus', '{', 'j', '=', '1', '}', 'm', 'J', '{', '1', '0', '}', '{', '*', 'j', '}']
# =============
# equation number 385
# sub-equation number 0
#   \\frac{\\partial y}{\\partial t}
# ['START', '\\', '\\frac', '{', '\\', '\\partial', 'y', '}', '{', '\\', '\\partial', 't', '}']
# sub-equation number 1
# -\\frac{\\partial V(y;c)}{\\partial t}, y \\in R^k, c \\in R^p,
# ['START', '-', '\\', '\\frac', '{', '\\', '\\partial', 'V', '(', 'y', 'c', ')', '}', '{', '\\', '\\partial', 't', '}', 'y', '\\', '\\in', 'R', 'k', 'c', '\\', '\\in', 'R', 'p']
# =============
# equation number 386
# sub-equation number 0
#  \\int_{E_i} \\kappa^{-1} (v\\cdot m_i) (w\\cdot m_i),s_i(v,w)
# ['START', '\\', '\\int', '{', 'E', 'i', '}', '\\', '\\kappa', '{', '-', '1', '}', '(', 'v', '\\', '\\cdot', 'm', 'i', ')', '(', 'w', '\\', '\\cdot', 'm', 'i', ')', 's', 'i', '(', 'v', 'w', ')']
# sub-equation number 1
#  \\int_{\\omega_i} \\kappa^{-1} v\\cdot w + \\int_{\\omega_i} \\text{div}(v) \\, \\text{div}(w),
# ['START', '\\', '\\int', '{', '\\', '\\omega', 'i', '}', '\\', '\\kappa', '{', '-', '1', '}', 'v', '\\', '\\cdot', 'w', '+', '\\', '\\int', '{', '\\', '\\omega', 'i', '}', '\\', '\\text', '{', 'd', 'i', 'v', '}', '(', 'v', ')', '\\', '\\', '\\', '\\text', '{', 'd', 'i', 'v', '}', '(', 'w', ')']
# =============
# equation number 387
# sub-equation number 0
#   \\frac{1}{\\tilde{\\tau}_{6\\nu\\kappa}}
# ['START', '\\', '\\frac', '{', '1', '}', '{', '\\', '\\tilde', '{', '\\', '\\tau', '}', '{', '6', '\\', '\\nu', '\\', '\\kappa', '}', '}']
# sub-equation number 1
#  C_6 +  \\frac{C_{\\nu\\kappa}}{\\mbox{\\rm Re}},    \\frac{1}{\\tilde{\\tau}_{7\\kappa\\kappa}}
# ['START', 'C', '6', '+', '\\', '\\frac', '{', 'C', '{', '\\', '\\nu', '\\', '\\kappa', '}', '}', '{', '\\', '\\mbox', '{', '\\', '\\rm', 'R', 'e', '}', '}', '\\', '\\frac', '{', '1', '}', '{', '\\', '\\tilde', '{', '\\', '\\tau', '}', '{', '7', '\\', '\\kappa', '\\', '\\kappa', '}', '}']
# sub-equation number 2
#  C_7  + \\frac{C_{\\kappa\\kappa}}{\\mbox{\\rm Pe}}.
# ['START', 'C', '7', '+', '\\', '\\frac', '{', 'C', '{', '\\', '\\kappa', '\\', '\\kappa', '}', '}', '{', '\\', '\\mbox', '{', '\\', '\\rm', 'P', 'e', '}', '}']
# =============
# equation number 388
# sub-equation number 0
# E_J \\frac{d^3{\\hat \\sigma}^B_{gg \\rightarrow q {\\bar q}}}{d^3p_J}\\equiv \\sigma^B_{gg \\rightarrow q {\\bar q}} \\delta(s_4)
# ['STARTE', 'J', '\\', '\\frac', '{', 'd', '3', '{', '\\', '\\hat', '\\', '\\sigma', '}', 'B', '{', 'g', 'g', '\\', '\\rightarrow', 'q', '{', '\\', '\\bar', 'q', '}', '}', '}', '{', 'd', '3', 'p', 'J', '}', '\\', '\\equiv', '\\', '\\sigma', 'B', '{', 'g', 'g', '\\', '\\rightarrow', 'q', '{', '\\', '\\bar', 'q', '}', '}', '\\', '\\delta', '(', 's', '4', ')']
# sub-equation number 1
# \\alpha_s^2 \\frac{N_c}{(N_c^2-1)\\, s} \\left[\\frac{(N_c^2-1)}{2N_c^2}\\frac{(t^2+u^2)}{tu}-1+2\\frac{tu}{s^2}\\right]  \\delta(s_4) \\, .
# ['START', '\\', '\\alpha', 's', '2', '\\', '\\frac', '{', 'N', 'c', '}', '{', '(', 'N', 'c', '2', '-', '1', ')', '\\', '\\', 's', '}', '\\', '\\left', '\\', '\\frac', '{', '(', 'N', 'c', '2', '-', '1', ')', '}', '{', '2', 'N', 'c', '2', '}', '\\', '\\frac', '{', '(', 't', '2', '+', 'u', '2', ')', '}', '{', 't', 'u', '}', '-', '1', '+', '2', '\\', '\\frac', '{', 't', 'u', '}', '{', 's', '2', '}', '\\', '\\right', '\\', '\\delta', '(', 's', '4', ')', '\\', '\\']
# =============
# equation number 389
# sub-equation number 0
#  \\frac{3}{4} \\; ,  \\mu_2(n,l)
# ['START', '\\', '\\frac', '{', '3', '}', '{', '4', '}', '\\', '\\', '\\', '\\mu', '2', '(', 'n', 'l', ')']
# sub-equation number 1
#  \\frac{3}{4} +\\Delta(n,l) \\; , \\Delta(n,l) \\equiv \\frac{1}{8} - \\frac{5\\alpha_{nl}}{72\\gamma_{nl}^2} \\; ,
# ['START', '\\', '\\frac', '{', '3', '}', '{', '4', '}', '+', '\\', '\\Delta', '(', 'n', 'l', ')', '\\', '\\', '\\', '\\Delta', '(', 'n', 'l', ')', '\\', '\\equiv', '\\', '\\frac', '{', '1', '}', '{', '8', '}', '-', '\\', '\\frac', '{', '5', '\\', '\\alpha', '{', 'n', 'l', '}', '}', '{', '7', '2', '\\', '\\gamma', '{', 'n', 'l', '}', '2', '}', '\\', '\\']
# =============
# equation number 390
# sub-equation number 0
# \\frac{t_\\eta}{t_{Ap}}
# ['START', '\\', '\\frac', '{', 't', '\\', '\\eta', '}', '{', 't', '{', 'A', 'p', '}', '}']
# sub-equation number 1
# \\frac{R \\, B_0}{\\eta\\sqrt{4\\pi\\rho_0}}\\ \\ \\ .
# ['START', '\\', '\\frac', '{', 'R', '\\', '\\', 'B', '0', '}', '{', '\\', '\\eta', '\\', '\\sqrt', '{', '4', '\\', '\\pi', '\\', '\\rho', '0', '}', '}', '\\', '\\', '\\', '\\', '\\', '\\']
# =============
# equation number 391
# sub-equation number 0
# -\\frac{i}{4\\sqrt{3}}\\frac{M^+_{111}}{N}+\\frac{1}{\\sqrt{3}}\\frac{d\\epsilon_{o}}{N},\\,\\,\\,\\,b_X
# ['START', '-', '\\', '\\frac', '{', 'i', '}', '{', '4', '\\', '\\sqrt', '{', '3', '}', '}', '\\', '\\frac', '{', 'M', '+', '{', '1', '1', '1', '}', '}', '{', 'N', '}', '+', '\\', '\\frac', '{', '1', '}', '{', '\\', '\\sqrt', '{', '3', '}', '}', '\\', '\\frac', '{', 'd', '\\', '\\epsilon', '{', 'o', '}', '}', '{', 'N', '}', '\\', '\\', '\\', '\\', '\\', '\\', '\\', '\\', 'b', 'X']
# sub-equation number 1
# -\\frac{1}{4\\sqrt{3}}\\frac{M^+_{111}}{N},
# ['START', '-', '\\', '\\frac', '{', '1', '}', '{', '4', '\\', '\\sqrt', '{', '3', '}', '}', '\\', '\\frac', '{', 'M', '+', '{', '1', '1', '1', '}', '}', '{', 'N', '}']
# =============
# equation number 392
# sub-equation number 0
#  \\frac{\\hat{\\lambda}^{(T,R)} - \\hat{\\kappa}^{(T,R)}}{|\\hat{\\lambda}'^{(T,R)}|}
# ['START', '\\', '\\frac', '{', '\\', '\\hat', '{', '\\', '\\lambda', '}', '{', '(', 'T', 'R', ')', '}', '-', '\\', '\\hat', '{', '\\', '\\kappa', '}', '{', '(', 'T', 'R', ')', '}', '}', '{', '\\', '\\hat', '{', '\\', '\\lambda', '}', '{', '(', 'T', 'R', ')', '}', '}']
# sub-equation number 1
#  \\frac{\\langle      \\hat{\\lambda}^{(T)}_r - \\hat{\\kappa}^{(T)}_r\\rangle_{r=1}^{R}}{\\langle |\\hat{\\lambda}'^{(T)}_r|\\rangle_{r=1}^{R}},
# ['START', '\\', '\\frac', '{', '\\', '\\langle', '\\', '\\hat', '{', '\\', '\\lambda', '}', '{', '(', 'T', ')', '}', 'r', '-', '\\', '\\hat', '{', '\\', '\\kappa', '}', '{', '(', 'T', ')', '}', 'r', '\\', '\\rangle', '{', 'r', '=', '1', '}', '{', 'R', '}', '}', '{', '\\', '\\langle', '\\', '\\hat', '{', '\\', '\\lambda', '}', '{', '(', 'T', ')', '}', 'r', '\\', '\\rangle', '{', 'r', '=', '1', '}', '{', 'R', '}', '}']
# =============
# equation number 393
# sub-equation number 0
# -\\frac{3\\lambda(0)(1+20\\omega_1^2)}{4\\omega_1(1+\\lambda(0)\\beta_2t')(-1+30\\omega_1+6\\beta_2\\omega_1+40\\omega_1^2)}+\\tilde\\Lambda_0(1+\\lambda(0)\\beta_2 t')^{W/\\beta_2}\\,,W
# ['START', '-', '\\', '\\frac', '{', '3', '\\', '\\lambda', '(', '0', ')', '(', '1', '+', '2', '0', '\\', '\\omega', '1', '2', ')', '}', '{', '4', '\\', '\\omega', '1', '(', '1', '+', '\\', '\\lambda', '(', '0', ')', '\\', '\\beta', '2', 't', ')', '(', '-', '1', '+', '3', '0', '\\', '\\omega', '1', '+', '6', '\\', '\\beta', '2', '\\', '\\omega', '1', '+', '4', '0', '\\', '\\omega', '1', '2', ')', '}', '+', '\\', '\\tilde', '\\', '\\Lambda', '0', '(', '1', '+', '\\', '\\lambda', '(', '0', ')', '\\', '\\beta', '2', 't', ')', '{', 'W', '\\', '\\beta', '2', '}', '\\', '\\', 'W']
# sub-equation number 1
# \\frac{20}{3}\\omega_1+5-\\frac{1}{6\\omega_1}
# ['START', '\\', '\\frac', '{', '2', '0', '}', '{', '3', '}', '\\', '\\omega', '1', '+', '5', '-', '\\', '\\frac', '{', '1', '}', '{', '6', '\\', '\\omega', '1', '}']
# =============
# equation number 394
# sub-equation number 0
# \\frac{d}{dt}\\rho_n
# ['START', '\\', '\\frac', '{', 'd', '}', '{', 'd', 't', '}', '\\', '\\rho', 'n']
# sub-equation number 1
# \\frac{\\gamma}{\\rho_n}\\,\\left(\\frac{R_{n+1}-R_{n}}{\\Delta_{n}}-\\frac{R_{n}-R_{n-1}}{\\Delta_{n-1}}\\right)\\/,\\mbox{for}\\;\\;2\\leqn\\leqN-1\\/,
# ['START', '\\', '\\frac', '{', '\\', '\\gamma', '}', '{', '\\', '\\rho', 'n', '}', '\\', '\\', '\\', '\\left', '(', '\\', '\\frac', '{', 'R', '{', 'n', '+', '1', '}', '-', 'R', '{', 'n', '}', '}', '{', '\\', '\\Delta', '{', 'n', '}', '}', '-', '\\', '\\frac', '{', 'R', '{', 'n', '}', '-', 'R', '{', 'n', '-', '1', '}', '}', '{', '\\', '\\Delta', '{', 'n', '-', '1', '}', '}', '\\', '\\right', ')', '\\', '\\', '\\', '\\mbox', '{', 'f', 'o', 'r', '}', '\\', '\\', '\\', '\\', '2', '\\', '\\leqn', '\\', '\\leqN', '-', '1', '\\', '\\']
# =============
# equation number 395
# sub-equation number 0
# cU_x + V_x + f(U)
# ['STARTcU', 'x', '+', 'V', 'x', '+', 'f', '(', 'U', ')']
# sub-equation number 1
#  0,U_x + c\\tau V_x - V
# ['START', '0', 'U', 'x', '+', 'c', '\\', '\\tau', 'V', 'x', '-', 'V']
# =============
# equation number 396
# sub-equation number 0
# \\Gamma[f_1,f_2] + \\eta[f_1]\\eta[f_2],\\\\\n S_3[f_1,f_2,f_3]
# ['START', '\\', '\\Gamma', 'f', '1', 'f', '2', '+', '\\', '\\eta', 'f', '1', '\\', '\\eta', 'f', '2', '\\', '\\', '\\', '\\', '\\n', 'S', '3', 'f', '1', 'f', '2', 'f', '3']
# sub-equation number 1
# \\Gamma[f_1,f_2]\\eta[f_3] +   \\Gamma[f_3,f_1] \\eta[f_2] +   \\Gamma[f_2,f_3] \\eta[f_1]+  \\eta[f_1] \\eta[z_2] \\eta[f_3],\\\\\n S_4[f_1,f_2,f_3,f_4]
# ['START', '\\', '\\Gamma', 'f', '1', 'f', '2', '\\', '\\eta', 'f', '3', '+', '\\', '\\Gamma', 'f', '3', 'f', '1', '\\', '\\eta', 'f', '2', '+', '\\', '\\Gamma', 'f', '2', 'f', '3', '\\', '\\eta', 'f', '1', '+', '\\', '\\eta', 'f', '1', '\\', '\\eta', 'z', '2', '\\', '\\eta', 'f', '3', '\\', '\\', '\\', '\\', '\\n', 'S', '4', 'f', '1', 'f', '2', 'f', '3', 'f', '4']
# sub-equation number 2
#  \\Gamma[f_1,f_2]\\Gamma[f_3,f_4]+\\Gamma[f_1,f_3]\\Gamma[f_2,f_4]+\\Gamma[f_1,f_4]\\Gamma[f_2,f_3] +\\\\+ \\Gamma[f_1,f_2]\\eta[f_3]\\eta[f_4]+\\Gamma[f_1,f_3]\\eta[f_2]\\eta[f_4]+\\Gamma[f_1,f_4]\\eta[f_2]\\eta[f_3] +\\\\+ \\eta[f_1]\\eta[f_2]\\eta[f_3]\\eta[f_4].  \\end{split}
# ['START', '\\', '\\Gamma', 'f', '1', 'f', '2', '\\', '\\Gamma', 'f', '3', 'f', '4', '+', '\\', '\\Gamma', 'f', '1', 'f', '3', '\\', '\\Gamma', 'f', '2', 'f', '4', '+', '\\', '\\Gamma', 'f', '1', 'f', '4', '\\', '\\Gamma', 'f', '2', 'f', '3', '+', '\\', '\\', '\\', '\\', '+', '\\', '\\Gamma', 'f', '1', 'f', '2', '\\', '\\eta', 'f', '3', '\\', '\\eta', 'f', '4', '+', '\\', '\\Gamma', 'f', '1', 'f', '3', '\\', '\\eta', 'f', '2', '\\', '\\eta', 'f', '4', '+', '\\', '\\Gamma', 'f', '1', 'f', '4', '\\', '\\eta', 'f', '2', '\\', '\\eta', 'f', '3', '+', '\\', '\\', '\\', '\\', '+', '\\', '\\eta', 'f', '1', '\\', '\\eta', 'f', '2', '\\', '\\eta', 'f', '3', '\\', '\\eta', 'f', '4', '\\', '\\end', '{', 's', 'p', 'l', 'i', 't', '}']
# =============
# equation number 397
# sub-equation number 0
# \\begin{split}\\int d\\bm{q}_T \\frac{q_T^2}{4M_N^2} F_{TT}^{\\cos(\\phi_a + \\phi_b)}  \\\\\n
# ['START', '\\', '\\begin', '{', 's', 'p', 'l', 'i', 't', '}', '\\', '\\int', 'd', '\\', '\\bm', '{', 'q', '}', 'T', '\\', '\\frac', '{', 'q', 'T', '2', '}', '{', '4', 'M', 'N', '2', '}', 'F', '{', 'T', 'T', '}', '{', '\\', '\\cos', '(', '\\', '\\phi', 'a', '+', '\\', '\\phi', 'b', ')', '}', '\\', '\\', '\\', '\\', '\\n']
# sub-equation number 1
# \\frac{1}{N_c} \\sum_{q} e_q^2 \\big[f_{1T}^{\\perp(1)q}(x_a) f_{1T}^{\\perp(1)q}(x_b) - g_{1T}^{(1)q}(x_a) g_{1T}^{(1)q}(x_b)\\big],\\end{split}
# ['START', '\\', '\\frac', '{', '1', '}', '{', 'N', 'c', '}', '\\', '\\sum', '{', 'q', '}', 'e', 'q', '2', '\\', '\\big', 'f', '{', '1', 'T', '}', '{', '\\', '\\perp', '(', '1', ')', 'q', '}', '(', 'x', 'a', ')', 'f', '{', '1', 'T', '}', '{', '\\', '\\perp', '(', '1', ')', 'q', '}', '(', 'x', 'b', ')', '-', 'g', '{', '1', 'T', '}', '{', '(', '1', ')', 'q', '}', '(', 'x', 'a', ')', 'g', '{', '1', 'T', '}', '{', '(', '1', ')', 'q', '}', '(', 'x', 'b', ')', '\\', '\\big', '\\', '\\end', '{', 's', 'p', 'l', 'i', 't', '}']
# =============
# equation number 398
# sub-equation number 0
#  {\\mathbf{e_1}} A_{{\\widehat{1}}} + {\\mathbf{e_2}} A_{{\\widehat{2}}}
# ['START', '{', '\\', '\\mathbf', '{', 'e', '1', '}', '}', 'A', '{', '{', '\\', '\\widehat', '{', '1', '}', '}', '}', '+', '{', '\\', '\\mathbf', '{', 'e', '2', '}', '}', 'A', '{', '{', '\\', '\\widehat', '{', '2', '}', '}', '}']
# sub-equation number 1
#  {\\mathbf{e_1}} P_1(A) + {\\mathbf{e_2}} P_2(A) ,
# ['START', '{', '\\', '\\mathbf', '{', 'e', '1', '}', '}', 'P', '1', '(', 'A', ')', '+', '{', '\\', '\\mathbf', '{', 'e', '2', '}', '}', 'P', '2', '(', 'A', ')']
# =============
# equation number 399
# sub-equation number 0
# \\frac{y}{\\varepsilon(s)},\\varepsilon(s):
# ['START', '\\', '\\frac', '{', 'y', '}', '{', '\\', '\\varepsilon', '(', 's', ')', '}', '\\', '\\varepsilon', '(', 's', ')']
# sub-equation number 1
# \\frac{1}{\\lvert\\partial_{y}f(0,s)\\rvert},
# ['START', '\\', '\\frac', '{', '1', '}', '{', '\\', '\\lvert', '\\', '\\partial', '{', 'y', '}', 'f', '(', '0', 's', ')', '\\', '\\rvert', '}']
# =============
# equation number 400
# sub-equation number 0
#  \\frac{\\tau}{N_k\\cdot N_{k-1}\\cdot...\\cdot N_i}
# ['START', '\\', '\\frac', '{', '\\', '\\tau', '}', '{', 'N', 'k', '\\', '\\cdot', 'N', '{', 'k', '-', '1', '}', '\\', '\\cdot', '\\', '\\cdot', 'N', 'i', '}']
# sub-equation number 1
#   \\frac{\\tau}{N_{\\mathrm{MD}_i}}\\, , 0\\leq i\\leq k\\, ,
# ['START', '\\', '\\frac', '{', '\\', '\\tau', '}', '{', 'N', '{', '\\', '\\mathrm', '{', 'M', 'D', '}', 'i', '}', '}', '\\', '\\', '0', '\\', '\\leq', 'i', '\\', '\\leq', 'k', '\\', '\\']

# %% [markdown]
# Buglist:
# 1. \n Didn't get filtered:
# \\Sigma_{jk}(p)-\\varphi^{l}  (\\Lambda_{lj;k}^{(3)}(p)-\\Gamma_{ljk}^{(3)})  \\\\\n
#
# ['START', '\\', '\\Sigma', '{', 'j', 'k', '}', '(', 'p', ')', '-', '\\', '\\varphi', '{', 'l', '}', '(', '\\', '\\Lambda', '{', 'l', 'j', 'k', '}', '{', '(', '3', ')', '}', '(', 'p', ')', '-', '\\', '\\Gamma', '{', 'l', 'j', 'k', '}', '{', '(', '3', ')', '}', ')', '\\', '\\', '\\', '\\', '\\n']
#
# 2. Did I handle periods and commas?
