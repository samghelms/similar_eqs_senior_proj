# %%
# setup
import pandas as pd
from common.clean import replace
from common.heuristics import has_op, test_for_suitable, split_high_level_eqs
from common.tokenize import tokenize
df = pd.DataFrame(pd.read_csv("../data/eqs_100k.tsv", sep = "\t", header=None))
# stopwords
sw = ['\\', '\\\\']
df.columns = ["eq_id", "eq"]
df['clean'] = replace(df['eq'])
df['clean_split'] = df['clean'].apply(split_high_level_eqs)
se = df['clean_split'].apply(lambda x: len(x) > 1 if x is not None else False)
df = df[se].reset_index()
se = df['clean_split'].apply(test_for_suitable)
df['clean_split_filtered'] = se
filt = df['clean_split_filtered'].apply(lambda x: x is not None)
df = df[filt]
df['clean_split_filtered_tokenized'] = df['clean_split_filtered'].apply(lambda x: [tokenize(e, sw) for e in x])

# %%
df['clean_split_filtered_tokenized'].to_csv('aligned_ex.csv')

# %%
import pandas as pd
import ast

df = pd.read_csv('aligned_ex.csv', header=None)

df[1] = df[1].apply(ast.literal_eval)

df[1].tolist()
# Out:
# [[['START',
#    '\\left',
#    '\\langle',
#    '\\frac',
#    '{',
#    'd',
#    'C',
#    '}',
#    '{',
#    'd',
#    't',
#    '}',
#    '\\right',
#    '\\rangle'],
#   ['START',
#    '\\frac',
#    '{',
#    'e',
#    'C',
#    '}',
#    '{',
#    '1',
#    '-',
#    'e',
#    '{',
#    '2',
#    '}',
#    '}',
#    '\\left',
#    '\\langle',
#    '\\frac',
#    '{',
#    'd',
#    'e',
#    '}',
#    '{',
#    'd',
#    't',
#    '}',
#    '\\right',
#    '\\rangle']],
#  [['START',
#    '3',
#    '\\widetilde',
#    '{',
#    '\\Gamma',
#    '}',
#    '{',
#    '2',
#    'j',
#    '}',
#    '-',
#    '3',
#    '\\Gamma',
#    '{',
#    '2',
#    'j',
#    '}'],
#   ['START',
#    '-',
#    '3',
#    'R',
#    '4',
#    '(',
#    '0',
#    ')',
#    'a',
#    '{',
#    '2',
#    'j',
#    '}',
#    '2',
#    '-',
#    '6',
#    '\\int',
#    '{',
#    '\\gamma',
#    'j',
#    '}',
#    '\\frac',
#    '{',
#    'S',
#    '2',
#    'R',
#    '4',
#    '}',
#    '{',
#    'r',
#    '5',
#    '}',
#    '\\psi',
#    '2',
#    '\\varphi',
#    '1',
#    '4',
#    'd',
#    'w',
#    '+',
#    '3',
#    '\\int',
#    '{',
#    '\\gamma',
#    'j',
#    '}',
#    '\\frac',
#    '{',
#    'S',
#    '2',
#    'R',
#    '3',
#    '}',
#    '{',
#    'r',
#    '4',
#    '}',
#    '\\psi',
#    '2',
#    '2',
#    '\\varphi',
#    '1',
#    '3',
#    'd',
#    'w']],
#  [['START',
#    '\\mathrm',
#    '{',
#    'o',
#    'r',
#    '}',
#    '\\sqrt',
#    '{',
#    '\\alpha',
#    '2',
#    '-',
#    '\\beta',
#    '2',
#    '}',
#    '-',
#    'c'],
#   ['START',
#    '-',
#    '\\betaz',
#    '+',
#    '\\alpha',
#    '\\sqrt',
#    '{',
#    '1',
#    '+',
#    'z',
#    '2',
#    '}']],
#  [['START',
#    '\\frac',
#    '{',
#    '1',
#    '}',
#    '{',
#    '2',
#    '}',
#    '\\int',
#    '{',
#    '0',
#    '}',
#    '{',
#    '1',
#    '}',
#    '\\frac',
#    '{',
#    'd',
#    '}',
#    '{',
#    'd',
#    's',
#    '}',
#    'g',
#    '\\big',
#    '(',
#    '\\dot',
#    '{',
#    'r',
#    '}',
#    '(',
#    's',
#    't',
#    ')',
#    '\\dot',
#    '{',
#    'r',
#    '}',
#    '(',
#    's',
#    't',
#    ')',
#    '\\big',
#    ')',
#    'd',
#    't'],
#   ['START',
#    '\\int',
#    '{',
#    '0',
#    '}',
#    '{',
#    '1',
#    '}',
#    'g',
#    '\\big',
#    '(',
#    '\\frac',
#    '{',
#    'D',
#    '}',
#    '{',
#    'd',
#    's',
#    '}',
#    '\\dot',
#    '{',
#    'r',
#    '}',
#    '(',
#    's',
#    't',
#    ')',
#    '\\dot',
#    '{',
#    'r',
#    '}',
#    '(',
#    's',
#    't',
#    ')',
#    '\\big',
#    ')',
#    'd',
#    't']],
#  [['START',
#    '\\sum',
#    '{',
#    '\\mu',
#    '=',
#    '1',
#    '}',
#    '\\infty',
#    '\\frac',
#    '{',
#    '\\mu',
#    '{',
#    '\\mu',
#    '-',
#    '1',
#    '}',
#    '}',
#    '{',
#    '\\mu',
#    '}',
#    'e',
#    '{',
#    '-',
#    '\\mu',
#    '}',
#    'x',
#    '\\mu',
#    't',
#    '-',
#    '1'],
#   ['START',
#    '\\sum',
#    '{',
#    '\\mu',
#    '=',
#    '1',
#    '}',
#    '\\infty',
#    '\\frac',
#    '{',
#    '\\mu',
#    '{',
#    '\\mu',
#    '}',
#    '}',
#    '{',
#    '\\mu',
#    '}',
#    'e',
#    '{',
#    '-',
#    '\\mu',
#    '}',
#    'x',
#    '\\mu']],
#  [['START',
#    '\\frac',
#    '{',
#    '\\omega',
#    'n',
#    '}',
#    '{',
#    '\\omega',
#    '{',
#    'n',
#    '-',
#    'j',
#    '}',
#    '}',
#    '\\left',
#    '(',
#    '\\int',
#    '{',
#    '{',
#    '\\rmG',
#    '}',
#    '{',
#    'n',
#    'n',
#    '-',
#    'j',
#    '}',
#    '}',
#    'V',
#    '{',
#    'n',
#    '-',
#    'j',
#    '}',
#    '(',
#    'K',
#    '\\xi',
#    ')',
#    '{',
#    '-',
#    '1',
#    '}',
#    'd',
#    '\\mu',
#    '{',
#    'n',
#    '-',
#    'j',
#    '}',
#    '(',
#    '\\xi',
#    ')',
#    '\\right',
#    ')',
#    '{',
#    '-',
#    '1',
#    '}',
#    'j'],
#   ['START', '1', '\\ldots', 'n', '-', '1']],
#  [['START',
#    '{',
#    '\\cal',
#    '{',
#    'H',
#    '}',
#    '}',
#    '{',
#    's',
#    'p',
#    '}',
#    '+',
#    '{',
#    '\\cal',
#    '{',
#    'H',
#    '}',
#    '}',
#    'c',
#    '+',
#    '{',
#    '\\cal',
#    '{',
#    'H',
#    '}',
#    '}',
#    'd'],
#   ['START', 'T', '+', 'V', '\\']],
#  [['START',
#    '\\frac',
#    '{',
#    'e',
#    '{',
#    '-',
#    '\\gammat',
#    '}',
#    '}',
#    '{',
#    'L',
#    '{',
#    '\\sigma',
#    '}',
#    '}',
#    '\\mathrm',
#    '{',
#    'I',
#    'm',
#    '}',
#    '\\sum',
#    '{',
#    'n',
#    '=',
#    '-',
#    'N',
#    '}',
#    '{',
#    'n',
#    '=',
#    'N',
#    '}',
#    '(',
#    '-',
#    '\\gammau',
#    'n',
#    '+',
#    '\\dot',
#    '{',
#    'u',
#    '}',
#    'n',
#    ')'],
#   ['START',
#    '\\frac',
#    '{',
#    'e',
#    '{',
#    '-',
#    '\\gammat',
#    '}',
#    '}',
#    '{',
#    'L',
#    '{',
#    '\\sigma',
#    '}',
#    '}',
#    '\\mathrm',
#    '{',
#    'I',
#    'm',
#    '}',
#    '\\sum',
#    '{',
#    'n',
#    '=',
#    '-',
#    'N',
#    '}',
#    '{',
#    'n',
#    '=',
#    'N',
#    '}',
#    '\\left',
#    '{',
#    '(',
#    '\\lambda',
#    '+',
#    'i',
#    '\\alpha',
#    ')',
#    '(',
#    'u',
#    '{',
#    'n',
#    '-',
#    '1',
#    '}',
#    '-',
#    '2',
#    'u',
#    'n',
#    '+',
#    'u',
#    '{',
#    'n',
#    '+',
#    '1',
#    '}',
#    ')',
#    '+',
#    'F',
#    '(',
#    'u',
#    'n',
#    ')',
#    '\\right',
#    '}']],
#  [['START',
#    '\\frac',
#    '{',
#    '2',
#    'c',
#    '}',
#    '{',
#    '\\sqrt',
#    '{',
#    'g',
#    '}',
#    '}',
#    '\\frac',
#    '{',
#    '\\delta',
#    'S',
#    '}',
#    '{',
#    '\\delta',
#    'g',
#    '{',
#    'i',
#    'k',
#    '}',
#    '}',
#    '\\Leftrightarrow',
#    '\\nT',
#    '{',
#    'i',
#    'k',
#    '}'],
#   ['START',
#    '-',
#    '\\frac',
#    '{',
#    '2',
#    'c',
#    '}',
#    '{',
#    '\\sqrt',
#    '{',
#    'g',
#    '}',
#    '}',
#    '\\frac',
#    '{',
#    '\\delta',
#    'S',
#    '}',
#    '{',
#    '\\delta',
#    'g',
#    '{',
#    'i',
#    'k',
#    '}',
#    '}',
#    '\\']],
#  [['START',
#    '-',
#    '\\frac',
#    '{',
#    '1',
#    '}',
#    '{',
#    '3',
#    '}',
#    '\\left',
#    '{',
#    '\\nabla',
#    '{',
#    'x',
#    '}',
#    '\\cdot',
#    '\\vec',
#    '{',
#    'u',
#    '}',
#    '(',
#    '\\vec',
#    '{',
#    'x',
#    '}',
#    ')',
#    '\\right',
#    '}',
#    '\\frac',
#    '{',
#    'p',
#    '{',
#    '2',
#    '}',
#    '}',
#    '{',
#    'E',
#    '}',
#    '\\stackrel',
#    '{',
#    '\\rm',
#    'a',
#    'v',
#    'e',
#    '}',
#    '{',
#    '\\xrightarrow',
#    '{',
#    '\\hspace',
#    '*',
#    '{',
#    '1',
#    'c',
#    'm',
#    '}',
#    '}',
#    '}',
#    'b',
#    '{',
#    '\\rm',
#    'a',
#    'd',
#    'i',
#    'a',
#    '}',
#    '(',
#    'K',
#    ')'],
#   ['START',
#    '-',
#    '\\frac',
#    '{',
#    'V',
#    '{',
#    '\\rm',
#    'c',
#    'o',
#    'n',
#    'v',
#    '}',
#    '}',
#    '{',
#    '3',
#    'h',
#    '}',
#    '\\frac',
#    '{',
#    'p',
#    '{',
#    '2',
#    '}',
#    '}',
#    '{',
#    'E',
#    '}']],
#  [['START',
#    '2',
#    '\\langle',
#    '\\triangle',
#    '\\perp',
#    '{',
#    '\\vec',
#    '{',
#    'H',
#    '}',
#    '}',
#    '{',
#    '\\vec',
#    '{',
#    'H',
#    '}',
#    '}',
#    '\\rangle',
#    '+',
#    '2',
#    '\\nabla',
#    '\\perp',
#    '{',
#    '\\vec',
#    '{',
#    'H',
#    '}',
#    '}',
#    '2'],
#   ['START',
#    '2',
#    '\\langle',
#    '{',
#    '\\vec',
#    '{',
#    'H',
#    '}',
#    '}',
#    '-',
#    'P',
#    '{',
#    'i',
#    'k',
#    '}',
#    'A',
#    '{',
#    'i',
#    'k',
#    '}',
#    '+',
#    '\\theta',
#    'k',
#    '\\nabla',
#    'k',
#    '\\perp',
#    '{',
#    '\\vec',
#    '{',
#    'H',
#    '}',
#    '}',
#    '{',
#    '\\vec',
#    '{',
#    'H',
#    '}',
#    '}',
#    '\\rangle',
#    '+',
#    '2',
#    '\\nabla',
#    '\\perp',
#    '{',
#    '\\vec',
#    '{',
#    'H',
#    '}',
#    '}',
#    '2']],
#  [['START',
#    'a',
#    '\\hat',
#    '{',
#    'x',
#    '}',
#    '(',
#    't',
#    ')',
#    '+',
#    'K',
#    '(',
#    't',
#    ')',
#    'y',
#    '(',
#    't',
#    ')',
#    '\\n',
#    '\\check',
#    '{',
#    'x',
#    '}',
#    '(',
#    't',
#    '+',
#    '1',
#    ')'],
#   ['START',
#    'a',
#    'N',
#    '(',
#    'P',
#    '+',
#    'N',
#    ')',
#    '{',
#    '-',
#    '1',
#    '}',
#    '\\check',
#    '{',
#    'x',
#    '}',
#    '(',
#    't',
#    ')',
#    '+',
#    'x',
#    '(',
#    't',
#    '+',
#    '1',
#    ')',
#    '-',
#    'a',
#    'x',
#    '(',
#    't',
#    ')',
#    '\\n',
#    '+',
#    'a',
#    '\\bar',
#    '{',
#    '\\sigma',
#    '}',
#    't',
#    '2',
#    '(',
#    '\\bar',
#    '{',
#    '\\sigma',
#    '}',
#    't',
#    '2',
#    '+',
#    'N',
#    '\\textup',
#    '{',
#    'f',
#    '}',
#    ')',
#    '{',
#    '-',
#    '1',
#    '}',
#    '(',
#    'x',
#    '(',
#    't',
#    ')',
#    '-',
#    '\\check',
#    '{',
#    'x',
#    '}',
#    '(',
#    't',
#    ')',
#    '-',
#    'y',
#    '\\textup',
#    '{',
#    'f',
#    '}',
#    '(',
#    't',
#    ')',
#    ')',
#    'z',
#    '(',
#    't',
#    ')'],
#   ['START',
#    '\\frac',
#    '{',
#    '\\sqrt',
#    '{',
#    'P',
#    '}',
#    '}',
#    '{',
#    '\\sigma',
#    't',
#    '}',
#    '\\check',
#    '{',
#    'x',
#    '}',
#    '(',
#    't',
#    ')',
#    '\\n',
#    '\\end',
#    '{',
#    'a',
#    'l',
#    'i',
#    'g',
#    'n',
#    'e',
#    'd',
#    '}']],
#  [['START',
#    '\\Sigma',
#    '{',
#    'j',
#    'k',
#    '}',
#    '(',
#    'p',
#    ')',
#    '-',
#    '\\varphi',
#    '{',
#    'l',
#    '}',
#    '(',
#    '\\Lambda',
#    '{',
#    'l',
#    'j',
#    'k',
#    '}',
#    '{',
#    '(',
#    '3',
#    ')',
#    '}',
#    '(',
#    'p',
#    ')',
#    '-',
#    '\\Gamma',
#    '{',
#    'l',
#    'j',
#    'k',
#    '}',
#    '{',
#    '(',
#    '3',
#    ')',
#    '}',
#    ')',
#    '\\n'],
#   ['START',
#    '\\Sigma',
#    '{',
#    'j',
#    'k',
#    '}',
#    '-',
#    '\\vec',
#    '{',
#    '\\varphi',
#    '}',
#    '{',
#    '2',
#    '}',
#    '{',
#    '3',
#    '\\lambda',
#    '+',
#    '\\Lambda',
#    '{',
#    '2',
#    '}',
#    '{',
#    '(',
#    '3',
#    ')',
#    '}',
#    '(',
#    'p',
#    ')',
#    '+',
#    '2',
#    '\\Lambda',
#    '{',
#    '4',
#    '}',
#    '{',
#    '(',
#    '3',
#    ')',
#    '}',
#    '(',
#    'p',
#    ')',
#    'P',
#    '{',
#    '\\parallel',
#    'j',
#    'k',
#    '}',
#    '+',
#    '\\lambda',
#    '+',
#    '\\Lambda',
#    '{',
#    '3',
#    '}',
#    '{',
#    '(',
#    '3',
#    ')',
#    '}',
#    '(',
#    'p',
#    ')',
#    'P',
#    '{',
#    '\\perp',
#    'j',
#    'k',
#    '}',
#    '}',
#    '\\end',
#    '{',
#    's',
#    'p',
#    'l',
#    'i',
#    't',
#    '}']],
#  [['START',
#    '\\lim',
#    '{',
#    'n',
#    '\\to',
#    '\\infty',
#    '}',
#    '\\frac',
#    '{',
#    '\\log',
#    '(',
#    '\\rho',
#    '{',
#    '\\star',
#    '}',
#    '{',
#    '\\lambda',
#    '{',
#    '\\textup',
#    '{',
#    '{',
#    '\\textsf',
#    '{',
#    '{',
#    'U',
#    'C',
#    '}',
#    '}',
#    '}',
#    '}',
#    '}',
#    '}',
#    '(',
#    'n',
#    ')',
#    ')',
#    '}',
#    '{',
#    '\\log',
#    '(',
#    'n',
#    ')',
#    '}'],
#   ['START',
#    '\\lim',
#    '{',
#    'n',
#    '\\to',
#    '\\infty',
#    '}',
#    '\\frac',
#    '{',
#    '\\log',
#    '(',
#    '\\hat',
#    '{',
#    '\\rho',
#    '}',
#    '{',
#    '\\star',
#    '}',
#    '{',
#    '\\lambda',
#    '{',
#    '\\textup',
#    '{',
#    '{',
#    '\\textsf',
#    '{',
#    '{',
#    'U',
#    'C',
#    '}',
#    '}',
#    '}',
#    '}',
#    '}',
#    '}',
#    '(',
#    'n',
#    ')',
#    ')',
#    '}',
#    '{',
#    '\\log',
#    '(',
#    'n',
#    ')',
#    '}']],
#  [['START',
#    '\\int',
#    '\\limits',
#    '{',
#    '0',
#    '}',
#    '{',
#    '\\beta',
#    '0',
#    '}',
#    '{',
#    '\\rm',
#    'd',
#    '}',
#    '\\beta',
#    '\\beta',
#    '\\alpha',
#    '\\left',
#    '\\frac',
#    '{',
#    '\\beta',
#    '}',
#    '{',
#    '\\pi',
#    '\\alpha',
#    '}',
#    '+',
#    '\\frac',
#    '1',
#    '2',
#    '+',
#    '\\frac',
#    '{',
#    '\\pi',
#    '\\alpha',
#    '}',
#    '{',
#    '1',
#    '2',
#    '\\beta',
#    '}',
#    '\\right',
#    '\\nI',
#    '2'],
#   ['START',
#    '\\int',
#    '\\limits',
#    '{',
#    '0',
#    '}',
#    '{',
#    '\\beta',
#    '0',
#    '}',
#    '{',
#    '\\rm',
#    'd',
#    '}',
#    '\\beta',
#    '\\beta',
#    '\\alpha',
#    '\\left',
#    '\\frac',
#    '{',
#    '1',
#    '}',
#    '{',
#    '1',
#    '-',
#    'e',
#    '{',
#    '-',
#    '\\pi',
#    '\\alpha',
#    '\\beta',
#    '}',
#    '}',
#    '-',
#    '\\frac',
#    '{',
#    '\\beta',
#    '}',
#    '{',
#    '\\pi',
#    '\\alpha',
#    '}',
#    '-',
#    '\\frac',
#    '1',
#    '2',
#    '-',
#    '\\frac',
#    '{',
#    '\\pi',
#    '\\alpha',
#    '}',
#    '{',
#    '1',
#    '2',
#    '\\beta',
#    '}',
#    '\\right',
#    '\\end',
#    '{',
#    's',
#    'p',
#    'l',
#    'i',
#    't',
#    '}']],
#  [['START',
#    '\\pi',
#    'i',
#    '\\frac',
#    '{',
#    '\\pi',
#    'W',
#    '*',
#    'e',
#    'i',
#    '}',
#    '{',
#    '\\pi',
#    'W',
#    '*',
#    '\\pi',
#    '}'],
#   ['START',
#    '\\frac',
#    '{',
#    '\\pi',
#    'W',
#    '*',
#    'e',
#    'i',
#    'e',
#    'i',
#    '\\pi',
#    '}',
#    '{',
#    '\\pi',
#    'W',
#    '*',
#    '\\pi',
#    '}']],
#  [['START',
#    '\\frac',
#    '{',
#    'L',
#    '{',
#    '3',
#    '2',
#    '}',
#    '}',
#    '{',
#    '1',
#    '2',
#    '\\pi',
#    '}',
#    '+',
#    '\\frac',
#    '{',
#    '\\sqrt',
#    '{',
#    'L',
#    '}',
#    '}',
#    '{',
#    '\\pi',
#    '}'],
#   ['STARTs',
#    '\\sqrt',
#    '{',
#    'b',
#    '}',
#    '\\textrm',
#    '{',
#    'a',
#    'n',
#    'd',
#    '}',
#    'R'],
#   ['START',
#    '\\frac',
#    '{',
#    '2',
#    '\\pi',
#    '}',
#    '{',
#    '\\sqrt',
#    '{',
#    'L',
#    '}',
#    '}',
#    '-',
#    '\\frac',
#    '{',
#    '\\pi',
#    '\\sqrt',
#    '{',
#    'L',
#    '}',
#    '}',
#    '{',
#    '2',
#    '}']],
#  [['START',
#    '\\bigcup',
#    '{',
#    'i',
#    '\\in',
#    'I',
#    '}',
#    '\\Omega',
#    'i',
#    '{',
#    '\\mathcal',
#    '{',
#    'X',
#    '}',
#    '}',
#    '{',
#    '\\dashrightarrow',
#    '}',
#    '{',
#    '\\mathcal',
#    '{',
#    'Y',
#    '}',
#    '}',
#    '\\left',
#    '(',
#    '\\bigcup',
#    '{',
#    'i',
#    '\\in',
#    'I',
#    '}',
#    '\\Omega',
#    'i',
#    '\\right',
#    ')',
#    '(',
#    'x',
#    ')'],
#   ['START',
#    '\\bigcup',
#    '{',
#    'i',
#    '\\in',
#    'I',
#    '}',
#    '\\Omega',
#    'i',
#    '(',
#    'x',
#    ')',
#    '\\text',
#    '{',
#    'f',
#    'o',
#    'r',
#    'a',
#    'l',
#    'l',
#    '}',
#    'x',
#    '\\in',
#    '{',
#    '\\mathcal',
#    '{',
#    'X',
#    '}',
#    '}']],
#  [['START', '\\textstyle', 'p', '0', '-', '1'],
#   ['START',
#    '\\frac',
#    '{',
#    '2',
#    '\\delta',
#    '}',
#    '{',
#    '\\delta',
#    '+',
#    '1',
#    '}',
#    '(',
#    'p',
#    '-',
#    '1',
#    ')',
#    '\\frac',
#    '{',
#    '1',
#    '}',
#    '{',
#    'p',
#    '}'],
#   ['START',
#    '\\frac',
#    '{',
#    '1',
#    '}',
#    '{',
#    '2',
#    'p',
#    '0',
#    '}',
#    '+',
#    '\\frac',
#    '{',
#    '1',
#    '}',
#    '{',
#    '2',
#    'p',
#    '1',
#    '}']],
#  [['START',
#    '\\frac',
#    '{',
#    '\\vec',
#    '{',
#    '\\eta',
#    '}',
#    '\\cdot',
#    '\\vec',
#    '{',
#    '\\xi',
#    '}',
#    '+',
#    '\\Omega',
#    '\\vec',
#    '{',
#    '\\xi',
#    '}',
#    '\\cdot',
#    '\\vec',
#    '{',
#    '\\xi',
#    '}',
#    '}',
#    '{',
#    '\\vec',
#    '{',
#    '\\eta',
#    '}',
#    '\\cdot',
#    '\\vec',
#    '{',
#    '\\eta',
#    '}',
#    '+',
#    '\\Omega',
#    '\\vec',
#    '{',
#    '\\eta',
#    '}',
#    '\\cdot',
#    '\\vec',
#    '{',
#    '\\xi',
#    '}',
#    '}'],
#   ['START',
#    '\\frac',
#    '{',
#    '{',
#    '\\mathfrak',
#    'R',
#    '}',
#    '2',
#    '\\Omega',
#    '-',
#    '\\omega',
#    '}',
#    '{',
#    '\\Omega',
#    '\\omega',
#    '-',
#    '1',
#    '}']],
#  [['START',
#    '2',
#    '-',
#    '\\frac',
#    '{',
#    '\\nu',
#    '}',
#    '{',
#    'z',
#    '1',
#    '}',
#    '-',
#    '\\frac',
#    '{',
#    '\\nu',
#    '}',
#    '{',
#    'z',
#    '2',
#    '}'],
#   ['START',
#    '1',
#    '\\mbox',
#    '{',
#    'w',
#    'i',
#    't',
#    'h',
#    '}',
#    '\\frac',
#    '{',
#    '\\nu',
#    '}',
#    '{',
#    'z',
#    '3',
#    '}',
#    '\\geq',
#    '1']],
#  [['START',
#    '\\lim',
#    '{',
#    'i',
#    '\\to',
#    '\\infty',
#    '}',
#    '\\int',
#    '{',
#    '-',
#    'L',
#    '{',
#    'i',
#    '\\pm',
#    '}',
#    '}',
#    '{',
#    'L',
#    '{',
#    'i',
#    '\\pm',
#    '}',
#    '}',
#    '\\int',
#    '{',
#    'S',
#    '1',
#    '}',
#    'v',
#    '{',
#    'i',
#    '\\pm',
#    '}',
#    '*',
#    '\\Theta',
#    '*',
#    'd',
#    '\\lambda'],
#   ['START',
#    '0',
#    'E',
#    '\\Sigma',
#    '(',
#    'v',
#    '{',
#    'i',
#    '\\pm',
#    '}',
#    ')',
#    '\\leq',
#    '2',
#    '\\pi',
#    '+',
#    '\\delta']],
#  [['START',
#    '\\frac',
#    '{',
#    '2',
#    'm',
#    '(',
#    '2',
#    'm',
#    '-',
#    '1',
#    ')',
#    '}',
#    '{',
#    'm',
#    '(',
#    'm',
#    '+',
#    '1',
#    ')',
#    '}',
#    'Y',
#    '{',
#    '0',
#    '}',
#    '(',
#    'm',
#    '-',
#    '1',
#    ')'],
#   ['START',
#    '\\frac',
#    '{',
#    '(',
#    '2',
#    'm',
#    ')',
#    '}',
#    '{',
#    'm',
#    '(',
#    'm',
#    '+',
#    '1',
#    ')',
#    '}']],
#  [['START',
#    '\\left',
#    '\\frac',
#    '{',
#    'A',
#    'h',
#    '{',
#    'v',
#    '6',
#    '}',
#    '}',
#    '{',
#    'A',
#    'h',
#    '{',
#    'v',
#    '0',
#    '}',
#    '}',
#    '\\right',
#    '{',
#    'v',
#    '6',
#    '}',
#    '2'],
#   ['START',
#    '-',
#    '(',
#    'G',
#    'N',
#    'M',
#    '\\omega',
#    ')',
#    '2',
#    '\\frac',
#    '{',
#    '2',
#    '1',
#    '4',
#    '}',
#    '{',
#    '1',
#    '0',
#    '5',
#    '}',
#    '\\ln',
#    '\\frac',
#    '{',
#    '\\omega',
#    '2',
#    '}',
#    '{',
#    '\\mu',
#    '2',
#    '}',
#    '+',
#    '\\ldots',
#    '\\']],
#  [['START',
#    '\\downarrow',
#    '{',
#    '{',
#    '\\rho',
#    '{',
#    '\\vec',
#    '{',
#    'y',
#    '}',
#    '\\vec',
#    '{',
#    'x',
#    '}',
#    '}',
#    '}',
#    '{',
#    '\\alpha',
#    '}',
#    '}',
#    '(',
#    '{',
#    '{',
#    '\\overline',
#    '{',
#    '\\exists',
#    '}',
#    '{',
#    '\\vec',
#    '{',
#    'y',
#    '}',
#    '}',
#    '}',
#    '{',
#    '\\alpha',
#    '}',
#    '}',
#    '(',
#    '{',
#    '{',
#    'S',
#    'H',
#    '}',
#    '{',
#    '\\alpha',
#    '}',
#    '}',
#    '{',
#    '\\llbracket',
#    '{',
#    'p',
#    '(',
#    '\\vec',
#    '{',
#    'y',
#    '}',
#    ')',
#    '}',
#    '\\rrbracket',
#    '}',
#    ')',
#    ')',
#    'w',
#    'h',
#    'e',
#    'r',
#    'e',
#    'p',
#    '(',
#    '\\vec',
#    '{',
#    'y',
#    '}',
#    ')',
#    '{',
#    '\\leftarrow',
#    '}',
#    'B',
#    '\\in',
#    'P',
#    '\\n',
#    '{',
#    '{',
#    'S',
#    'G',
#    '}',
#    '{',
#    '\\alpha',
#    '}',
#    '}',
#    '{',
#    '\\llbracket',
#    '{',
#    'G',
#    '1',
#    'G',
#    '2',
#    '}',
#    '\\rrbracket',
#    '}'],
#   ['START',
#    '\\downarrow',
#    '{',
#    '{',
#    '\\overline',
#    '{',
#    '\\exists',
#    '}',
#    '{',
#    '\\vec',
#    '{',
#    'y',
#    '}',
#    '}',
#    '}',
#    '{',
#    '\\alpha',
#    '}',
#    '}',
#    '(',
#    '{',
#    '{',
#    'S',
#    'G',
#    '}',
#    '{',
#    '\\alpha',
#    '}',
#    '}',
#    '{',
#    '\\llbracket',
#    '{',
#    'G',
#    '1',
#    '}',
#    '\\rrbracket',
#    '}',
#    '\\vee',
#    '{',
#    '{',
#    'S',
#    'G',
#    '}',
#    '{',
#    '\\alpha',
#    '}',
#    '}',
#    '{',
#    '\\llbracket',
#    '{',
#    'G',
#    '2',
#    'G',
#    '3',
#    '}',
#    '\\rrbracket',
#    '}',
#    '\\vee',
#    '{',
#    '{',
#    'S',
#    'G',
#    '}',
#    '{',
#    '\\alpha',
#    '}',
#    '}',
#    '{',
#    '\\llbracket',
#    '{',
#    'G',
#    '4',
#    '}',
#    '\\rrbracket',
#    '}',
#    ')',
#    'w',
#    'h',
#    'e',
#    'r',
#    'e',
#    'p',
#    '(',
#    '\\vec',
#    '{',
#    'y',
#    '}',
#    ')',
#    '{',
#    '\\leftarrow',
#    '}',
#    'B',
#    '\\in',
#    'P',
#    'a',
#    'n',
#    'd',
#    'B']],
#  [['START',
#    '\\frac',
#    '{',
#    '1',
#    '}',
#    '{',
#    '1',
#    '-',
#    't',
#    'e',
#    '{',
#    'x',
#    '}',
#    '}'],
#   ['START',
#    '\\frac',
#    '{',
#    '1',
#    '+',
#    't',
#    'e',
#    '{',
#    'x',
#    '}',
#    '}',
#    '{',
#    '1',
#    '-',
#    't',
#    '{',
#    '2',
#    '}',
#    'e',
#    '{',
#    '2',
#    'x',
#    '}',
#    '}'],
#   ['START',
#    '\\frac',
#    '{',
#    '1',
#    '}',
#    '{',
#    '1',
#    '-',
#    't',
#    '}',
#    '+',
#    '\\sum',
#    '{',
#    'n',
#    '=',
#    '1',
#    '}',
#    '{',
#    '\\infty',
#    '}',
#    '\\sum',
#    '{',
#    '\\pi',
#    '\\in',
#    '\\mathfrak',
#    '{',
#    'S',
#    '}',
#    '{',
#    'n',
#    '}',
#    '}',
#    '\\frac',
#    '{',
#    '(',
#    '1',
#    '+',
#    't',
#    '{',
#    '2',
#    '}',
#    ')',
#    '{',
#    'n',
#    '}',
#    '}',
#    '{',
#    '2',
#    '(',
#    '1',
#    '-',
#    't',
#    '{',
#    '2',
#    '}',
#    ')',
#    '{',
#    'n',
#    '-',
#    '1',
#    '}',
#    '(',
#    '1',
#    '-',
#    't',
#    ')',
#    '{',
#    '2',
#    '}',
#    '}',
#    '\\left',
#    '(',
#    '\\frac',
#    '{',
#    '2',
#    't',
#    '}',
#    '{',
#    '1',
#    '+',
#    't',
#    '{',
#    '2',
#    '}',
#    '}',
#    '\\right',
#    ')',
#    '{',
#    '{',
#    '\\operatorname',
#    '{',
#    'u',
#    'd',
#    'r',
#    '}',
#    '}',
#    '(',
#    '\\pi',
#    ')',
#    '}',
#    '\\frac',
#    '{',
#    'x',
#    '{',
#    'n',
#    '}',
#    '}',
#    '{',
#    'n',
#    '}']],
#  [['START',
#    '-',
#    '\\frac',
#    '{',
#    'f',
#    '2',
#    '}',
#    '{',
#    'Q',
#    '2',
#    '}',
#    '\\simeq',
#    '\\Pi',
#    'T',
#    '{',
#    'V',
#    '-',
#    'A',
#    '}',
#    '(',
#    'Q',
#    '2',
#    ')'],
#   ['START',
#    '\\left',
#    '(',
#    '\\frac',
#    '{',
#    'F',
#    '2',
#    '}',
#    '{',
#    'a',
#    '}',
#    '(',
#    'M',
#    '{',
#    'A',
#    '}',
#    '2',
#    '-',
#    'M',
#    'V',
#    '2',
#    ')',
#    '-',
#    'f',
#    '2',
#    '\\right',
#    ')',
#    '\\frac',
#    '{',
#    '1',
#    '}',
#    '{',
#    'Q',
#    '2',
#    '}']],
#  [['START',
#    '\\frac',
#    '{',
#    '2',
#    'k',
#    '\\cdotQF',
#    '\\pi',
#    '(',
#    'Q',
#    '2',
#    ')',
#    '}',
#    '{',
#    '(',
#    'k',
#    '\\cdotQ',
#    ')',
#    '2',
#    '-',
#    '(',
#    'k',
#    '\\cdotl',
#    ')',
#    '2',
#    '}',
#    'f',
#    '2',
#    '{',
#    's',
#    'Q',
#    'E',
#    'D',
#    '}'],
#   ['START',
#    '\\frac',
#    '{',
#    '-',
#    '2',
#    'F',
#    '\\pi',
#    '(',
#    'Q',
#    '2',
#    ')',
#    '}',
#    '{',
#    '(',
#    'k',
#    '\\cdotQ',
#    ')',
#    '2',
#    '-',
#    '(',
#    'k',
#    '\\cdotl',
#    ')',
#    '2',
#    '}',
#    '\\']],
#  [['START',
#    '\\frac',
#    '{',
#    '\\kappa',
#    '{',
#    'w',
#    '\\kappa',
#    '}',
#    '\\exp',
#    '(',
#    '-',
#    '\\kappa',
#    ')',
#    '}',
#    '{',
#    '(',
#    'w',
#    '\\kappa',
#    ')',
#    '}',
#    'w'],
#   ['START',
#    '0',
#    '\\frac',
#    '{',
#    '1',
#    '}',
#    '{',
#    '\\kappa',
#    '}',
#    '\\frac',
#    '{',
#    '2',
#    '}',
#    '{',
#    '\\kappa',
#    '}',
#    '\\frac',
#    '{',
#    '3',
#    '}',
#    '{',
#    '\\kappa',
#    '}',
#    '\\dots']],
#  [['START', '\\int', '0', 'h', '\\rhodz'],
#   ['START', '\\Sigma', '0', '+', '\\Sigma', '{', '}']],
#  [['START',
#    '\\frac',
#    '{',
#    'L',
#    '{',
#    '\\mathit',
#    'M',
#    'E',
#    '}',
#    '}',
#    '{',
#    'D',
#    '{',
#    '\\mathit',
#    'M',
#    'M',
#    '}',
#    '}',
#    '\\nabla',
#    'T',
#    '\\'],
#   ['START',
#    '-',
#    'B',
#    '\\frac',
#    '{',
#    '\\partial',
#    '\\chi',
#    '}',
#    '{',
#    '\\partial',
#    'T',
#    '}',
#    '\\nabla',
#    'T']],
#  [['START', '\\frac', '{', '\\delta', 'c', 's', '}', '{', 'c', 's', '}'],
#   ['START',
#    '\\frac',
#    '{',
#    'c',
#    '{',
#    's',
#    '{',
#    '\\rm',
#    'm',
#    'a',
#    'g',
#    '}',
#    '}',
#    '-',
#    'c',
#    '{',
#    's',
#    '0',
#    '}',
#    '}',
#    '{',
#    'c',
#    '{',
#    's',
#    '0',
#    '}',
#    '}']],
#  [['STARTE',
#    '{',
#    '0',
#    '}',
#    '-',
#    '2',
#    'V',
#    '\\cos',
#    '\\phi',
#    '{',
#    'm',
#    'i',
#    'n',
#    '}',
#    'k',
#    '\\'],
#   ['STARTE',
#    '{',
#    '0',
#    '}',
#    '-',
#    '2',
#    'V',
#    '\\cos',
#    '\\frac',
#    '{',
#    '\\pi',
#    '(',
#    'k',
#    '+',
#    '1',
#    '2',
#    ')',
#    '}',
#    '{',
#    'N',
#    '+',
#    '1',
#    '}',
#    '\\']],
#  [['START',
#    '\\Pi',
#    '{',
#    'S',
#    'P',
#    '}',
#    '(',
#    'Q',
#    '2',
#    ')',
#    '-',
#    '\\frac',
#    '3',
#    '2',
#    '\\Pi',
#    '{',
#    'V',
#    'A',
#    '}',
#    '(',
#    'Q',
#    '2',
#    ')'],
#   ['START',
#    '\\frac',
#    '{',
#    '\\alpha',
#    's',
#    '}',
#    '{',
#    '4',
#    '\\pi',
#    '}',
#    '\\frac',
#    '{',
#    '\\langleG',
#    '2',
#    '\\rangle',
#    '}',
#    '{',
#    'Q',
#    '2',
#    '}',
#    '+',
#    '\\mathcal',
#    '{',
#    'O',
#    '}',
#    '\\left',
#    '(',
#    '\\frac',
#    '{',
#    '1',
#    '}',
#    '{',
#    'Q',
#    '4',
#    '}',
#    '\\right',
#    ')']],
#  [['START',
#    '8',
#    '\\pi',
#    '\\int',
#    '0',
#    '\\infty',
#    '(',
#    '1',
#    '-',
#    '\\eta',
#    ')',
#    'b',
#    'd',
#    'b',
#    '2',
#    '\\sigma',
#    '{',
#    '\\rm',
#    'e',
#    'l',
#    '}'],
#   ['START',
#    '8',
#    '\\pi',
#    '\\int',
#    '0',
#    '\\infty',
#    '(',
#    '1',
#    '-',
#    '\\eta',
#    ')',
#    '2',
#    'b',
#    'd',
#    'b',
#    '4']],
#  [['START',
#    '\\min',
#    '{',
#    'L',
#    'S',
#    '}',
#    '\\frac',
#    '{',
#    '1',
#    '}',
#    '{',
#    '2',
#    '}',
#    'L',
#    '+',
#    'S',
#    '-',
#    'Y',
#    'F',
#    '2',
#    '+',
#    '\\kappa',
#    'S',
#    '1',
#    '+',
#    '\\lambda',
#    'L',
#    '*'],
#   ['START',
#    '\\min',
#    '{',
#    'L',
#    '}',
#    '\\rho',
#    '{',
#    '\\kappa',
#    '}',
#    '(',
#    'Y',
#    '-',
#    'L',
#    ')',
#    '+',
#    '\\lambda',
#    'L',
#    '*']],
#  [['START',
#    '-',
#    '{',
#    '1',
#    '\\over',
#    '(',
#    '4',
#    '\\pi',
#    '{',
#    '\\kappa',
#    '}',
#    '2',
#    '{',
#    '1',
#    '1',
#    '}',
#    ')',
#    '{',
#    '1',
#    '3',
#    '}',
#    '}',
#    '\\int',
#    '{',
#    '\\mathbb',
#    '{',
#    'R',
#    '}',
#    '{',
#    '1',
#    '0',
#    '}',
#    'I',
#    '}',
#    'G',
#    '\\wedgeX',
#    '7'],
#   ['START',
#    '-',
#    '{',
#    '1',
#    '\\over',
#    '2',
#    '(',
#    '4',
#    '\\pi',
#    '{',
#    '\\kappa',
#    '}',
#    '2',
#    '{',
#    '1',
#    '1',
#    '}',
#    ')',
#    '{',
#    '1',
#    '3',
#    '}',
#    '}',
#    '\\int',
#    '{',
#    '\\mathbb',
#    '{',
#    'R',
#    '}',
#    '{',
#    '1',
#    '0',
#    '}',
#    'S',
#    '1',
#    '}',
#    'G',
#    '\\wedge',
#    'X',
#    '7']],
#  [['START', '\\frac', '1', '2', 'J', '1', '(', 'h', ')', '+', 'I'],
#   ['START',
#    '\\frac',
#    '1',
#    '2',
#    'h',
#    '2',
#    '{',
#    '\\Phi',
#    '\\gamma',
#    '}',
#    '-',
#    '\\frac',
#    '1',
#    '2',
#    'J',
#    '2',
#    '(',
#    'h',
#    ')',
#    '+',
#    'I',
#    '\\']],
#  [['START',
#    '\\frac',
#    '{',
#    '\\partial',
#    '}',
#    '{',
#    '{',
#    '\\partial',
#    '}',
#    'r',
#    '}',
#    'V',
#    'W',
#    '{',
#    '+',
#    '}',
#    '(',
#    'r',
#    '\\rightarrow',
#    'r',
#    '+',
#    '{',
#    '\\theta',
#    '}',
#    'z',
#    ')',
#    '-',
#    '\\frac',
#    '{',
#    '\\partial',
#    '}',
#    '{',
#    '{',
#    '\\partial',
#    '}',
#    'r',
#    '}',
#    'V',
#    'W',
#    '{',
#    '+',
#    '}',
#    '(',
#    'r',
#    '\\rightarrow',
#    'r',
#    '-',
#    '{',
#    '\\theta',
#    '}',
#    'z',
#    ')'],
#   ['START',
#    '-',
#    '\\frac',
#    '{',
#    '4',
#    '\\pi',
#    'q',
#    '}',
#    '{',
#    'r',
#    '}',
#    '{',
#    '\\delta',
#    '}',
#    '(',
#    '{',
#    '\\theta',
#    '}',
#    '-',
#    '{',
#    '\\theta',
#    '}',
#    ')',
#    '{',
#    '\\delta',
#    '}',
#    '(',
#    'z',
#    '-',
#    'z',
#    ')',
#    '\\']],
#  [['START',
#    '\\sum',
#    '{',
#    'a',
#    '\\in',
#    'A',
#    '-',
#    'k',
#    '}',
#    '\\int',
#    '{',
#    'X',
#    '{',
#    '-',
#    '1',
#    '}',
#    '{',
#    '{',
#    '\\cal',
#    'O',
#    '}',
#    '}',
#    '}',
#    '\\frac',
#    '{',
#    'd',
#    '\\mu',
#    '(',
#    'g',
#    ')',
#    '}',
#    '{',
#    'a',
#    '+',
#    'g',
#    '2',
#    '\\infty',
#    '}'],
#   ['START',
#    '\\sum',
#    '{',
#    'a',
#    '\\in',
#    'A',
#    '-',
#    'k',
#    '}',
#    '\\frac',
#    '{',
#    '1',
#    '}',
#    '{',
#    'a',
#    '2',
#    '\\infty',
#    '}',
#    '\\mu',
#    '(',
#    'X',
#    '{',
#    '-',
#    '1',
#    '}',
#    '{',
#    '{',
#    '\\cal',
#    'O',
#    '}',
#    '}',
#    ')',
#    '\\']],
#  [['START',
#    '\\frac',
#    '{',
#    'u',
#    '-',
#    's',
#    '{',
#    '-',
#    '1',
#    '}',
#    '}',
#    '{',
#    'u',
#    's',
#    '-',
#    '1',
#    '}',
#    'w',
#    '2'],
#   ['START',
#    '\\frac',
#    '{',
#    'u',
#    '-',
#    's',
#    '}',
#    '{',
#    'u',
#    's',
#    '-',
#    '1',
#    '}',
#    'w',
#    '4'],
#   ['START',
#    '\\frac',
#    '{',
#    'u',
#    's',
#    '{',
#    '-',
#    '1',
#    '}',
#    '-',
#    '1',
#    '}',
#    '{',
#    'u',
#    's',
#    '-',
#    '1',
#    '}',
#    'w',
#    '5'],
#   ['START',
#    '\\frac',
#    '{',
#    '(',
#    's',
#    '2',
#    '-',
#    '1',
#    ')',
#    'u',
#    '}',
#    '{',
#    'u',
#    's',
#    '-',
#    '1',
#    '}',
#    'w',
#    '6'],
#   ['START',
#    '\\frac',
#    '{',
#    '1',
#    '-',
#    's',
#    '{',
#    '-',
#    '2',
#    '}',
#    '}',
#    '{',
#    'u',
#    's',
#    '-',
#    '1',
#    '}',
#    '\\end',
#    '{',
#    's',
#    'p',
#    'l',
#    'i',
#    't',
#    '}']],
#  [['START', '\\frac', '{', 'd', 'w', 'b', '}', '{', 'd', '\\omega', '}'],
#   ['START',
#    '\\frac',
#    '{',
#    '4',
#    '\\alpha',
#    '}',
#    '{',
#    '\\omega',
#    '(',
#    '2',
#    '\\pi',
#    ')',
#    '2',
#    '}',
#    '\\int',
#    '{',
#    '}',
#    '{',
#    '}',
#    '\\left',
#    '0',
#    'r',
#    '1',
#    'M',
#    '+',
#    'r',
#    '2',
#    '{',
#    '\\bfp',
#    '}',
#    'M',
#    '{',
#    '\\bfp',
#    '}',
#    '0',
#    '\\right',
#    'd',
#    '2',
#    'p']],
#  [['START',
#    '{',
#    '{',
#    '\\boldsymbol',
#    '{',
#    '{',
#    'Q',
#    '}',
#    '}',
#    '}',
#    '}',
#    '(',
#    't',
#    ')',
#    '+',
#    '{',
#    '{',
#    '\\boldsymbol',
#    '{',
#    '{',
#    '\\xi',
#    '}',
#    '}',
#    '}',
#    '}',
#    'Q',
#    '\\hat',
#    '{',
#    '{',
#    '{',
#    '\\boldsymbol',
#    '{',
#    '{',
#    'E',
#    '}',
#    '}',
#    '}',
#    '}',
#    '}',
#    '(',
#    't',
#    ')'],
#   ['START',
#    '{',
#    '{',
#    '\\boldsymbol',
#    '{',
#    '{',
#    'E',
#    '}',
#    '}',
#    '}',
#    '}',
#    '(',
#    't',
#    ')',
#    '+',
#    '{',
#    '{',
#    '\\boldsymbol',
#    '{',
#    '{',
#    '\\xi',
#    '}',
#    '}',
#    '}',
#    '}',
#    'E']],
#  [['START',
#    '\\int',
#    '{',
#    '\\rm',
#    'd',
#    '}',
#    '\\hat',
#    '{',
#    '\\bf',
#    'x',
#    '}',
#    '\\big',
#    'Y',
#    '{',
#    '\\ell',
#    'x',
#    '}',
#    '(',
#    '\\hat',
#    '{',
#    '\\bf',
#    'x',
#    '}',
#    ')',
#    'S',
#    '{',
#    'x',
#    '}',
#    '\\big',
#    '\\dag',
#    '{',
#    'j',
#    'x',
#    'm',
#    'x',
#    '}',
#    '(',
#    '{',
#    '\\bm',
#    '\\sigma',
#    '}',
#    '2',
#    '+',
#    '{',
#    '\\bm',
#    '\\sigma',
#    '}',
#    '3',
#    ')',
#    '\\cdot',
#    '\\hat',
#    '{',
#    '\\bf',
#    'x',
#    '}',
#    '\\big',
#    'Y',
#    '{',
#    '\\ell',
#    'x',
#    '\\prime',
#    '}',
#    '(',
#    '\\hat',
#    '{',
#    '\\bf',
#    'x',
#    '}',
#    ')',
#    'S',
#    '{',
#    'x',
#    '}',
#    '\\prime',
#    '\\big',
#    '{',
#    'j',
#    'x',
#    'm',
#    'x',
#    '}'],
#   ['START',
#    '-',
#    '2',
#    '\\sqrt',
#    '{',
#    '\\frac',
#    '{',
#    'j',
#    'x',
#    '+',
#    '1',
#    '2',
#    '\\pm',
#    '1',
#    '2',
#    '}',
#    '{',
#    '2',
#    'j',
#    'x',
#    '+',
#    '1',
#    '}',
#    '}',
#    '\\delta',
#    '{',
#    '\\ell',
#    'x',
#    'j',
#    'x',
#    '}',
#    '\\delta',
#    '{',
#    'S',
#    'x',
#    '1',
#    '}',
#    '\\delta',
#    '{',
#    'S',
#    '\\prime',
#    'x',
#    '1',
#    '}',
#    '\\delta',
#    '{',
#    '\\ell',
#    'x',
#    '\\prime',
#    'j',
#    'x',
#    '\\mp',
#    '1',
#    '}',
#    '\\']],
#  [['START',
#    '\\sqrt',
#    '{',
#    '2',
#    '}',
#    '\\hat',
#    '{',
#    'a',
#    '}',
#    'A',
#    '-',
#    '\\frac',
#    '{',
#    '\\hat',
#    '{',
#    'a',
#    '}',
#    '\\dag',
#    '{',
#    '\\rmin',
#    '}',
#    '+',
#    '\\hat',
#    '{',
#    'a',
#    '}',
#    '\\dag',
#    'B',
#    '}',
#    '{',
#    '\\sqrt',
#    '{',
#    '2',
#    '}',
#    '}',
#    '\\hat',
#    '{',
#    'a',
#    '}',
#    'B'],
#   ['START',
#    '\\frac',
#    '{',
#    '\\hat',
#    '{',
#    'a',
#    '}',
#    '{',
#    '\\rmin',
#    '}',
#    '-',
#    '\\hat',
#    '{',
#    'a',
#    '}',
#    'B',
#    '}',
#    '{',
#    '\\sqrt',
#    '{',
#    '2',
#    '}',
#    '}',
#    '\\setcounter',
#    '{',
#    'e',
#    'q',
#    'u',
#    'a',
#    't',
#    'i',
#    'o',
#    'n',
#    '}',
#    '{',
#    '8',
#    '}']],
#  [['START',
#    '\\widetilde',
#    '{',
#    'g',
#    'r',
#    '}',
#    '(',
#    '{',
#    '\\bf',
#    'g',
#    '}',
#    '1',
#    ')',
#    '-',
#    '\\widetilde',
#    '{',
#    'g',
#    'r',
#    '}',
#    '(',
#    '{',
#    '\\bf',
#    'g',
#    '}',
#    '2',
#    ')'],
#   ['START',
#    '\\frac',
#    '{',
#    '1',
#    '}',
#    '{',
#    'n',
#    '}',
#    '\\widetilde',
#    '{',
#    'g',
#    'r',
#    '}',
#    '(',
#    '\\widetilde',
#    '{',
#    '{',
#    '\\bf',
#    'g',
#    '}',
#    '}',
#    '1',
#    ')',
#    '-',
#    '\\widetilde',
#    '{',
#    'g',
#    'r',
#    '}',
#    '(',
#    '\\widetilde',
#    '{',
#    '{',
#    '\\bf',
#    'g',
#    '}',
#    '}',
#    '2',
#    ')']],
#  [['START',
#    '\\frac',
#    '{',
#    '(',
#    '1',
#    '-',
#    '\\gamma',
#    ')',
#    '\\log',
#    '(',
#    'T',
#    't',
#    '2',
#    ')',
#    '}',
#    '{',
#    'K',
#    '(',
#    '\\theta',
#    'a',
#    '*',
#    '-',
#    't',
#    '\\theta',
#    'a',
#    '*',
#    '+',
#    '\\zeta',
#    't',
#    ')',
#    '}'],
#   ['START',
#    '\\frac',
#    '{',
#    '(',
#    '1',
#    '-',
#    '\\gamma',
#    ')',
#    '\\log',
#    '(',
#    'T',
#    't',
#    '2',
#    ')',
#    '}',
#    '{',
#    'K',
#    '(',
#    '\\overline',
#    '{',
#    '\\theta',
#    '}',
#    'a',
#    '\\theta',
#    'a',
#    '*',
#    '+',
#    '\\zeta',
#    't',
#    ')',
#    '}']],
#  [['START',
#    '\\int',
#    '0',
#    '{',
#    '+',
#    '\\infty',
#    '}',
#    '(',
#    '1',
#    '-',
#    '\\cos',
#    '(',
#    'k',
#    'b',
#    '\\zeta',
#    ')',
#    ')',
#    '\\frac',
#    '{',
#    'd',
#    '\\zeta',
#    '}',
#    '{',
#    '\\zeta',
#    '{',
#    '3',
#    '-',
#    '\\alpha',
#    '}',
#    '}'],
#   ['START',
#    '\\frac',
#    '{',
#    '(',
#    'k',
#    'b',
#    ')',
#    '2',
#    'I',
#    '{',
#    '(',
#    '1',
#    ')',
#    '}',
#    '}',
#    '{',
#    '(',
#    '1',
#    '-',
#    '\\alpha',
#    ')',
#    '(',
#    '2',
#    '-',
#    '\\alpha',
#    ')',
#    '}']],
#  [['START',
#    '\\frac',
#    '{',
#    '\\delta',
#    '\\Gamma',
#    '{',
#    'e',
#    'f',
#    'f',
#    '}',
#    '}',
#    '{',
#    '\\deltaw',
#    '+',
#    '(',
#    'k',
#    '1',
#    ')',
#    '\\deltaW',
#    '-',
#    '{',
#    '\\mu',
#    '2',
#    '}',
#    '(',
#    'k',
#    '2',
#    ')',
#    '}'],
#   ['STARTi',
#    '\\frac',
#    '{',
#    'e',
#    '4',
#    '}',
#    '{',
#    '(',
#    '1',
#    '6',
#    '\\pi',
#    '2',
#    ')',
#    '2',
#    '{',
#    's',
#    'W',
#    '}',
#    '4',
#    '}',
#    '\\frac',
#    '{',
#    '{',
#    'm',
#    'H',
#    '}',
#    '2',
#    '}',
#    '{',
#    '{',
#    'M',
#    'W',
#    '}',
#    '3',
#    '}',
#    'k',
#    '1',
#    '{',
#    '\\mu',
#    '2',
#    '}',
#    'k',
#    '1',
#    '\\cdotk',
#    '1',
#    '\\Biggl',
#    '{',
#    '-',
#    '\\frac',
#    '{',
#    '7',
#    '1',
#    '}',
#    '{',
#    '1',
#    '9',
#    '2',
#    '}',
#    '+',
#    '\\frac',
#    '{',
#    '1',
#    '1',
#    '}',
#    '{',
#    '2',
#    '8',
#    '8',
#    '}',
#    '\\pi',
#    '2',
#    '\\Biggr',
#    '}']],
#  [['START',
#    '\\frac',
#    '{',
#    'd',
#    '}',
#    '{',
#    'd',
#    't',
#    '}',
#    '\\frac',
#    '{',
#    '\\delta',
#    '\\mathbb',
#    '{',
#    'L',
#    '}',
#    '}',
#    '{',
#    '\\delta',
#    '\\dot',
#    '{',
#    '\\chi',
#    '}',
#    '}'],
#   ['START',
#    '\\frac',
#    '{',
#    '\\delta',
#    '\\mathbb',
#    '{',
#    'L',
#    '}',
#    '}',
#    '{',
#    '\\delta',
#    '\\chi',
#    '}',
#    '\\']],
#  [['START',
#    '\\sum',
#    '{',
#    'k',
#    '}',
#    '\\theta',
#    '(',
#    'n',
#    '+',
#    'k',
#    'n',
#    ')',
#    '\\frac',
#    '{',
#    'u',
#    '{',
#    'n',
#    '+',
#    'k',
#    '}',
#    '}',
#    '{',
#    '(',
#    'n',
#    '+',
#    'k',
#    ')',
#    '}'],
#   ['START',
#    '\\sum',
#    '{',
#    'k',
#    '}',
#    '\\frac',
#    '{',
#    '(',
#    'n',
#    '+',
#    'k',
#    ')',
#    '}',
#    '{',
#    '(',
#    'n',
#    '-',
#    '1',
#    ')',
#    '}',
#    '\\delta',
#    'k',
#    '(',
#    'n',
#    '+',
#    'k',
#    ')',
#    '\\frac',
#    '{',
#    'u',
#    '{',
#    'n',
#    '+',
#    'k',
#    '}',
#    '}',
#    '{',
#    '(',
#    'n',
#    '+',
#    'k',
#    ')',
#    '}'],
#   ['START',
#    '\\frac',
#    '{',
#    '1',
#    '}',
#    '{',
#    'n',
#    '}',
#    '\\arg',
#    '\\tanh',
#    'n',
#    'u']],
#  [['START',
#    '\\sum',
#    '{',
#    'j',
#    '=',
#    '1',
#    '}',
#    '{',
#    '\\infty',
#    '}',
#    '\\frac',
#    '{',
#    '1',
#    '}',
#    '{',
#    '2',
#    'j',
#    '-',
#    '1',
#    '}',
#    '\\left',
#    '(',
#    '\\int',
#    '{',
#    '\\gamma',
#    '0',
#    '}',
#    '\\frac',
#    '{',
#    'd',
#    'p',
#    '}',
#    '{',
#    '\\pi',
#    '}',
#    '\\frac',
#    '{',
#    't',
#    'p',
#    '}',
#    '{',
#    '1',
#    '+',
#    'e',
#    '{',
#    '\\epsilon',
#    '(',
#    'p',
#    ')',
#    '}',
#    '}',
#    '\\right',
#    ')',
#    '{',
#    '2',
#    'j',
#    '-',
#    '1',
#    '}'],
#   ['START',
#    '\\ln',
#    '\\sqrt',
#    '{',
#    '{',
#    '\\frac',
#    '{',
#    '1',
#    '+',
#    'A',
#    '0',
#    '}',
#    '{',
#    '1',
#    '-',
#    'A',
#    '0',
#    '}',
#    '}',
#    '}',
#    '\\end',
#    '{',
#    's',
#    'p',
#    'l',
#    'i',
#    't',
#    '}']],
#  [['START',
#    '{',
#    '\\refstepcounter',
#    '{',
#    'e',
#    'q',
#    'u',
#    '}',
#    '}',
#    '\\forall',
#    '{',
#    '\\alpha',
#    '}',
#    '\\in',
#    'R',
#    '\\mathrm',
#    '{',
#    'm',
#    'a',
#    'x',
#    '}',
#    '\\exists',
#    '{',
#    '\\beta',
#    '}',
#    '{',
#    '\\gamma',
#    '}',
#    '\\in',
#    'R',
#    '\\setminus',
#    'R',
#    '\\mathrm',
#    '{',
#    'm',
#    'a',
#    'x',
#    '}',
#    '{',
#    '\\alpha',
#    '}'],
#   ['START', '{', '\\beta', '}', '+', '{', '\\gamma', '}']],
#  [['START',
#    '\\int',
#    '\\infty',
#    '0',
#    '\\omega',
#    'S',
#    '(',
#    '\\omega',
#    ')',
#    '{',
#    '\\mathrm',
#    '{',
#    'd',
#    '}',
#    '}',
#    '\\omega'],
#   ['START',
#    '\\frac',
#    '{',
#    '\\pi',
#    '}',
#    '{',
#    '2',
#    '}',
#    '\\n',
#    '\\text',
#    '{',
#    'a',
#    'n',
#    'd',
#    '}',
#    '\\int',
#    '\\infty',
#    '0',
#    '\\omega',
#    '3',
#    'S',
#    '(',
#    '\\omega',
#    ')',
#    '{',
#    '\\mathrm',
#    '{',
#    'd',
#    '}',
#    '}',
#    '\\omega'],
#   ['START',
#    '\\frac',
#    '{',
#    '\\pi',
#    '}',
#    '{',
#    '2',
#    '}',
#    '\\omega',
#    '2',
#    'R',
#    '\\']],
#  [['START',
#    '\\frac',
#    '{',
#    '1',
#    '+',
#    '\\dot',
#    '{',
#    '\\xi',
#    '}',
#    '1',
#    '1',
#    '+',
#    '\\dot',
#    '{',
#    '\\xi',
#    '}',
#    '2',
#    '-',
#    '(',
#    '1',
#    '+',
#    '\\dot',
#    '{',
#    '\\xi',
#    '}',
#    '1',
#    '\\cdot',
#    '\\dot',
#    '{',
#    '\\xi',
#    '}',
#    '2',
#    ')',
#    '}',
#    '{',
#    '\\left',
#    '(',
#    't',
#    '1',
#    '-',
#    't',
#    '2',
#    '\\right',
#    ')',
#    '2',
#    '+',
#    '\\left',
#    '(',
#    '\\xi',
#    '1',
#    '-',
#    '\\xi',
#    '2',
#    '\\right',
#    ')',
#    '2',
#    '}'],
#   ['START',
#    '\\frac',
#    '{',
#    '\\frac',
#    '{',
#    '1',
#    '}',
#    '{',
#    '2',
#    '}',
#    '\\left',
#    '(',
#    '\\dot',
#    '{',
#    '\\xi',
#    '}',
#    '(',
#    't',
#    '1',
#    ')',
#    '-',
#    '\\dot',
#    '{',
#    '\\xi',
#    '}',
#    '(',
#    't',
#    '2',
#    ')',
#    '\\right',
#    ')',
#    '2',
#    '}',
#    '{',
#    '\\left',
#    '(',
#    't',
#    '1',
#    '-',
#    't',
#    '2',
#    '\\right',
#    ')',
#    '2',
#    '}',
#    '+',
#    '\\mathcal',
#    '{',
#    'O',
#    '}',
#    '\\left',
#    '(',
#    '\\xi',
#    '4',
#    '\\right',
#    ')']],
#  [['START', '\\frac', '{', 'd', 'h', '}', '{', 'd', '\\mu', '}'],
#   ['START',
#    '-',
#    '\\frac',
#    '{',
#    'n',
#    '0',
#    '\\Delta',
#    'x',
#    '}',
#    '{',
#    '\\Delta',
#    'M',
#    '}']],
#  [['START', '\\mu', '0', '2', '-', '\\mu', '1', '2'],
#   ['START',
#    '4',
#    'q',
#    '(',
#    'q',
#    '-',
#    '1',
#    ')',
#    '-',
#    '4',
#    'p',
#    '(',
#    'p',
#    '+',
#    '1',
#    ')']],
#  [['START',
#    '\\tfrac',
#    '{',
#    'g',
#    '0',
#    '}',
#    '{',
#    '\\log',
#    '2',
#    'q',
#    '}',
#    '{',
#    '\\widetilde',
#    '}',
#    '{',
#    'a',
#    '}',
#    '{',
#    '0',
#    '1',
#    '}'],
#   ['START',
#    '\\tfrac',
#    '{',
#    'h',
#    '{',
#    '0',
#    '0',
#    '}',
#    '}',
#    '{',
#    '\\log',
#    '2',
#    'q',
#    '}',
#    '{',
#    '\\widetilde',
#    '}',
#    '{',
#    'a',
#    '}',
#    '{',
#    '0',
#    '0',
#    '}'],
#   ['START',
#    '\\tfrac',
#    '{',
#    'c',
#    '{',
#    '0',
#    '0',
#    '}',
#    '}',
#    '{',
#    '\\log',
#    '2',
#    'q',
#    '}']],
#  [['STARTUV', '*', '+', '\\Psi', '0'],
#   ['STARTK', 'i', 'U', 'o', 'V', '*', '+', '\\Psi', '0']],
#  [['START',
#    '\\sum',
#    '{',
#    'i',
#    '=',
#    '1',
#    '}',
#    '{',
#    '2',
#    'n',
#    '-',
#    '1',
#    '}',
#    'e',
#    'i',
#    '+',
#    'e',
#    '{',
#    '2',
#    'n',
#    '1',
#    '}',
#    '\\Lambda',
#    '2'],
#   ['START',
#    '\\sum',
#    '{',
#    'i',
#    '=',
#    '1',
#    '}',
#    '{',
#    '2',
#    'n',
#    '-',
#    '2',
#    '}',
#    'e',
#    '{',
#    'i',
#    '1',
#    '}',
#    '+',
#    'e',
#    '{',
#    '2',
#    'n',
#    '-',
#    '1',
#    '2',
#    '}',
#    '+',
#    'e',
#    '{',
#    '2',
#    'n',
#    '2',
#    '}']],
#  [['START',
#    '\\frac',
#    '{',
#    '1',
#    '}',
#    '{',
#    '2',
#    '}',
#    '\\Theta',
#    '1',
#    'q',
#    '(',
#    't',
#    ')',
#    'A',
#    '{',
#    '2',
#    '2',
#    '}',
#    '(',
#    't',
#    ')'],
#   ['START',
#    '-',
#    '\\frac',
#    '{',
#    '1',
#    '}',
#    '{',
#    '2',
#    '}',
#    '\\Theta',
#    '2',
#    'q',
#    '(',
#    't',
#    ')']],
#  [['START',
#    '\\mathop',
#    '{',
#    '\\min',
#    '{',
#    'y',
#    '{',
#    '*',
#    '}',
#    'x',
#    '\\neq',
#    '0',
#    '}',
#    '}',
#    '{',
#    'y',
#    '=',
#    '(',
#    'V',
#    'V',
#    '{',
#    '*',
#    '}',
#    ')',
#    '{',
#    '-',
#    '1',
#    '}',
#    'x',
#    '}',
#    '\\frac',
#    '{',
#    'y',
#    '{',
#    '*',
#    '}',
#    'A',
#    'x',
#    '}',
#    '{',
#    'y',
#    '{',
#    '*',
#    '}',
#    'x',
#    '}'],
#   ['START',
#    '\\lambda',
#    '{',
#    '1',
#    '}',
#    '\\mbox',
#    '{',
#    'a',
#    'n',
#    'd',
#    '}',
#    '\\mathop',
#    '{',
#    '\\max',
#    '{',
#    'y',
#    '{',
#    '*',
#    '}',
#    'x',
#    '\\neq',
#    '0',
#    '}',
#    '}',
#    '{',
#    'y',
#    '=',
#    '(',
#    'V',
#    'V',
#    '{',
#    '*',
#    '}',
#    ')',
#    '{',
#    '-',
#    '1',
#    '}',
#    'x',
#    '}',
#    '\\frac',
#    '{',
#    'y',
#    '{',
#    '*',
#    '}',
#    'A',
#    'x',
#    '}',
#    '{',
#    'y',
#    '{',
#    '*',
#    '}',
#    'x',
#    '}']],
#  [['START',
#    '\\frac',
#    '{',
#    '\\sqrt',
#    '{',
#    'D',
#    '(',
#    '\\nu',
#    'n',
#    ')',
#    'D',
#    '(',
#    '-',
#    '\\nu',
#    'n',
#    ')',
#    '}',
#    '}',
#    '{',
#    '\\sqrt',
#    '{',
#    '1',
#    '+',
#    'D',
#    '(',
#    '\\nu',
#    'n',
#    ')',
#    '+',
#    'D',
#    '(',
#    '-',
#    '\\nu',
#    'n',
#    ')',
#    '}',
#    '}'],
#   ['START',
#    '{',
#    '\\sqrt',
#    '{',
#    'D',
#    '(',
#    '\\nu',
#    'n',
#    ')',
#    'D',
#    '(',
#    '-',
#    '\\nu',
#    'n',
#    ')',
#    '}',
#    '}',
#    '-',
#    '\\frac',
#    '{',
#    '1',
#    '}',
#    '{',
#    '2',
#    '}',
#    '\\frac',
#    '{',
#    '\\sqrt',
#    '{',
#    'D',
#    '(',
#    '\\nu',
#    'n',
#    ')',
#    'D',
#    '(',
#    '-',
#    '\\nu',
#    'n',
#    ')',
#    '}',
#    '}',
#    '{',
#    '(',
#    '2',
#    'i',
#    '\\nu',
#    'n',
#    ')',
#    '{',
#    'N',
#    '+',
#    '1',
#    '}',
#    '}']],
#  [['START',
#    '{',
#    '\\label',
#    '}',
#    '{',
#    'b',
#    'b',
#    '6',
#    '8',
#    '}',
#    '\\begin',
#    '{',
#    'a',
#    'l',
#    'i',
#    'g',
#    'n',
#    'e',
#    'd',
#    '}',
#    '-',
#    '\\frac',
#    '{',
#    '1',
#    '}',
#    '{',
#    '2',
#    '}',
#    '\\int',
#    '(',
#    'e',
#    '+',
#    'u',
#    '2',
#    ')',
#    '\\ln',
#    '(',
#    'e',
#    '+',
#    'u',
#    '2',
#    ')',
#    'G',
#    'd',
#    'x',
#    '\\'],
#   ['START',
#    '\\frac',
#    '{',
#    '\\varepsilon',
#    '}',
#    '{',
#    '4',
#    '}',
#    '\\int',
#    '{',
#    '\\rho',
#    '}',
#    '{',
#    '-',
#    '1',
#    '}',
#    'h',
#    '{',
#    '\\varepsilon',
#    '}',
#    '(',
#    '{',
#    '\\rho',
#    '}',
#    ')',
#    '{',
#    '\\nabla',
#    '}',
#    '{',
#    '\\rho',
#    '}',
#    '2',
#    '(',
#    'e',
#    '+',
#    'u',
#    '2',
#    ')',
#    '\\ln',
#    '(',
#    'e',
#    '+',
#    'u',
#    '2',
#    ')',
#    'd',
#    'x',
#    '+',
#    '{',
#    '\\varepsilon',
#    '}',
#    '\\int',
#    'h',
#    '{',
#    '\\varepsilon',
#    '}',
#    '(',
#    '{',
#    '\\rho',
#    '}',
#    ')',
#    '{',
#    '\\nabla',
#    '}',
#    '{',
#    '\\rho',
#    '}',
#    '\\cdot',
#    '{',
#    '\\nabla',
#    '}',
#    'u',
#    '\\cdot',
#    'u',
#    'd',
#    'x',
#    '+',
#    '{',
#    '\\varepsilon',
#    '}',
#    '\\int',
#    'h',
#    '{',
#    '\\varepsilon',
#    '}',
#    '(',
#    '{',
#    '\\rho',
#    '}',
#    ')',
#    '\\ln',
#    '(',
#    'e',
#    '+',
#    'u',
#    '2',
#    ')',
#    '{',
#    '\\nabla',
#    '}',
#    '{',
#    '\\rho',
#    '}',
#    '\\cdot',
#    '{',
#    '\\nabla',
#    '}',
#    'u',
#    '\\cdot',
#    'u',
#    'd',
#    'x',
#    '\\ge',
#    '\\frac',
#    '{',
#    '\\varepsilon',
#    '}',
#    '{',
#    '8',
#    '}',
#    '\\int',
#    '{',
#    '\\rho',
#    '}',
#    '{',
#    '-',
#    '1',
#    '}',
#    'h',
#    '{',
#    '\\varepsilon',
#    '}',
#    '(',
#    '{',
#    '\\rho',
#    '}',
#    ')',
#    '{',
#    '\\nabla',
#    '}',
#    '{',
#    '\\rho',
#    '}',
#    '2',
#    '(',
#    'e',
#    '+',
#    'u',
#    '2',
#    ')',
#    '\\ln',
#    '(',
#    'e',
#    '+',
#    'u',
#    '2',
#    ')',
#    'd',
#    'x',
#    '-',
#    '{',
#    '\\varepsilon',
#    '}',
#    '\\int',
#    '{',
#    '\\rho',
#    '}',
#    'h',
#    '{',
#    '\\varepsilon',
#    '}',
#    '(',
#    '{',
#    '\\rho',
#    '}',
#    ')',
#    '{',
#    '\\nabla',
#    '}',
#    'u',
#    '2',
#    'd',
#    'x',
#    '-',
#    '{',
#    '\\varepsilon',
#    '}',
#    '\\int',
#    '{',
#    '\\rho',
#    '}',
#    '{',
#    '-',
#    '1',
#    '}',
#    'h',
#    '{',
#    '\\varepsilon',
#    '}',
#    '(',
#    '{',
#    '\\rho',
#    '}',
#    ')',
#    '{',
#    '\\nabla',
#    '}',
#    '{',
#    '\\rho',
#    '}',
#    '2',
#    'u',
#    '2',
#    'd',
#    'x',
#    '-',
#    '2',
#    '{',
#    '\\varepsilon',
#    '}',
#    '(',
#    '{',
#    '\\alpha',
#    '}',
#    '+',
#    '2',
#    ')',
#    '\\int',
#    'h',
#    '{',
#    '\\varepsilon',
#    '}',
#    '(',
#    '{',
#    '\\rho',
#    '}',
#    ')',
#    '\\ln',
#    '(',
#    'e',
#    '+',
#    'u',
#    '2',
#    ')',
#    '{',
#    '\\nabla',
#    '}',
#    'u',
#    '2',
#    'd',
#    'x',
#    '\\end',
#    '{',
#    'a',
#    'l',
#    'i',
#    'g',
#    'n',
#    'e',
#    'd',
#    '}']],
#  [['START',
#    '\\begin',
#    '{',
#    't',
#    'i',
#    'k',
#    'z',
#    'p',
#    'i',
#    'c',
#    't',
#    'u',
#    'r',
#    'e',
#    '}',
#    'b',
#    'a',
#    's',
#    'e',
#    'l',
#    'i',
#    'n',
#    'e',
#    '=',
#    '0',
#    's',
#    'c',
#    'a',
#    'l',
#    'e',
#    '=',
#    '1',
#    '2',
#    '{',
#    '\\fill',
#    's',
#    'h',
#    'a',
#    'd',
#    'e',
#    'd',
#    '(',
#    '-',
#    '0',
#    '8',
#    '0',
#    ')',
#    '-',
#    '-',
#    '(',
#    '-',
#    '0',
#    '8',
#    '0',
#    '6',
#    ')',
#    'a',
#    'r',
#    'c',
#    '(',
#    '1',
#    '8',
#    '0',
#    '0',
#    '0',
#    '8',
#    ')',
#    '-',
#    '-',
#    '(',
#    '0',
#    '8',
#    '0',
#    ')',
#    '-',
#    '-',
#    '(',
#    '0',
#    '2',
#    '0',
#    ')',
#    '-',
#    '-',
#    '(',
#    '0',
#    '2',
#    '1',
#    ')',
#    '-',
#    '-',
#    '(',
#    '-',
#    '0',
#    '2',
#    '1',
#    ')',
#    '-',
#    '-',
#    '(',
#    '-',
#    '0',
#    '2',
#    '0',
#    ')',
#    '\\draw',
#    '(',
#    '-',
#    '0',
#    '8',
#    '0',
#    ')',
#    '-',
#    '-',
#    '(',
#    '-',
#    '0',
#    '8',
#    '0',
#    '6',
#    ')',
#    'a',
#    'r',
#    'c',
#    '(',
#    '1',
#    '8',
#    '0',
#    '0',
#    '0',
#    '8',
#    ')',
#    '-',
#    '-',
#    '(',
#    '0',
#    '8',
#    '0',
#    ')',
#    '\\draw',
#    '(',
#    '-',
#    '0',
#    '2',
#    '0',
#    ')',
#    '-',
#    '-',
#    '(',
#    '-',
#    '0',
#    '2',
#    '1',
#    ')',
#    '\\draw',
#    '(',
#    '0',
#    '2',
#    '0',
#    ')',
#    '-',
#    '-',
#    '(',
#    '0',
#    '2',
#    '1',
#    ')',
#    '\\node',
#    'a',
#    't',
#    '(',
#    '0',
#    '4',
#    '5',
#    '0',
#    '5',
#    ')',
#    '{',
#    '\\footnotesize',
#    '5',
#    '}',
#    '{',
#    '\\filldraw',
#    'f',
#    'i',
#    'l',
#    'l',
#    '=',
#    'w',
#    'h',
#    'i',
#    't',
#    'e',
#    't',
#    'h',
#    'i',
#    'c',
#    'k',
#    '(',
#    '0',
#    '1',
#    ')',
#    'e',
#    'l',
#    'l',
#    'i',
#    'p',
#    's',
#    'e',
#    '(',
#    '3',
#    'm',
#    'm',
#    'a',
#    'n',
#    'd',
#    '3',
#    'm',
#    'm',
#    ')',
#    '\\node',
#    'a',
#    't',
#    '(',
#    '0',
#    '1',
#    ')',
#    '{',
#    '\\Large',
#    'T',
#    '}',
#    '\\path',
#    '(',
#    '0',
#    '1',
#    ')',
#    '+',
#    '+',
#    '(',
#    '-',
#    '9',
#    '0',
#    '0',
#    '3',
#    '7',
#    ')',
#    'n',
#    'o',
#    'd',
#    'e',
#    '{',
#    '\\star',
#    '}',
#    '}',
#    '}',
#    '\\draw',
#    '(',
#    '0',
#    '0',
#    ')',
#    '-',
#    '-',
#    '(',
#    '0',
#    '-',
#    '0',
#    '5',
#    ')',
#    '\\node',
#    'a',
#    'n',
#    'c',
#    'h',
#    'o',
#    'r',
#    '=',
#    'w',
#    'e',
#    's',
#    't',
#    'a',
#    't',
#    '(',
#    '0',
#    '-',
#    '0',
#    '3',
#    '5',
#    ')',
#    '{',
#    '\\footnotesize',
#    '8',
#    '}',
#    '{',
#    '\\filldraw',
#    'f',
#    'i',
#    'l',
#    'l',
#    '=',
#    'w',
#    'h',
#    'i',
#    't',
#    'e',
#    't',
#    'h',
#    'i',
#    'c',
#    'k',
#    '(',
#    '-',
#    '1',
#    '-',
#    '0',
#    '2',
#    ')',
#    'r',
#    'e',
#    'c',
#    't',
#    'a',
#    'n',
#    'g',
#    'l',
#    'e',
#    '(',
#    '1',
#    '0',
#    '2',
#    ')',
#    '\\node',
#    'a',
#    't',
#    '(',
#    '0',
#    '0',
#    ')',
#    '{',
#    '{',
#    'f',
#    '{',
#    '(',
#    '{',
#    '8',
#    '}',
#    ')',
#    '}',
#    '}',
#    '}',
#    '}',
#    '\\end',
#    '{',
#    't',
#    'i',
#    'k',
#    'z',
#    'p',
#    'i',
#    'c',
#    't',
#    'u',
#    'r',
#    'e',
#    '}'],
#   ['STARTx',
#    '1',
#    '\\cdot',
#    '\\begin',
#    '{',
#    't',
#    'i',
#    'k',
#    'z',
#    'p',
#    'i',
#    'c',
#    't',
#    'u',
#    'r',
#    'e',
#    '}',
#    'b',
#    'a',
#    's',
#    'e',
#    'l',
#    'i',
#    'n',
#    'e',
#    '=',
#    '0',
#    's',
#    'c',
#    'a',
#    'l',
#    'e',
#    '=',
#    '1',
#    '2',
#    '{',
#    '\\draw',
#    '(',
#    '-',
#    '0',
#    '5',
#    '1',
#    ')',
#    '-',
#    '-',
#    '(',
#    '-',
#    '0',
#    '5',
#    '0',
#    ')',
#    '\\node',
#    'a',
#    'n',
#    'c',
#    'h',
#    'o',
#    'r',
#    '=',
#    'w',
#    'e',
#    's',
#    't',
#    'a',
#    't',
#    '(',
#    '-',
#    '0',
#    '5',
#    '0',
#    '5',
#    ')',
#    '{',
#    '\\footnotesize',
#    '4',
#    '}',
#    '\\draw',
#    '(',
#    '0',
#    '5',
#    '1',
#    ')',
#    '-',
#    '-',
#    '(',
#    '0',
#    '5',
#    '0',
#    ')',
#    '\\node',
#    'a',
#    'n',
#    'c',
#    'h',
#    'o',
#    'r',
#    '=',
#    'w',
#    'e',
#    's',
#    't',
#    'a',
#    't',
#    '(',
#    '0',
#    '5',
#    '0',
#    '5',
#    ')',
#    '{',
#    '\\footnotesize',
#    '4',
#    '}',
#    '}',
#    '{',
#    '\\node',
#    'a',
#    'n',
#    'c',
#    'h',
#    'o',
#    'r',
#    '=',
#    's',
#    'o',
#    'u',
#    't',
#    'h',
#    'a',
#    't',
#    '(',
#    '0',
#    '1',
#    ')',
#    '{',
#    '\\footnotesize',
#    '2',
#    '}',
#    '\\draw',
#    '(',
#    '-',
#    '0',
#    '5',
#    '1',
#    ')',
#    '-',
#    '-',
#    '(',
#    '0',
#    '5',
#    '1',
#    ')',
#    '\\foreach',
#    '\\x',
#    'i',
#    'n',
#    '{',
#    '-',
#    '0',
#    '5',
#    '0',
#    '5',
#    '}',
#    '{',
#    '{',
#    '\\filldraw',
#    'f',
#    'i',
#    'l',
#    'l',
#    '=',
#    'w',
#    'h',
#    'i',
#    't',
#    'e',
#    't',
#    'h',
#    'i',
#    'c',
#    'k',
#    '(',
#    '\\x',
#    '1',
#    ')',
#    'e',
#    'l',
#    'l',
#    'i',
#    'p',
#    's',
#    'e',
#    '(',
#    '3',
#    'm',
#    'm',
#    'a',
#    'n',
#    'd',
#    '3',
#    'm',
#    'm',
#    ')',
#    '\\node',
#    'a',
#    't',
#    '(',
#    '-',
#    '5',
#    '1',
#    ')',
#    '{',
#    '\\Large',
#    'T',
#    '}',
#    '\\node',
#    'a',
#    't',
#    '(',
#    '5',
#    '1',
#    ')',
#    '{',
#    '\\Large',
#    'T',
#    '}',
#    '\\path',
#    '(',
#    '\\x',
#    '1',
#    ')',
#    '+',
#    '+',
#    '(',
#    '9',
#    '0',
#    '0',
#    '3',
#    '7',
#    ')',
#    'n',
#    'o',
#    'd',
#    'e',
#    '{',
#    '\\star',
#    '}',
#    '}',
#    '}',
#    '}',
#    '\\draw',
#    '(',
#    '0',
#    '0',
#    ')',
#    '-',
#    '-',
#    '(',
#    '0',
#    '-',
#    '0',
#    '5',
#    ')',
#    '\\node',
#    'a',
#    'n',
#    'c',
#    'h',
#    'o',
#    'r',
#    '=',
#    'w',
#    'e',
#    's',
#    't',
#    'a',
#    't',
#    '(',
#    '0',
#    '-',
#    '0',
#    '3',
#    '5',
#    ')',
#    '{',
#    '\\footnotesize',
#    '8',
#    '}',
#    '{',
#    '\\filldraw',
#    'f',
#    'i',
#    'l',
#    'l',
#    '=',
#    'w',
#    'h',
#    'i',
#    't',
#    'e',
#    't',
#    'h',
#    'i',
#    'c',
#    'k',
#    '(',
#    '-',
#    '1',
#    '-',
#    '0',
#    '2',
#    ')',
#    'r',
#    'e',
#    'c',
#    't',
#    'a',
#    'n',
#    'g',
#    'l',
#    'e',
#    '(',
#    '1',
#    '0',
#    '2',
#    ')',
#    '\\node',
#    'a',
#    't',
#    '(',
#    '0',
#    '0',
#    ')',
#    '{',
#    '{',
#    'f',
#    '{',
#    '(',
#    '{',
#    '8',
#    '}',
#    ')',
#    '}',
#    '}',
#    '}',
#    '}',
#    '\\end',
#    '{',
#    't',
#    'i',
#    'k',
#    'z',
#    'p',
#    'i',
#    'c',
#    't',
#    'u',
#    'r',
#    'e',
#    '}',
#    '+',
#    'x',
#    '2',
#    '\\cdot',
#    '\\begin',
#    '{',
#    't',
#    'i',
#    'k',
#    'z',
#    'p',
#    'i',
#    'c',
#    't',
#    'u',
#    'r',
#    'e',
#    '}',
#    'b',
#    'a',
#    's',
#    'e',
#    'l',
#    'i',
#    'n',
#    'e',
#    '=',
# ...
#    'd',
#    'v',
#    'd',
#    'S',
#    '(',
#    'x',
#    ')',
#    'd',
#    's',
#    '\\n'],
#   ['START',
#    '\\int',
#    '0',
#    't',
#    '\\iint',
#    '{',
#    '{',
#    '{',
#    '\\Omega',
#    '}',
#    '}',
#    '{',
#    '\\mathbf',
#    '{',
#    'R',
#    '}',
#    '}',
#    'N',
#    '}',
#    '(',
#    'v',
#    '{',
#    '\\otimes',
#    '2',
#    '}',
#    '{',
#    '{',
#    '\\nabla',
#    '}',
#    '}',
#    'x',
#    '\\xi',
#    '(',
#    'x',
#    ')',
#    ')',
#    'F',
#    '{',
#    '{',
#    '{',
#    '\\epsilon',
#    '}',
#    '}',
#    'm',
#    '}',
#    '(',
#    's',
#    'x',
#    'v',
#    ')',
#    'd',
#    'v',
#    'd',
#    'x',
#    'd',
#    's',
#    '\\n',
#    '+',
#    '{',
#    '{',
#    '\\epsilon',
#    '}',
#    '}',
#    '\\iint',
#    '{',
#    '{',
#    '{',
#    '\\Omega',
#    '}',
#    '}',
#    '{',
#    '\\mathbf',
#    '{',
#    'R',
#    '}',
#    '}',
#    'N',
#    '}',
#    '\\xi',
#    '(',
#    'x',
#    ')',
#    '\\cdot',
#    'v',
#    'F',
#    '{',
#    'i',
#    'n',
#    '}',
#    '{',
#    '{',
#    '{',
#    '\\epsilon',
#    '}',
#    '}',
#    'm',
#    '}',
#    '(',
#    'x',
#    'v',
#    ')',
#    'd',
#    'v',
#    'd',
#    'x',
#    '\\n',
#    '-',
#    '{',
#    '{',
#    '\\epsilon',
#    '}',
#    '}',
#    '\\iint',
#    '{',
#    '{',
#    '{',
#    '\\Omega',
#    '}',
#    '}',
#    '{',
#    '\\mathbf',
#    '{',
#    'R',
#    '}',
#    '}',
#    'N',
#    '}',
#    '\\xi',
#    '(',
#    'x',
#    ')',
#    '\\cdot',
#    'v',
#    'F',
#    '{',
#    '{',
#    '{',
#    '\\epsilon',
#    '}',
#    '}',
#    'm',
#    '}',
#    '(',
#    't',
#    'x',
#    'v',
#    ')',
#    'd',
#    'v',
#    'd',
#    'x',
#    '\\end',
#    '{',
#    'a',
#    'l',
#    'i',
#    'g',
#    'n',
#    'e',
#    'd',
#    '}']],
#  [['START',
#    '\\begin',
#    '{',
#    'a',
#    'l',
#    'i',
#    'g',
#    'n',
#    'e',
#    'd',
#    '}',
#    'z',
#    '2',
#    '{',
#    '{',
#    '\\mathfrak',
#    '{',
#    'c',
#    '}',
#    '}',
#    '}',
#    '{',
#    '0',
#    'n',
#    '0',
#    '+',
#    '2',
#    '}',
#    '(',
#    'z',
#    '\\zeta',
#    '1',
#    ')',
#    '{',
#    'n',
#    '0',
#    '}',
#    'w',
#    '4',
#    '+',
#    'z',
#    '{',
#    '{',
#    '\\mathfrak',
#    '{',
#    'c',
#    '}',
#    '}',
#    '}',
#    '{',
#    '1',
#    'n',
#    '1',
#    '+',
#    '1',
#    '}',
#    '(',
#    '{',
#    'z',
#    '}',
#    '\\zeta',
#    '1',
#    ')',
#    '{',
#    'n',
#    '1',
#    '}',
#    'w',
#    '3',
#    'x',
#    '+',
#    '{',
#    '{',
#    '\\mathfrak',
#    '{',
#    'c',
#    '}',
#    '}',
#    '}',
#    '{',
#    '2',
#    'n',
#    '2',
#    '}',
#    '(',
#    '{',
#    'z',
#    '}',
#    '\\zeta',
#    '1',
#    ')',
#    '{',
#    'n',
#    '2',
#    '}',
#    'w',
#    '2',
#    'x',
#    '2',
#    '+',
#    '\\zeta',
#    '1',
#    '{',
#    '{',
#    '\\mathfrak',
#    '{',
#    'c',
#    '}',
#    '}',
#    '}',
#    '{',
#    '3',
#    'n',
#    '3',
#    '}',
#    '(',
#    '{',
#    'z',
#    '}',
#    '\\zeta',
#    '1',
#    ')',
#    '{',
#    'n',
#    '3',
#    '}',
#    'w',
#    'x',
#    '3',
#    '\\cr'],
#   ['START',
#    'y',
#    '2',
#    '+',
#    '\\zeta',
#    '1',
#    '{',
#    '{',
#    '\\mathfrak',
#    '{',
#    'b',
#    '}',
#    '}',
#    '}',
#    '{',
#    '0',
#    'm',
#    '0',
#    '}',
#    '(',
#    '{',
#    'z',
#    '}',
#    '\\zeta',
#    '1',
#    ')',
#    '{',
#    'm',
#    '0',
#    '}',
#    'x',
#    '2',
#    'y',
#    '+',
#    '{',
#    '{',
#    '\\mathfrak',
#    '{',
#    'b',
#    '}',
#    '}',
#    '}',
#    '{',
#    '1',
#    'm',
#    '1',
#    '}',
#    '(',
#    '{',
#    'z',
#    '}',
#    '\\zeta',
#    '1',
#    ')',
#    '{',
#    'm',
#    '1',
#    '}',
#    'y',
#    'w',
#    'x',
#    '+',
#    'z',
#    '{',
#    '{',
#    '\\mathfrak',
#    '{',
#    'b',
#    '}',
#    '}',
#    '}',
#    '{',
#    '2',
#    'm',
#    '2',
#    '+',
#    '1',
#    '}',
#    '(',
#    '{',
#    'z',
#    '}',
#    '\\zeta',
#    '1',
#    ')',
#    '{',
#    'm',
#    '2',
#    '}',
#    'w',
#    '2',
#    'y',
#    '\\end',
#    '{',
#    'a',
#    'l',
#    'i',
#    'g',
#    'n',
#    'e',
#    'd',
#    '}']],
#  [['START',
#    'p',
#    '{',
#    '3',
#    '}',
#    '-',
#    '\\tfrac',
#    '1',
#    '2',
#    '(',
#    'p',
#    '{',
#    '1',
#    '}',
#    '+',
#    'p',
#    '{',
#    '2',
#    '}',
#    ')',
#    'y'],
#   ['START',
#    '\\tfrac',
#    '{',
#    '\\sqrt',
#    '{',
#    '3',
#    '}',
#    '}',
#    '2',
#    '(',
#    'p',
#    '{',
#    '1',
#    '}',
#    '-',
#    'p',
#    '{',
#    '2',
#    '}',
#    ')',
#    '\\nz'],
#   ['START',
#    'p',
#    '{',
#    '0',
#    '}',
#    '-',
#    '\\tfrac',
#    '1',
#    '2',
#    '(',
#    'p',
#    '{',
#    '4',
#    '}',
#    '+',
#    'p',
#    '{',
#    '5',
#    '}',
#    ')',
#    '\\eta'],
#   ['START',
#    '\\tfrac',
#    '{',
#    '\\sqrt',
#    '{',
#    '3',
#    '}',
#    '}',
#    '2',
#    '(',
#    'p',
#    '{',
#    '4',
#    '}',
#    '-',
#    'p',
#    '{',
#    '5',
#    '}',
#    ')',
#    '\\end',
#    '{',
#    'a',
#    'l',
#    'i',
#    'g',
#    'n',
#    'e',
#    'd',
#    '}']],
#  [['STARTc',
#    '\\frac',
#    '{',
#    '\\partial',
#    '}',
#    '{',
#    '\\partialc',
#    '}',
#    'c',
#    '\\frac',
#    '{',
#    '\\partial',
#    '\\logZ',
#    '}',
#    '{',
#    '\\partialc',
#    '}'],
#   ['STARTc',
#    '\\frac',
#    '{',
#    '\\partial',
#    '}',
#    '{',
#    '\\partialc',
#    '}',
#    '\\frac',
#    '{',
#    'c',
#    '}',
#    '{',
#    'Z',
#    '}',
#    '\\frac',
#    '{',
#    '\\partialZ',
#    '}',
#    '{',
#    '\\partialc',
#    '}']],
#  [['START',
#    '\\frac',
#    '{',
#    '1',
#    '}',
#    '{',
#    '2',
#    '}',
#    '\\langle',
#    '\\psi',
#    '\\psi',
#    '+',
#    '\\psi',
#    '\\psi',
#    '\\rangle'],
#   ['START',
#    '-',
#    '2',
#    '\\mathcal',
#    '{',
#    'H',
#    '}',
#    '\\delta',
#    '\\langle',
#    '\\psi',
#    '2',
#    '\\rangle',
#    '-',
#    '\\mathcal',
#    '{',
#    'H',
#    '}',
#    '2',
#    '(',
#    '\\delta',
#    '-',
#    '\\epsilon',
#    ')',
#    '\\partial',
#    '\\eta',
#    '\\langle',
#    '\\psi',
#    '2',
#    '\\rangle',
#    '+',
#    '\\frac',
#    '{',
#    '1',
#    '}',
#    '{',
#    '2',
#    '}',
#    '\\partial',
#    '\\eta',
#    '\\big',
#    '\\langle',
#    '\\psi',
#    '\\nabla',
#    '2',
#    '\\psi',
#    '\\big',
#    '\\rangle']],
#  [['START',
#    '-',
#    '\\rho',
#    '\\vec',
#    '{',
#    '\\nabla',
#    '}',
#    '{',
#    '\\cal',
#    'V',
#    '}',
#    '+',
#    '\\vec',
#    '{',
#    'F',
#    '}',
#    '{',
#    'r',
#    'a',
#    'd',
#    '}'],
#   ['START',
#    '\\frac',
#    '{',
#    'V',
#    '{',
#    '\\star',
#    '}',
#    '2',
#    '}',
#    '{',
#    'r',
#    '{',
#    '\\star',
#    '}',
#    '}',
#    '\\rho',
#    '\\left',
#    '(',
#    'Q',
#    '\\left',
#    '(',
#    'R',
#    '\\right',
#    ')',
#    '-',
#    '\\frac',
#    '{',
#    '\\nu',
#    '2',
#    '}',
#    '{',
#    '2',
#    'R',
#    '2',
#    '}',
#    '\\right',
#    ')',
#    '\\hat',
#    '{',
#    'r',
#    '}',
#    '\\']],
#  [['START',
#    '\\sqrt',
#    '{',
#    '-',
#    '1',
#    '+',
#    '\\dfrac',
#    '{',
#    '1',
#    '}',
#    '{',
#    '2',
#    '}',
#    'i',
#    '}'],
#   ['START',
#    '\\dfrac',
#    '{',
#    '1',
#    '}',
#    '{',
#    '\\sqrt',
#    '{',
#    '2',
#    '}',
#    '}',
#    '\\left',
#    '(',
#    '\\sqrt',
#    '{',
#    '\\dfrac',
#    '{',
#    '\\sqrt',
#    '{',
#    '5',
#    '}',
#    '}',
#    '{',
#    '2',
#    '}',
#    '+',
#    '1',
#    '}',
#    '+',
#    'i',
#    '\\sqrt',
#    '{',
#    '\\dfrac',
#    '{',
#    '\\sqrt',
#    '{',
#    '5',
#    '}',
#    '}',
#    '{',
#    '2',
#    '}',
#    '-',
#    '1',
#    '}',
#    '\\right',
#    ')',
#    'e',
#    '{',
#    'n',
#    'i',
#    '\\pi',
#    '}']],
#  [['START',
#    '\\frac',
#    '{',
#    '\\partial',
#    'W',
#    '}',
#    '{',
#    '\\partial',
#    'g',
#    '{',
#    '\\pm',
#    '}',
#    '}'],
#   ['START',
#    '+',
#    '\\frac',
#    '{',
#    'N',
#    '{',
#    '\\pm',
#    '}',
#    '}',
#    '{',
#    'g',
#    '{',
#    '\\pm',
#    '}',
#    '}',
#    '-',
#    '\\frac',
#    '{',
#    'V',
#    '\\sigma',
#    '2',
#    '}',
#    '{',
#    '4',
#    '}',
#    '-',
#    '\\sigma',
#    '2',
#    'g',
#    '{',
#    '\\mp',
#    '}',
#    'T',
#    'r',
#    '(',
#    '\\frac',
#    '{',
#    'K',
#    '2',
#    '}',
#    '{',
#    '-',
#    '\\hat',
#    '{',
#    'D',
#    '}',
#    '2',
#    '+',
#    'g',
#    '+',
#    'g',
#    '-',
#    '\\sigma',
#    '2',
#    'K',
#    '2',
#    '}',
#    ')']],
#  [['START',
#    '\\frac',
#    '{',
#    '\\widetilde',
#    '\\tau',
#    '1',
#    '(',
#    'w',
#    '\\barw',
#    ')',
#    '}',
#    '{',
#    '(',
#    '\\barz',
#    '-',
#    '\\barw',
#    ')',
#    '{',
#    '1',
#    '2',
#    '}',
#    '}',
#    '\\bar',
#    '{',
#    '\\partial',
#    '}',
#    '\\widetilde',
#    '{',
#    '\\phi',
#    '}',
#    '{',
#    '1',
#    '\\dagger',
#    '}',
#    '(',
#    '\\barz',
#    ')',
#    '\\sigma',
#    '1',
#    '(',
#    'w',
#    '\\bar',
#    '{',
#    'w',
#    '}',
#    ')'],
#   ['START',
#    '\\frac',
#    '{',
#    '\\widetilde',
#    '\\tau',
#    '1',
#    '(',
#    'w',
#    '\\barw',
#    ')',
#    '}',
#    '{',
#    '(',
#    '\\barz',
#    '-',
#    '\\barw',
#    ')',
#    '{',
#    '1',
#    '2',
#    '}',
#    '}']],
#  [['START',
#    '\\int',
#    '{',
#    '0',
#    '}',
#    '{',
#    '1',
#    '}',
#    '\\phi',
#    'd',
#    '\\hat',
#    'z',
#    '\\'],
#   ['START',
#    '\\int',
#    '{',
#    '0',
#    '}',
#    '{',
#    '1',
#    '}',
#    '\\left',
#    '\\left',
#    '(',
#    '\\frac',
#    '{',
#    'd',
#    '2',
#    'w',
#    '}',
#    '{',
#    'd',
#    '\\hat',
#    'z',
#    '2',
#    '}',
#    '\\right',
#    ')',
#    '2',
#    '+',
#    '2',
#    '\\left',
#    '(',
#    '\\frac',
#    '{',
#    'd',
#    'w',
#    '}',
#    '{',
#    'd',
#    '\\hat',
#    'z',
#    '}',
#    '\\right',
#    ')',
#    '2',
#    '+',
#    'w',
#    '2',
#    '\\right',
#    'd',
#    '\\hat',
#    'z',
#    '\\']],
#  [['START', '\\int', '\\Sigma', '\\delta', 'f', 'd', 'n', 'x'],
#   ['START',
#    '\\int',
#    '\\Sigma',
#    '\\delta',
#    'z',
#    'A',
#    '\\frac',
#    '{',
#    '\\delta',
#    'f',
#    '}',
#    '{',
#    '\\delta',
#    'z',
#    'A',
#    '}',
#    'd',
#    'n',
#    'x',
#    '+',
#    '\\oint',
#    '{',
#    '{',
#    '\\partial',
#    '}',
#    '\\Sigma',
#    '}',
#    'I',
#    'n',
#    '(',
#    'f',
#    'd',
#    'n',
#    'x',
#    ')']],
#  [['START',
#    '\\left',
#    '\\frac',
#    '{',
#    'M',
#    'L',
#    '}',
#    '{',
#    'M',
#    '7',
#    '}',
#    '\\right',
#    '{',
#    'M',
#    '{',
#    'G',
#    'U',
#    'T',
#    '}',
#    '}'],
#   ['START', '-', '\\frac', '{', '7', '}', '{', '3', '}']],
#  [['START',
#    '\\pi',
#    '-',
#    '\\Theta',
#    '{',
#    '-',
#    '\\sigma',
#    '}',
#    '-',
#    '\\rho',
#    '\\Psi',
#    '{',
#    '\\sigma',
#    '}',
#    '\\rho'],
#   ['START',
#    '2',
#    '\\pi',
#    '-',
#    '\\Psi',
#    '{',
#    '-',
#    '\\sigma',
#    '}',
#    '-',
#    '\\rho']],
#  [['START',
#    '\\bmg',
#    '{',
#    '\\bmD',
#    '(',
#    'a',
#    ')',
#    '}',
#    '+',
#    '\\bmC',
#    '(',
#    'c',
#    ')',
#    '\\bmg',
#    '{',
#    '\\bmC',
#    '(',
#    'c',
#    ')',
#    '}'],
#   ['START',
#    '\\bmg',
#    '{',
#    '\\bmC',
#    '(',
#    'c',
#    ')',
#    '}',
#    '-',
#    '\\bmC',
#    '(',
#    'c',
#    ')']],
#  [['START',
#    '\\frac',
#    '{',
#    '1',
#    '}',
#    '{',
#    'p',
#    '{',
#    'i',
#    'i',
#    '}',
#    '}',
#    '\\sum',
#    '{',
#    'j',
#    '=',
#    '1',
#    '}',
#    '{',
#    'n',
#    '}',
#    'p',
#    '{',
#    'j',
#    'i',
#    '}'],
#   ['START',
#    '\\frac',
#    '{',
#    '1',
#    '}',
#    '{',
#    'p',
#    '{',
#    'i',
#    'i',
#    '}',
#    '}',
#    '\\mathcal',
#    '{',
#    'P',
#    '}',
#    'i']],
#  [['START',
#    'r',
#    '{',
#    '\\mathrm',
#    '{',
#    'v',
#    '}',
#    '2',
#    '}',
#    '+',
#    'r',
#    '{',
#    '\\mathrm',
#    '{',
#    'v',
#    '}',
#    '3',
#    '}',
#    '\\nH',
#    '(',
#    '\\bm',
#    '\\delta',
#    '2',
#    ')'],
#   ['START',
#    'r',
#    '{',
#    '\\mathrm',
#    '{',
#    'v',
#    '}',
#    '1',
#    '}',
#    '+',
#    'r',
#    '{',
#    '\\mathrm',
#    '{',
#    'v',
#    '}',
#    '2',
#    '}',
#    '\\end',
#    '{',
#    's',
#    'p',
#    'l',
#    'i',
#    't',
#    '}']],
#  [['START',
#    '\\int',
#    '{',
#    '\\Omega',
#    '}',
#    '\\sum',
#    '{',
#    'i',
#    'j',
#    '=',
#    '1',
#    '}',
#    '{',
#    'n',
#    '}',
#    'a',
#    '{',
#    'i',
#    'j',
#    '}',
#    'X',
#    '{',
#    'i',
#    '}',
#    'u',
#    'X',
#    '{',
#    'j',
#    '}',
#    '\\varphi',
#    'd',
#    'x'],
#   ['START',
#    '0',
#    '\\text',
#    '{',
#    'f',
#    'o',
#    'r',
#    'a',
#    'n',
#    'y',
#    '}',
#    '\\varphi',
#    '\\in',
#    'C',
#    '{',
#    '0',
#    '}',
#    '{',
#    '\\infty',
#    '}',
#    '\\left',
#    '(',
#    '\\Omega',
#    '\\right',
#    ')']],
#  [['START',
#    '{',
#    '\\mathcal',
#    '{',
#    'K',
#    '}',
#    '}',
#    '-',
#    '\\frac',
#    '{',
#    '1',
#    '}',
#    '{',
#    'k',
#    '}',
#    '\\frac',
#    '{',
#    '\\dot',
#    '{',
#    '\\barH',
#    '}',
#    '}',
#    '{',
#    '\\barH',
#    '}',
#    '\\sigma',
#    'g'],
#   ['START',
#    '{',
#    '\\mathcal',
#    '{',
#    'K',
#    '}',
#    '}',
#    '-',
#    '\\frac',
#    '{',
#    '3',
#    '}',
#    '{',
#    '2',
#    '}',
#    '(',
#    '1',
#    '+',
#    'w',
#    'T',
#    ')',
#    '\\frac',
#    '{',
#    '\\sigma',
#    'g',
#    '}',
#    '{',
#    'k',
#    '{',
#    '{',
#    '\\mathcal',
#    '{',
#    'H',
#    '}',
#    '}',
#    '}',
#    '}']],
#  [['START',
#    '\\int',
#    '{',
#    '{',
#    '\\mathbb',
#    '{',
#    'R',
#    '}',
#    '}',
#    '3',
#    '}',
#    '\\rho',
#    '1',
#    '(',
#    '{',
#    '\\bm',
#    '{',
#    '{',
#    'r',
#    '}',
#    '}',
#    '}',
#    ')',
#    '\\rho',
#    '2',
#    '(',
#    '{',
#    '\\bm',
#    '{',
#    '{',
#    'r',
#    '}',
#    '}',
#    '}',
#    '+',
#    '{',
#    '\\bm',
#    '{',
#    '{',
#    'r',
#    '}',
#    '}',
#    '}',
#    ')',
#    'd',
#    '{',
#    '\\bm',
#    '{',
#    '{',
#    'r',
#    '}',
#    '}',
#    '}',
#    '{',
#    '\\gamma',
#    '}',
#    '{',
#    '1',
#    '2',
#    '}',
#    '(',
#    'l',
#    ')'],
#   ['START',
#    '\\frac',
#    '{',
#    '1',
#    '}',
#    '{',
#    '4',
#    '\\pi',
#    'l',
#    '2',
#    '}',
#    '\\int',
#    '{',
#    '{',
#    '\\mathbb',
#    '{',
#    'S',
#    '}',
#    '}',
#    'l',
#    '}',
#    '{',
#    '\\gamma',
#    '}',
#    '{',
#    '1',
#    '2',
#    '}',
#    '(',
#    '{',
#    '\\bm',
#    '{',
#    '{',
#    'r',
#    '}',
#    '}',
#    '}',
#    ')',
#    'd',
#    '\\Omega',
#    'd',
#    '\\Omega']],
#  [['START',
#    '\\frac',
#    '{',
#    'x',
#    '1',
#    'x',
#    '3',
#    'x',
#    '4',
#    '+',
#    'x',
#    '2',
#    'x',
#    '3',
#    'x',
#    '5',
#    '+',
#    'x',
#    '1',
#    'x',
#    '5',
#    'x',
#    '6',
#    '}',
#    '{',
#    'x',
#    '1',
#    'x',
#    '4',
#    'x',
#    '5',
#    '}',
#    'J',
#    '4'],
#   ['START',
#    '\\frac',
#    '{',
#    'x',
#    '1',
#    'x',
#    '3',
#    'x',
#    '5',
#    '+',
#    'x',
#    '2',
#    'x',
#    '4',
#    'x',
#    '6',
#    '+',
#    'x',
#    '1',
#    'x',
#    '2',
#    'x',
#    '4',
#    'x',
#    '5',
#    '+',
#    'x',
#    '1',
#    'x',
#    '3',
#    'x',
#    '4',
#    'x',
#    '6',
#    '+',
#    'x',
#    '2',
#    'x',
#    '3',
#    'x',
#    '5',
#    'x',
#    '6',
#    '}',
#    '{',
#    'x',
#    '1',
#    'x',
#    '2',
#    'x',
#    '5',
#    'x',
#    '6',
#    '}',
#    '{',
#    '}']],
#  [['START',
#    '\\frac',
#    '{',
#    '2',
#    '}',
#    '{',
#    '\\pi',
#    '}',
#    '\\int',
#    '{',
#    '-',
#    '1',
#    '}',
#    '1',
#    '\\frac',
#    '{',
#    'f',
#    '(',
#    'x',
#    ')',
#    'T',
#    'm',
#    '(',
#    'x',
#    ')',
#    '}',
#    '{',
#    '\\sqrt',
#    '{',
#    '1',
#    '-',
#    'x',
#    '2',
#    '}',
#    '}',
#    'd',
#    'x'],
#   ['START',
#    '\\frac',
#    '{',
#    '2',
#    '}',
#    '{',
#    '\\pi',
#    '}',
#    '\\int',
#    '0',
#    '\\pi',
#    'f',
#    '(',
#    '\\cos',
#    '\\theta',
#    ')',
#    '\\cos',
#    'm',
#    '\\theta',
#    'd',
#    '\\theta']],
#  [['START',
#    '\\displaystyle',
#    '\\frac',
#    '{',
#    'a',
#    '1',
#    'c',
#    '2',
#    '-',
#    'a',
#    '2',
#    'c',
#    '1',
#    '}',
#    '{',
#    'c',
#    '1',
#    'b',
#    '2',
#    '-',
#    'c',
#    '2',
#    'b',
#    '1',
#    '}',
#    'G'],
#   ['START',
#    '\\displaystyle',
#    '\\frac',
#    '{',
#    'c',
#    '1',
#    'b',
#    '2',
#    '-',
#    'c',
#    '2',
#    'b',
#    '1',
#    '}',
#    '{',
#    'a',
#    '1',
#    'b',
#    '2',
#    '-',
#    'a',
#    '2',
#    'b',
#    '1',
#    '}']],
#  [['START',
#    '\\frac',
#    '{',
#    '1',
#    '}',
#    '{',
#    'c',
#    '{',
#    '2',
#    '}',
#    '}',
#    '\\left',
#    '(',
#    '\\frac',
#    '{',
#    'd',
#    'p',
#    '{',
#    'r',
#    '}',
#    '}',
#    '{',
#    'd',
#    '\\rho',
#    '}',
#    '\\right',
#    ')',
#    '{',
#    'r',
#    '=',
#    '0',
#    '}'],
#   ['START',
#    '\\frac',
#    '{',
#    '1',
#    '}',
#    '{',
#    'c',
#    '{',
#    '2',
#    '}',
#    '}',
#    '\\left',
#    '(',
#    '\\frac',
#    '{',
#    'd',
#    'p',
#    '{',
#    't',
#    '}',
#    '}',
#    '{',
#    'd',
#    '\\rho',
#    '}',
#    '\\right',
#    ')',
#    '{',
#    'r',
#    '=',
#    '0',
#    '}']],
#  [['START',
#    '\\frac',
#    '{',
#    '\\left',
#    '\\langle',
#    'k',
#    '(',
#    '0',
#    ')',
#    '\\right',
#    '\\rangle',
#    '}',
#    '{',
#    'L',
#    '}'],
#   ['START',
#    '\\frac',
#    '{',
#    '\\Omega',
#    '+',
#    'M',
#    '(',
#    '1',
#    '-',
#    's',
#    ')',
#    '}',
#    '{',
#    '1',
#    '+',
#    '2',
#    '\\Omega',
#    '+',
#    '2',
#    'M',
#    '(',
#    '1',
#    '-',
#    's',
#    ')',
#    '}']],
#  [['START', '\\int', '0', '1', '\\varphi', '1', 'r', 'k', 'd', 't'],
#   ['START',
#    '\\int',
#    '0',
#    '1',
#    '\\varphi',
#    '2',
#    's',
#    'k',
#    'd',
#    't',
#    '\\forall',
#    '1',
#    '\\leq',
#    'k',
#    '\\leq',
#    'N',
#    '+',
#    '1']],
#  [['START',
#    '\\frac',
#    '{',
#    '{',
#    '\\delta',
#    '}',
#    '{',
#    '\\Sigma',
#    '}',
#    'c',
#    '}',
#    '{',
#    '{',
#    '\\delta',
#    '}',
#    'b',
#    '(',
#    'x',
#    ')',
#    '}'],
#   ['START',
#    '0',
#    '\\frac',
#    '{',
#    '{',
#    '\\partial',
#    '}',
#    '{',
#    '\\Sigma',
#    '}',
#    'c',
#    '}',
#    '{',
#    '{',
#    '\\partial',
#    '}',
#    '{',
#    '\\xi',
#    '}',
#    '{',
#    '\\mu',
#    '}',
#    '}']],
#  ...]

# %%
from gensim.models import TfidfModel
from gensim.corpora import Dictionary
from gensim.similarities import MatrixSimilarity

dataset = df['clean_split_filtered_tokenized']
docs = [doc for sublist in dataset.tolist() for doc in sublist]
dct = Dictionary(docs)
corpus = [dct.doc2bow(line) for line in docs]

# %%
from gensim.models import LsiModel
lsi = LsiModel(corpus, id2word=dct, num_topics=100)
index = MatrixSimilarity(lsi[corpus]) # transform corpus to LSI space and index it

# %%
# doc = "Human computer interaction"
vec_bow = dct.doc2bow(docs[0])
vec_lsi = lsi[vec_bow] # convert the query to LSI space
# print(vec_lsi)

# %%
lsi.print_topics()
# Out:
# [(0,
#   '0.616*"}" + 0.616*"{" + 0.154*"e" + 0.139*"t" + 0.136*"2" + 0.134*")" + 0.134*"(" + 0.132*"i" + 0.125*"1" + 0.105*"n"'),
#  (1,
#   '-0.438*"e" + -0.339*"t" + -0.311*"i" + 0.292*"}" + 0.292*"{" + -0.252*"n" + -0.220*"l" + -0.218*"r" + -0.215*"o" + -0.206*"a"'),
#  (2,
#   '0.392*"(" + 0.392*")" + 0.373*"2" + 0.307*"0" + 0.279*"1" + 0.263*"-" + -0.232*"e" + 0.163*"5" + -0.148*"}" + -0.147*"{"'),
#  (3,
#   '-0.445*")" + -0.445*"(" + 0.240*"0" + -0.213*"s" + 0.207*"4" + 0.204*"3" + 0.201*"2" + 0.198*"5" + 0.197*"7" + 0.197*"="'),
#  (4,
#   '0.646*"2" + -0.373*"0" + 0.299*"1" + 0.230*"+" + -0.188*"(" + -0.188*")" + 0.185*"\\frac" + -0.156*"=" + -0.130*"i" + -0.128*"l"'),
#  (5,
#   '0.541*"1" + 0.499*"-" + -0.409*"2" + 0.228*"+" + -0.189*"t" + -0.158*"(" + -0.157*")" + -0.157*"d" + 0.147*"a" + 0.142*"n"'),
#  (6,
#   '0.545*"x" + 0.388*"l" + -0.287*"0" + 0.214*"v" + 0.209*"p" + 0.208*"a" + 0.187*"b" + -0.162*"t" + 0.161*"i" + 0.152*"3"'),
#  (7,
#   '-0.406*"i" + 0.401*"a" + -0.340*"n" + 0.303*"z" + 0.242*"0" + -0.213*"j" + 0.205*"r" + -0.174*"+" + 0.162*"-" + -0.153*"d"'),
#  (8,
#   '0.607*"1" + -0.578*"-" + -0.242*"2" + -0.220*"n" + 0.179*"t" + 0.125*"h" + -0.123*"m" + -0.112*"*" + -0.110*"r" + 0.107*"x"'),
#  (9,
#   '-0.532*"z" + 0.312*"x" + 0.311*"-" + 0.276*"t" + -0.231*"r" + -0.219*"\\overline" + -0.216*"i" + 0.174*"0" + -0.155*"\\varphi" + 0.153*"\\frac"'),
#  (10,
#   '-0.431*"x" + -0.408*"z" + -0.298*"d" + -0.263*"t" + -0.260*"\\frac" + 0.205*"l" + 0.198*"s" + -0.172*"n" + -0.144*"\\overline" + -0.140*"START"'),
#  (11,
#   '-0.819*"+" + 0.233*"-" + -0.212*"0" + 0.199*"1" + 0.188*"z" + 0.153*"i" + 0.119*"\\frac" + -0.108*"a" + -0.100*"3" + -0.098*"s"'),
#  (12,
#   '0.449*"i" + -0.448*"n" + 0.373*"t" + -0.186*"e" + 0.185*"k" + 0.183*"z" + 0.168*"j" + 0.160*"p" + 0.155*"+" + -0.142*"d"'),
#  (13,
#   '0.440*"x" + -0.373*"\\frac" + -0.273*"l" + -0.237*"\\left" + -0.237*"\\right" + -0.227*"d" + 0.223*"m" + 0.212*"n" + 0.179*"i" + 0.164*"\\alpha"'),
#  (14,
#   '0.423*"t" + -0.395*"\\frac" + -0.340*"s" + -0.278*"0" + 0.194*"p" + -0.179*"r" + 0.179*"-" + -0.169*"x" + -0.167*"START" + -0.164*"\\partial"'),
#  (15,
#   '-0.464*"r" + 0.405*"s" + -0.342*"m" + 0.276*"z" + 0.248*"n" + -0.238*"*" + 0.160*"f" + -0.157*"a" + -0.156*"d" + 0.144*"l"'),
#  (16,
#   '-0.434*"s" + 0.392*"n" + -0.287*"d" + 0.264*"\\frac" + 0.207*"0" + 0.202*"a" + -0.192*"i" + -0.167*"4" + -0.165*"-" + -0.161*"7"'),
#  (17,
#   '-0.563*"d" + -0.423*"k" + 0.300*"\\right" + 0.300*"\\left" + 0.187*"i" + -0.180*"\\int" + 0.151*"\\partial" + -0.144*"0" + 0.139*"3" + 0.129*"f"'),
#  (18,
#   '0.676*"m" + 0.253*"p" + 0.253*"\\right" + 0.253*"\\left" + -0.252*"r" + 0.208*"s" + -0.190*"\\partial" + -0.162*"i" + 0.153*"d" + 0.145*"z"'),
#  (19,
#   '-0.644*"k" + 0.271*"0" + -0.244*"3" + 0.231*"i" + 0.216*"d" + -0.187*"4" + 0.182*"\\alpha" + -0.177*"t" + 0.152*"+" + -0.149*"6"')]
